# %% [markdown]
# ## Getting Data and Performing Operations

# %% [markdown]
# ### Getting Data Using Pandas Datareader

# %%
# Be sure to have installed pandas_datareader in bash shell 

# If you receive error message, ModuleNotFoundError: No module named 'pandas_datareader',
# then you need to pip install pandas_datareader

# %%
import pandas_datareader
from pandas_datareader import data
import matplotlib.pyplot as plot
import pandas as pd

# %%
# Only get the adjusted close.
netflix = data.DataReader("NFLX", 
                       start='2009-1-1', 
                       end='2020-01-31', 
                       data_source='yahoo')['Adj Close']

nf = pd.DataFrame(netflix)
nf.to_csv('netflix.csv')

# %%
# Read in saved data, this will be in pandas dataframe format
netflix = pd.read_csv('netflix.csv')
netflix.head()
# Out:
#          Date  Adj Close
# 0  2009-01-02   4.267143
# 1  2009-01-05   4.562857
# 2  2009-01-06   4.705714
# 3  2009-01-07   4.672857
# 4  2009-01-08   4.735714

# %%
netflix.tail()
# Out:
#             Date   Adj Close
# 2784  2020-01-27  342.880005
# 2785  2020-01-28  348.519989
# 2786  2020-01-29  343.160004
# 2787  2020-01-30  347.739990
# 2788  2020-01-31  345.089996

# %%
# Set datetime
from datetime import datetime
netflix['Date'] = pd.to_datetime(netflix['Date'])

# %%
# Set index
netflix.set_index('Date', inplace = True)
netflix.head()
# Out:
#             Adj Close
# Date
# 2009-01-02   4.267143
# 2009-01-05   4.562857
# 2009-01-06   4.705714
# 2009-01-07   4.672857
# 2009-01-08   4.735714

# %%
# Take a look at various fonts, lines, styles for matplotlib
print(plot.style.available)
# Out:
# ['seaborn-dark', 'seaborn-darkgrid', 'seaborn-ticks', 'fivethirtyeight', 'seaborn-whitegrid', 'classic', '_classic_test', 'fast', 'seaborn-talk', 'seaborn-dark-palette', 'seaborn-bright', 'seaborn-pastel', 'grayscale', 'seaborn-notebook', 'ggplot', 'seaborn-colorblind', 'seaborn-muted', 'seaborn', 'Solarize_Light2', 'seaborn-paper', 'bmh', 'tableau-colorblind10', 'seaborn-white', 'dark_background', 'seaborn-poster', 'seaborn-deep']

# %%
plot.style.use('fivethirtyeight')
netflix.plot(title='Netflix Adj. Closing Price', figsize=(10,5), color='red')
plot.show()

# %%
# Convert the adjusted closing prices to cumulative returns.

# Take percentage change of stock price of Netflix
returns = netflix.pct_change()

# Calculate the cumulative product
#  In cumulative product, the length of returned series is same as input series and every element is equal 
# to the product of current and all previous values.

plot.style.use('bmh')
((1 + returns).cumprod() - 1).plot(title='Netflix Cumulative Returns', figsize=(10,5), color='purple')

# %%
# Plot the returns, which is the percentage change in adjusted closing price

plot.style.use('tableau-colorblind10')
netflix.pct_change().plot(figsize=(10,5), color = 'green');

# %% [markdown]
# ### Getting Data Using API Key

# %%
# source:  https://github.com/RomelTorres/alpha_vantage
# source:  https://alpha-vantage.readthedocs.io/en/latest/
# You will need to obtain a free API key from Alpha Vantage by
# going to https://www.alphavantage.co/


# In bash shell, type command below: 

# pip install alpha_vantage

# %%
# Pull intraday data, example using Disney stock
from alpha_vantage.timeseries import TimeSeries

# ts = TimeSeries(key='YOUR_API_KEY_HERE')
ts = TimeSeries(key='HFWBAPPJ4B2C968U')

# Get json object with the intraday data and another with  the call's metadata
# Use "DIS" for Disney or fill in a stock ticker of your choice
data, meta_data = ts.get_intraday('DIS')

# %%
# Take a look at data structure
data
# Out:
# {'2020-02-03 16:00:00': {'1. open': '141.2700',
#   '2. high': '141.3900',
#   '3. low': '141.0800',
#   '4. close': '141.3100',
#   '5. volume': '1078124'},
#  '2020-02-03 15:45:00': {'1. open': '141.1901',
#   '2. high': '141.3400',
#   '3. low': '140.9750',
#   '4. close': '141.2651',
#   '5. volume': '463428'},
#  '2020-02-03 15:30:00': {'1. open': '140.9300',
#   '2. high': '141.1800',
#   '3. low': '140.8850',
#   '4. close': '141.1800',
#   '5. volume': '296136'},
#  '2020-02-03 15:15:00': {'1. open': '140.8300',
#   '2. high': '140.9540',
#   '3. low': '140.8100',
#   '4. close': '140.9149',
#   '5. volume': '196994'},
#  '2020-02-03 15:00:00': {'1. open': '140.5900',
#   '2. high': '140.9100',
#   '3. low': '140.5600',
#   '4. close': '140.8300',
#   '5. volume': '206293'},
#  '2020-02-03 14:45:00': {'1. open': '140.5789',
#   '2. high': '140.6100',
#   '3. low': '140.4300',
#   '4. close': '140.5852',
#   '5. volume': '256008'},
#  '2020-02-03 14:30:00': {'1. open': '140.8400',
#   '2. high': '140.8400',
#   '3. low': '140.5100',
#   '4. close': '140.5763',
#   '5. volume': '247027'},
#  '2020-02-03 14:15:00': {'1. open': '140.9632',
#   '2. high': '140.9700',
#   '3. low': '140.7788',
#   '4. close': '140.8300',
#   '5. volume': '176644'},
#  '2020-02-03 14:00:00': {'1. open': '140.9800',
#   '2. high': '141.1500',
#   '3. low': '140.8000',
#   '4. close': '140.9600',
#   '5. volume': '216941'},
#  '2020-02-03 13:45:00': {'1. open': '140.8150',
#   '2. high': '141.2000',
#   '3. low': '140.7850',
#   '4. close': '140.9700',
#   '5. volume': '260981'},
#  '2020-02-03 13:30:00': {'1. open': '140.8500',
#   '2. high': '141.1020',
#   '3. low': '140.8000',
#   '4. close': '140.8100',
#   '5. volume': '228453'},
#  '2020-02-03 13:15:00': {'1. open': '141.4345',
#   '2. high': '141.6188',
#   '3. low': '140.7830',
#   '4. close': '140.8466',
#   '5. volume': '377095'},
#  '2020-02-03 13:00:00': {'1. open': '141.7100',
#   '2. high': '141.7300',
#   '3. low': '141.4000',
#   '4. close': '141.4200',
#   '5. volume': '251531'},
#  '2020-02-03 12:45:00': {'1. open': '141.4700',
#   '2. high': '141.7150',
#   '3. low': '141.4200',
#   '4. close': '141.7050',
#   '5. volume': '225437'},
#  '2020-02-03 12:30:00': {'1. open': '141.2901',
#   '2. high': '141.6500',
#   '3. low': '141.2700',
#   '4. close': '141.4700',
#   '5. volume': '297383'},
#  '2020-02-03 12:15:00': {'1. open': '141.0757',
#   '2. high': '141.4454',
#   '3. low': '141.0750',
#   '4. close': '141.3057',
#   '5. volume': '248517'},
#  '2020-02-03 12:00:00': {'1. open': '140.7800',
#   '2. high': '141.0800',
#   '3. low': '140.6900',
#   '4. close': '141.0800',
#   '5. volume': '280370'},
#  '2020-02-03 11:45:00': {'1. open': '141.2500',
#   '2. high': '141.4260',
#   '3. low': '140.7501',
#   '4. close': '140.7800',
#   '5. volume': '396529'},
#  '2020-02-03 11:30:00': {'1. open': '141.4800',
#   '2. high': '141.5900',
#   '3. low': '141.2400',
#   '4. close': '141.2400',
#   '5. volume': '396004'},
#  '2020-02-03 11:15:00': {'1. open': '141.2700',
#   '2. high': '141.8200',
#   '3. low': '141.2389',
#   '4. close': '141.4910',
#   '5. volume': '575122'},
#  '2020-02-03 11:00:00': {'1. open': '140.9700',
#   '2. high': '141.3950',
#   '3. low': '140.8700',
#   '4. close': '141.2600',
#   '5. volume': '545096'},
#  '2020-02-03 10:45:00': {'1. open': '141.1445',
#   '2. high': '141.3736',
#   '3. low': '140.9281',
#   '4. close': '140.9745',
#   '5. volume': '435772'},
#  '2020-02-03 10:30:00': {'1. open': '141.2500',
#   '2. high': '141.5100',
#   '3. low': '141.1300',
#   '4. close': '141.1300',
#   '5. volume': '526546'},
#  '2020-02-03 10:15:00': {'1. open': '140.9500',
#   '2. high': '141.7573',
#   '3. low': '140.9000',
#   '4. close': '141.2558',
#   '5. volume': '656557'},
#  '2020-02-03 10:00:00': {'1. open': '140.3500',
#   '2. high': '141.1600',
#   '3. low': '140.3400',
#   '4. close': '140.8700',
#   '5. volume': '670964'},
#  '2020-02-03 09:45:00': {'1. open': '139.7900',
#   '2. high': '140.7400',
#   '3. low': '139.7500',
#   '4. close': '140.3200',
#   '5. volume': '1240584'},
#  '2020-01-31 16:00:00': {'1. open': '138.1700',
#   '2. high': '138.3700',
#   '3. low': '137.9870',
#   '4. close': '138.3000',
#   '5. volume': '1060825'},
#  '2020-01-31 15:45:00': {'1. open': '138.0188',
#   '2. high': '138.1600',
#   '3. low': '137.7800',
#   '4. close': '138.1550',
#   '5. volume': '591601'},
#  '2020-01-31 15:30:00': {'1. open': '138.1400',
#   '2. high': '138.2500',
#   '3. low': '138.0000',
#   '4. close': '138.0100',
#   '5. volume': '363260'},
#  '2020-01-31 15:15:00': {'1. open': '138.1736',
#   '2. high': '138.1800',
#   '3. low': '138.0000',
#   '4. close': '138.1578',
#   '5. volume': '296643'},
#  '2020-01-31 15:00:00': {'1. open': '137.9100',
#   '2. high': '138.2700',
#   '3. low': '137.8800',
#   '4. close': '138.1700',
#   '5. volume': '248377'},
#  '2020-01-31 14:45:00': {'1. open': '137.8100',
#   '2. high': '138.3800',
#   '3. low': '137.8000',
#   '4. close': '137.9300',
#   '5. volume': '441247'},
#  '2020-01-31 14:30:00': {'1. open': '137.9100',
#   '2. high': '138.0100',
#   '3. low': '137.7700',
#   '4. close': '137.8420',
#   '5. volume': '193535'},
#  '2020-01-31 14:15:00': {'1. open': '137.7200',
#   '2. high': '138.1000',
#   '3. low': '137.7200',
#   '4. close': '137.8900',
#   '5. volume': '301034'},
#  '2020-01-31 14:00:00': {'1. open': '137.2900',
#   '2. high': '137.7600',
#   '3. low': '137.2900',
#   '4. close': '137.7100',
#   '5. volume': '271312'},
#  '2020-01-31 13:45:00': {'1. open': '137.5200',
#   '2. high': '137.5200',
#   '3. low': '137.2150',
#   '4. close': '137.2900',
#   '5. volume': '235266'},
#  '2020-01-31 13:30:00': {'1. open': '137.8100',
#   '2. high': '137.8250',
#   '3. low': '137.5170',
#   '4. close': '137.5300',
#   '5. volume': '231242'},
#  '2020-01-31 13:15:00': {'1. open': '137.9094',
#   '2. high': '138.1100',
#   '3. low': '137.6800',
#   '4. close': '137.7944',
#   '5. volume': '252598'},
#  '2020-01-31 13:00:00': {'1. open': '138.0400',
#   '2. high': '138.1000',
#   '3. low': '137.7200',
#   '4. close': '137.9300',
#   '5. volume': '240512'},
#  '2020-01-31 12:45:00': {'1. open': '138.2536',
#   '2. high': '138.3840',
#   '3. low': '137.7089',
#   '4. close': '138.0336',
#   '5. volume': '345969'},
#  '2020-01-31 12:30:00': {'1. open': '138.2723',
#   '2. high': '138.2900',
#   '3. low': '138.1600',
#   '4. close': '138.2623',
#   '5. volume': '249121'},
#  '2020-01-31 12:15:00': {'1. open': '138.4300',
#   '2. high': '138.6700',
#   '3. low': '138.2600',
#   '4. close': '138.2800',
#   '5. volume': '335331'},
#  '2020-01-31 12:00:00': {'1. open': '138.3700',
#   '2. high': '138.4400',
#   '3. low': '138.2300',
#   '4. close': '138.4300',
#   '5. volume': '481387'},
#  '2020-01-31 11:45:00': {'1. open': '137.9500',
#   '2. high': '138.3900',
#   '3. low': '137.8440',
#   '4. close': '138.3900',
#   '5. volume': '571546'},
#  '2020-01-31 11:30:00': {'1. open': '137.8350',
#   '2. high': '138.3200',
#   '3. low': '137.5350',
#   '4. close': '137.9450',
#   '5. volume': '579100'},
#  '2020-01-31 11:15:00': {'1. open': '137.6400',
#   '2. high': '137.9700',
#   '3. low': '137.6100',
#   '4. close': '137.8331',
#   '5. volume': '275703'},
#  '2020-01-31 11:00:00': {'1. open': '137.5500',
#   '2. high': '137.7350',
#   '3. low': '137.5400',
#   '4. close': '137.6200',
#   '5. volume': '229945'},
#  '2020-01-31 10:45:00': {'1. open': '137.6300',
#   '2. high': '137.7550',
#   '3. low': '137.5200',
#   '4. close': '137.5450',
#   '5. volume': '335484'},
#  '2020-01-31 10:30:00': {'1. open': '137.2051',
#   '2. high': '137.9000',
#   '3. low': '137.1900',
#   '4. close': '137.6301',
#   '5. volume': '443099'},
#  '2020-01-31 10:15:00': {'1. open': '137.7250',
#   '2. high': '137.7550',
#   '3. low': '137.2100',
#   '4. close': '137.2100',
#   '5. volume': '485505'},
#  '2020-01-31 10:00:00': {'1. open': '138.0300',
#   '2. high': '138.0500',
#   '3. low': '137.2700',
#   '4. close': '137.7300',
#   '5. volume': '486277'},
#  '2020-01-31 09:45:00': {'1. open': '138.4058',
#   '2. high': '138.6432',
#   '3. low': '137.7924',
#   '4. close': '138.0425',
#   '5. volume': '899016'},
#  '2020-01-30 16:00:00': {'1. open': '137.4000',
#   '2. high': '137.7700',
#   '3. low': '137.3950',
#   '4. close': '137.7600',
#   '5. volume': '774388'},
#  '2020-01-30 15:45:00': {'1. open': '137.0351',
#   '2. high': '137.4600',
#   '3. low': '136.9800',
#   '4. close': '137.3956',
#   '5. volume': '446786'},
#  '2020-01-30 15:30:00': {'1. open': '136.8600',
#   '2. high': '137.1400',
#   '3. low': '136.7600',
#   '4. close': '137.0300',
#   '5. volume': '316834'},
#  '2020-01-30 15:15:00': {'1. open': '136.8000',
#   '2. high': '137.1200',
#   '3. low': '136.7800',
#   '4. close': '136.8350',
#   '5. volume': '326285'},
#  '2020-01-30 15:00:00': {'1. open': '136.3600',
#   '2. high': '136.8200',
#   '3. low': '136.2100',
#   '4. close': '136.7900',
#   '5. volume': '322048'},
#  '2020-01-30 14:45:00': {'1. open': '136.4227',
#   '2. high': '136.7920',
#   '3. low': '136.3200',
#   '4. close': '136.3527',
#   '5. volume': '468635'},
#  '2020-01-30 14:30:00': {'1. open': '136.3600',
#   '2. high': '136.5700',
#   '3. low': '136.3520',
#   '4. close': '136.4250',
#   '5. volume': '187506'},
#  '2020-01-30 14:15:00': {'1. open': '136.3243',
#   '2. high': '136.5138',
#   '3. low': '136.1885',
#   '4. close': '136.3667',
#   '5. volume': '260513'},
#  '2020-01-30 14:00:00': {'1. open': '136.4300',
#   '2. high': '136.5500',
#   '3. low': '136.2120',
#   '4. close': '136.3100',
#   '5. volume': '193723'},
#  '2020-01-30 13:45:00': {'1. open': '136.3850',
#   '2. high': '136.6650',
#   '3. low': '136.3400',
#   '4. close': '136.4200',
#   '5. volume': '226098'},
#  '2020-01-30 13:30:00': {'1. open': '136.3322',
#   '2. high': '136.5431',
#   '3. low': '136.2479',
#   '4. close': '136.3872',
#   '5. volume': '268222'},
#  '2020-01-30 13:15:00': {'1. open': '136.4405',
#   '2. high': '136.5807',
#   '3. low': '136.3205',
#   '4. close': '136.3455',
#   '5. volume': '253767'},
#  '2020-01-30 13:00:00': {'1. open': '136.3800',
#   '2. high': '136.4300',
#   '3. low': '136.0800',
#   '4. close': '136.4300',
#   '5. volume': '308652'},
#  '2020-01-30 12:45:00': {'1. open': '136.4700',
#   '2. high': '136.6200',
#   '3. low': '136.2800',
#   '4. close': '136.3900',
#   '5. volume': '292726'},
#  '2020-01-30 12:30:00': {'1. open': '136.4300',
#   '2. high': '136.8100',
#   '3. low': '136.3900',
#   '4. close': '136.4900',
#   '5. volume': '368617'},
#  '2020-01-30 12:15:00': {'1. open': '136.5900',
#   '2. high': '136.7100',
#   '3. low': '136.3500',
#   '4. close': '136.4400',
#   '5. volume': '250641'},
#  '2020-01-30 12:00:00': {'1. open': '136.6000',
#   '2. high': '136.7500',
#   '3. low': '136.5250',
#   '4. close': '136.5900',
#   '5. volume': '230884'},
#  '2020-01-30 11:45:00': {'1. open': '136.7693',
#   '2. high': '136.8300',
#   '3. low': '136.3200',
#   '4. close': '136.6143',
#   '5. volume': '338600'},
#  '2020-01-30 11:30:00': {'1. open': '136.4851',
#   '2. high': '136.8300',
#   '3. low': '136.3500',
#   '4. close': '136.7551',
#   '5. volume': '499401'},
#  '2020-01-30 11:15:00': {'1. open': '135.3400',
#   '2. high': '136.5600',
#   '3. low': '135.3200',
#   '4. close': '136.4850',
#   '5. volume': '438386'},
#  '2020-01-30 11:00:00': {'1. open': '135.6100',
#   '2. high': '135.7530',
#   '3. low': '135.3000',
#   '4. close': '135.3500',
#   '5. volume': '637809'},
#  '2020-01-30 10:45:00': {'1. open': '135.7054',
#   '2. high': '135.8300',
#   '3. low': '135.5000',
#   '4. close': '135.6054',
#   '5. volume': '340383'},
#  '2020-01-30 10:30:00': {'1. open': '135.6327',
#   '2. high': '135.7400',
#   '3. low': '135.4100',
#   '4. close': '135.7027',
#   '5. volume': '345498'},
#  '2020-01-30 10:15:00': {'1. open': '135.3300',
#   '2. high': '136.0548',
#   '3. low': '135.2850',
#   '4. close': '135.6400',
#   '5. volume': '371935'},
#  '2020-01-30 10:00:00': {'1. open': '135.8900',
#   '2. high': '136.0460',
#   '3. low': '135.3100',
#   '4. close': '135.3200',
#   '5. volume': '453312'},
#  '2020-01-30 09:45:00': {'1. open': '135.0944',
#   '2. high': '136.0400',
#   '3. low': '135.0200',
#   '4. close': '135.9082',
#   '5. volume': '1132961'},
#  '2020-01-29 16:00:00': {'1. open': '136.2000',
#   '2. high': '136.2150',
#   '3. low': '136.0700',
#   '4. close': '136.0700',
#   '5. volume': '715715'},
#  '2020-01-29 15:45:00': {'1. open': '136.1836',
#   '2. high': '136.3150',
#   '3. low': '136.0500',
#   '4. close': '136.2086',
#   '5. volume': '503462'},
#  '2020-01-29 15:30:00': {'1. open': '135.9100',
#   '2. high': '136.1900',
#   '3. low': '135.8600',
#   '4. close': '136.1750',
#   '5. volume': '397050'},
#  '2020-01-29 15:15:00': {'1. open': '136.2600',
#   '2. high': '136.2900',
#   '3. low': '135.7950',
#   '4. close': '135.8900',
#   '5. volume': '622406'},
#  '2020-01-29 15:00:00': {'1. open': '136.5700',
#   '2. high': '136.5700',
#   '3. low': '136.2550',
#   '4. close': '136.2600',
#   '5. volume': '309015'},
#  '2020-01-29 14:45:00': {'1. open': '136.6200',
#   '2. high': '136.6400',
#   '3. low': '136.5250',
#   '4. close': '136.5700',
#   '5. volume': '236911'},
#  '2020-01-29 14:30:00': {'1. open': '136.6750',
#   '2. high': '136.7000',
#   '3. low': '136.5200',
#   '4. close': '136.6184',
#   '5. volume': '262066'},
#  '2020-01-29 14:15:00': {'1. open': '136.6500',
#   '2. high': '136.9000',
#   '3. low': '136.5700',
#   '4. close': '136.6700',
#   '5. volume': '254951'},
#  '2020-01-29 14:00:00': {'1. open': '136.8600',
#   '2. high': '136.8700',
#   '3. low': '136.6400',
#   '4. close': '136.6400',
#   '5. volume': '171814'},
#  '2020-01-29 13:45:00': {'1. open': '136.9700',
#   '2. high': '136.9800',
#   '3. low': '136.8400',
#   '4. close': '136.8600',
#   '5. volume': '109480'},
#  '2020-01-29 13:30:00': {'1. open': '136.8300',
#   '2. high': '136.9800',
#   '3. low': '136.8140',
#   '4. close': '136.9800',
#   '5. volume': '115342'},
#  '2020-01-29 13:15:00': {'1. open': '136.9450',
#   '2. high': '136.9500',
#   '3. low': '136.7649',
#   '4. close': '136.8250',
#   '5. volume': '150346'},
#  '2020-01-29 13:00:00': {'1. open': '137.1200',
#   '2. high': '137.2120',
#   '3. low': '136.9500',
#   '4. close': '136.9500',
#   '5. volume': '169911'},
#  '2020-01-29 12:45:00': {'1. open': '137.0955',
#   '2. high': '137.2414',
#   '3. low': '137.0902',
#   '4. close': '137.1155',
#   '5. volume': '126009'},
#  '2020-01-29 12:30:00': {'1. open': '137.1094',
#   '2. high': '137.1200',
#   '3. low': '137.0300',
#   '4. close': '137.0900',
#   '5. volume': '120766'},
#  '2020-01-29 12:15:00': {'1. open': '137.0650',
#   '2. high': '137.2200',
#   '3. low': '137.0263',
#   '4. close': '137.1100',
#   '5. volume': '167649'},
#  '2020-01-29 12:00:00': {'1. open': '136.7700',
#   '2. high': '137.1200',
#   '3. low': '136.7700',
#   '4. close': '137.0800',
#   '5. volume': '157573'},
#  '2020-01-29 11:45:00': {'1. open': '137.0800',
#   '2. high': '137.1700',
#   '3. low': '136.7600',
#   '4. close': '136.7900',
#   '5. volume': '195214'},
#  '2020-01-29 11:30:00': {'1. open': '137.1086',
#   '2. high': '137.1700',
#   '3. low': '136.9600',
#   '4. close': '137.0932',
#   '5. volume': '197992'},
#  '2020-01-29 11:15:00': {'1. open': '136.5600',
#   '2. high': '137.1405',
#   '3. low': '136.5500',
#   '4. close': '137.0950',
#   '5. volume': '273715'},
#  '2020-01-29 11:00:00': {'1. open': '136.7700',
#   '2. high': '136.9000',
#   '3. low': '136.5800',
#   '4. close': '136.5800',
#   '5. volume': '364032'},
#  '2020-01-29 10:45:00': {'1. open': '136.6800',
#   '2. high': '136.8950',
#   '3. low': '136.6700',
#   '4. close': '136.7700',
#   '5. volume': '358581'}}

# %%
# Reformat data
# The data frame structure is given by the call on alpha vantage rest API. 
# The column names of the data frames are the ones given by their data structure.

from alpha_vantage.timeseries import TimeSeries
from pprint import pprint

# ts = TimeSeries(key='YOUR_API_KEY_HERE', output_format='pandas')
ts = TimeSeries(key='HFWBAPPJ4B2C968U', output_format='pandas')

# Use 'DIS' for Disney
data, meta_data = ts.get_intraday(symbol='DIS',interval='1min', outputsize='full')
pprint(data.head(10))
# Out:
#                      1. open   2. high   3. low  4. close  5. volume
# date
# 2020-02-03 16:00:00   141.12  141.3700  141.080  141.3100   260664.0
# 2020-02-03 15:59:00   141.19  141.2100  141.080  141.1300   101098.0
# 2020-02-03 15:58:00   141.33  141.3400  141.190  141.1900    94094.0
# 2020-02-03 15:57:00   141.27  141.3400  141.235  141.3300    75914.0
# 2020-02-03 15:56:00   141.21  141.2881  141.190  141.2800    66444.0
# 2020-02-03 15:55:00   141.24  141.2560  141.180  141.2100    69289.0
# 2020-02-03 15:54:00   141.31  141.3186  141.220  141.2581    61931.0
# 2020-02-03 15:53:00   141.26  141.3500  141.220  141.3200    46675.0
# 2020-02-03 15:52:00   141.28  141.2900  141.180  141.2600    46625.0
# 2020-02-03 15:51:00   141.29  141.3100  141.170  141.2700    67884.0

# %%
# We can also plot crypto currencies prices like Bitcoin

from alpha_vantage.cryptocurrencies import CryptoCurrencies

cc = CryptoCurrencies(key='HFWBAPPJ4B2C968U', output_format='pandas')

data, meta_data = cc.get_digital_currency_daily(symbol='BTC', market='CNY')

# %%
# Plot the data

plot.style.use('dark_background')
data['4b. close (USD)'].plot(figsize=(10,5), linewidth=4, color='orange')
plot.tight_layout()
plot.title('Daily Close Value for Bitcoin (BTC)')
plot.grid()
plot.show()

# %% [markdown]
# ## Getting Data by Downloading a File

# %%
# Google Trends website, search terms "Golf", "Soccer", "Tennis", "Hockey", and "Baseball"
# Dates:  2004-01 to 2019-11
# Source:  https://trends.google.com/trends/explore?date=all&geo=US&q=Golf,Soccer,Tennis,Hockey,Baseball

# Click on down arrow to download csv file
# Save As "file name here" and choose location to save file
# Open up csv file and take a look at header format of data, column headings, missing values, and number of data

# %%
# Read in file
sports = pd.read_csv("sports.csv", skiprows=2)

# %%
sports.head()
# Out:
#      Month  Golf: (United States)  Soccer: (United States)  \
# 0  2004-01                     45                       21
# 1  2004-02                     50                       24
# 2  2004-03                     63                       27
# 3  2004-04                     80                       29
# 4  2004-05                     82                       31
#
#    Tennis: (United States)  Hockey: (United States)  Baseball: (United States)
# 0                       13                       22                         24
# 1                       13                       23                         32
# 2                       15                       23                         45
# 3                       16                       16                         53
# 4                       17                       14                         52

# %%
# Reset column names
col_names = ['Month', 'Golf', 'Soccer', 'Tennis', 'Hockey', 'Baseball']

sports.columns = col_names

# %%
# verify column names have changed
sports.tail()
# Out:
#        Month  Golf  Soccer  Tennis  Hockey  Baseball
# 186  2019-07    58      42      17       6        35
# 187  2019-08    53      25      21       7        29
# 188  2019-09    39      31      21      10        25
# 189  2019-10    31      28      10      14        30
# 190  2019-11    27      27       9      16        17

# %%
# check for missing values
sports.isna().sum()
# Out:
# Month       0
# Golf        0
# Soccer      0
# Tennis      0
# Hockey      0
# Baseball    0
# dtype: int64

# %%
# Set index
sports.set_index('Month', inplace=True)

# %%
# Obtain the descriptive statistics
sports.describe()
# Out:
#              Golf      Soccer      Tennis      Hockey    Baseball
# count  191.000000  191.000000  191.000000  191.000000  191.000000
# mean    49.387435   28.853403   13.502618   14.879581   34.183246
# std     18.247326    8.682073    4.067683    5.916182   14.037279
# min     23.000000   17.000000    7.000000    6.000000   13.000000
# 25%     34.000000   24.000000   11.000000   11.000000   23.500000
# 50%     48.000000   28.000000   13.000000   15.000000   30.000000
# 75%     59.000000   32.000000   16.000000   18.000000   48.500000
# max    100.000000   84.000000   26.000000   55.000000   61.000000

# %%
# Plot the multi-time series
plot.style.use('classic')
sports.plot(figsize=(12,6), fontsize=10, linewidth=4)
plot.show();

# %%
# end
