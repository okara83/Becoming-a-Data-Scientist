# %%
from IPython.display import Image
from IPython.core.display import HTML

# %%
import sys
from rdflib import Graph,URIRef
import pandas as pd
pd.set_option("display.width",100)
pd.set_option("display.max_colwidth",80)

# %% [markdown]
# # Introduction to SPARQL

# %% [markdown]
# ## What is SPARQL?
# * Query language for the semantic web
# * since 2008 W3C recommendation
# * since 2013 SPARQL 1.1 W3C recommendation

# %% [markdown]
# ![title](img/sparql_anatomy.png)

# %% [markdown]
# # SPARQL
# * Types of SPARQL Queries
#     * SELECT: select values and return them (we will only use that)
#     * CONSTRUCT: create a new Graph
#     * ASK: Boolean (True/False)
#     * DESCRIBE: Describe a resource

# %% [markdown]
# ![title](img/4_types_sparql.png)

# %% [markdown]
# ### Representational State Transfer (Rest)
# * set of software architectual constraints to be used for web services
# * requests made to a resource's URI will elicit a response with a payload (in JSON, XML etc)
#     * response can e.g. be a confirmation that an operation on the resource has been done
#     * or a hyperlinked relation to another resource

# %% [markdown]
# ### most common HTTP methods
# * GET: Retrieve data
# * POST: Create new data
# * PUT: Update whole object
# * PATCH: Update part of the object
# * DELETE: Delete object

# %% [markdown]
# ### HTTP Header
# * used to define operating parameters
#     * Accept: Used to set the media type that is accepted by the request: "Accept: application/json"
#     * Accept-Charset: encoding that is accepted: "utf-8"
#     * Authorization: Authentication credentials: "Token TOKEN"

# %% [markdown]
# ### Some useful examples for Rest services in the DH
# * Lobid: https://lobid.org/
# * VIAF: https://platform.worldcat.org/api-explorer/apis
# * Peripleo (Pelagios): https://github.com/pelagios/peripleo/blob/master/README.md
# * ACDHs spacyapp: https://spacyapp.acdh-dev.oeaw.ac.at/query/nlppipeline/

# %% [markdown]
# # SPARQL query against local RDF

# %%
g=Graph()

# %%
g.parse('https://d-nb.info/gnd/118566512/about/lds.rdf')
# Out:
# <Graph identifier=N0abf254b7d1d412a880b5eb551e2d636 (<class 'rdflib.graph.Graph'>)>

# %%
properties = g.query("""
   SELECT ?s ?p ?o 
   WHERE {
      # ?s ?p ?o .
   }
""")
df_kreisky =  pd.DataFrame(properties)
df_kreisky
# Out:
#                                         0  \
# 0         https://d-nb.info/gnd/118566512
# 1   https://d-nb.info/gnd/118566512/about
# 2         https://d-nb.info/gnd/118566512
# 3         https://d-nb.info/gnd/118566512
# 4         https://d-nb.info/gnd/118566512
# 5         https://d-nb.info/gnd/118566512
# 6         https://d-nb.info/gnd/118566512
# 7         https://d-nb.info/gnd/118566512
# 8         https://d-nb.info/gnd/118566512
# 9       N08968214dbf14aa587ec1f5c3d5d4d1c
# 10        https://d-nb.info/gnd/118566512
# 11        https://d-nb.info/gnd/118566512
# 12        https://d-nb.info/gnd/118566512
# 13        https://d-nb.info/gnd/118566512
# 14      N08968214dbf14aa587ec1f5c3d5d4d1c
# 15        https://d-nb.info/gnd/118566512
# 16        https://d-nb.info/gnd/118566512
# 17        https://d-nb.info/gnd/118566512
# 18        https://d-nb.info/gnd/118566512
# 19        https://d-nb.info/gnd/118566512
# 20        https://d-nb.info/gnd/118566512
# 21        https://d-nb.info/gnd/118566512
# 22        https://d-nb.info/gnd/118566512
# 23        https://d-nb.info/gnd/118566512
# 24        https://d-nb.info/gnd/118566512
# 25        https://d-nb.info/gnd/118566512
# 26        https://d-nb.info/gnd/118566512
# 27        https://d-nb.info/gnd/118566512
# 28        https://d-nb.info/gnd/118566512
# 29        https://d-nb.info/gnd/118566512
# 30  https://d-nb.info/gnd/118566512/about
# 31        https://d-nb.info/gnd/118566512
# 32        https://d-nb.info/gnd/118566512
# 33        https://d-nb.info/gnd/118566512
# 34        https://d-nb.info/gnd/118566512
# 35        https://d-nb.info/gnd/118566512
# 36        https://d-nb.info/gnd/118566512
#
#                                                                                  1  \
# 0                         https://d-nb.info/standards/elementset/gnd#gndIdentifier
# 1                                                http://purl.org/dc/terms/modified
# 2                           https://d-nb.info/standards/elementset/gnd#dateOfDeath
# 3                  https://d-nb.info/standards/elementset/gnd#familialRelationship
# 4                          https://d-nb.info/standards/elementset/gnd#placeOfExile
# 5                                   http://www.w3.org/2007/05/powder-s#describedby
# 6       https://d-nb.info/standards/elementset/gnd#preferredNameEntityForThePerson
# 7                    https://d-nb.info/standards/elementset/gnd#oldAuthorityNumber
# 8                          https://d-nb.info/standards/elementset/gnd#placeOfBirth
# 9                               https://d-nb.info/standards/elementset/gnd#surname
# 10                        https://d-nb.info/standards/elementset/dnb#deprecatedUri
# 11                                                  http://xmlns.com/foaf/0.1/page
# 12                                            http://www.w3.org/2002/07/owl#sameAs
# 13                          https://d-nb.info/standards/elementset/gnd#affiliation
# 14                             https://d-nb.info/standards/elementset/gnd#forename
# 15               https://d-nb.info/standards/elementset/gnd#professionOrOccupation
# 16            https://d-nb.info/standards/elementset/gnd#preferredNameForThePerson
# 17                                            http://www.w3.org/2002/07/owl#sameAs
# 18                   https://d-nb.info/standards/elementset/gnd#gndSubjectCategory
# 19                                            http://www.w3.org/2002/07/owl#sameAs
# 20                                            http://www.w3.org/2002/07/owl#sameAs
# 21  https://d-nb.info/standards/elementset/gnd#biographicalOrHistoricalInformation
# 22                   https://d-nb.info/standards/elementset/gnd#geographicAreaCode
# 23                   https://d-nb.info/standards/elementset/gnd#oldAuthorityNumber
# 24                   https://d-nb.info/standards/elementset/gnd#geographicAreaCode
# 25                                            http://www.w3.org/2002/07/owl#sameAs
# 26                                            http://www.w3.org/2002/07/owl#sameAs
# 27                         https://d-nb.info/standards/elementset/gnd#placeOfDeath
# 28                   https://d-nb.info/standards/elementset/gnd#oldAuthorityNumber
# 29      https://d-nb.info/standards/elementset/gnd#professionOrOccupationAsLiteral
# 30                                                http://purl.org/dc/terms/license
# 31                                            http://www.w3.org/2002/07/owl#sameAs
# 32                                 http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 33      https://d-nb.info/standards/elementset/gnd#professionOrOccupationAsLiteral
# 34                          https://d-nb.info/standards/elementset/gnd#dateOfBirth
# 35  https://d-nb.info/standards/elementset/gnd#biographicalOrHistoricalInformation
# 36                               https://d-nb.info/standards/elementset/gnd#gender
#
#                                                                    2
# 0                                                          118566512
# 1                                                2021-12-15T00:31:22
# 2                                                         1990-07-29
# 3                                    https://d-nb.info/gnd/121036073
# 4                                    https://d-nb.info/gnd/4077258-5
# 5                              https://d-nb.info/gnd/118566512/about
# 6                                  N08968214dbf14aa587ec1f5c3d5d4d1c
# 7                                                 (DE-588)1243925787
# 8                                    https://d-nb.info/gnd/4066009-6
# 9                                                            Kreisky
# 10                                  https://d-nb.info/gnd/1243925787
# 11                       https://de.wikipedia.org/wiki/Bruno_Kreisky
# 12                                  https://d-nb.info/gnd/1243925787
# 13                                   https://d-nb.info/gnd/2029382-3
# 14                                                             Bruno
# 15                                   https://d-nb.info/gnd/4046517-2
# 16                                                    Kreisky, Bruno
# 17                                     http://viaf.org/viaf/31998484
# 18                https://d-nb.info/standards/vocab/gnd/gnd-sc#16.5p
# 19                            http://id.loc.gov/rwo/agents/n50043948
# 20                             http://www.wikidata.org/entity/Q44517
# 21                                            Politiker, Oesterreich
# 22  https://d-nb.info/standards/vocab/gnd/geographic-area-code#XA-SE
# 23                                                (DE-588a)118566512
# 24  https://d-nb.info/standards/vocab/gnd/geographic-area-code#XA-AT
# 25                         http://dbpedia.org/resource/Bruno_Kreisky
# 26                             http://isni.org/isni/0000000112608767
# 27                                   https://d-nb.info/gnd/4066009-6
# 28                                                (DE-588c)4032993-8
# 29                                                  Politiker <SPÖ>
# 30                 http://creativecommons.org/publicdomain/zero/1.0/
# 31  http://www.filmportal.de/person/5B113A52F8F14A879694D08C56BCEE81
# 32   https://d-nb.info/standards/elementset/gnd#DifferentiatedPerson
# 33                                       Bundeskanzler <Österreich>
# 34                                                        1911-01-22
# 35                                           Bundeskanzler 1970-1983
# 36                 https://d-nb.info/standards/vocab/gnd/gender#male

# %%
properties = g.query("""
   SELECT (COUNT(*) AS ?cnt) {
      # ?s ?p ?o .
   }
""")
df_kreisky =  pd.DataFrame(properties)
df_kreisky
# Out:
#     0
# 0  37

# %% [markdown]
# ## Example:
# ### SPARQL request wikidata

# %%
from SPARQLWrapper import SPARQLWrapper, JSON
import pandas as pd
import requests

# %%
sparql = SPARQLWrapper("https://query.wikidata.org/sparql")
sparql.setQuery("""
SELECT 
  # ?country ?population ?gnd ?capital
WHERE {
  # ?country wdt:P31 wd:Q261543.
  # ?country wdt:P1082 ?population .
  # ?country wdt:P227 ?gnd .
  # ?country wdt:P36 ?capital
}
""")
sparql.setReturnFormat(JSON)
results = sparql.query().convert()

# %%
results
# Out:
# {'head': {'vars': ['country', 'population', 'gnd', 'capital']},
#  'results': {'bindings': [{'country': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q37985'},
#     'capital': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q41753'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '561293'},
#     'gnd': {'type': 'literal', 'value': '4029175-3'}},
#    {'country': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q38981'},
#     'capital': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1737'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '397139'},
#     'gnd': {'type': 'literal', 'value': '4063944-7'}},
#    {'country': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q41358'},
#     'capital': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q13298'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '1246395'},
#     'gnd': {'type': 'literal', 'value': '4057092-7'}},
#    {'country': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q41967'},
#     'capital': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q41329'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '1490279'},
#     'gnd': {'type': 'literal', 'value': '4075560-5'}},
#    {'country': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q42497'},
#     'capital': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q82500'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '1684287'},
#     'gnd': {'type': 'literal', 'value': '4075391-8'}},
#    {'country': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q43210'},
#     'capital': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q126321'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '294436'},
#     'gnd': {'type': 'literal', 'value': '4009114-4'}},
#    {'country': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q43325'},
#     'capital': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q34713'},
#     'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '558410'},
#     'gnd': {'type': 'literal', 'value': '4051423-7'}}]}}

# %%
results_df = pd.json_normalize(results['results']['bindings'])
results_df[['capital.value', 'country.value', 'gnd.value', 'population.value']]
# Out:
#                             capital.value                          country.value  gnd.value  \
# 0   http://www.wikidata.org/entity/Q41753  http://www.wikidata.org/entity/Q37985  4029175-3
# 1    http://www.wikidata.org/entity/Q1737  http://www.wikidata.org/entity/Q38981  4063944-7
# 2   http://www.wikidata.org/entity/Q13298  http://www.wikidata.org/entity/Q41358  4057092-7
# 3   http://www.wikidata.org/entity/Q41329  http://www.wikidata.org/entity/Q41967  4075560-5
# 4   http://www.wikidata.org/entity/Q82500  http://www.wikidata.org/entity/Q42497  4075391-8
# 5  http://www.wikidata.org/entity/Q126321  http://www.wikidata.org/entity/Q43210  4009114-4
# 6   http://www.wikidata.org/entity/Q34713  http://www.wikidata.org/entity/Q43325  4051423-7
#
#   population.value
# 0           561293
# 1           397139
# 2          1246395
# 3          1490279
# 4          1684287
# 5           294436
# 6           558410

# %%
sparql.setQuery("""
SELECT 
  # ?country ?countryLabel ?population ?gnd ?capital ?capitalLabel
WHERE {
  # ?country wdt:P31 wd:Q261543.
  # ?country wdt:P1082 ?population .
  # ?country wdt:P227 ?gnd .
  # ?country wdt:P36 ?capital
SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
}
""")
sparql.setReturnFormat(JSON)
results = sparql.query().convert()

# %%
results_df = pd.json_normalize(results['results']['bindings'])
results_df[['capitalLabel.value', 'countryLabel.value', 'gnd.value', 'population.value']]
# Out:
#   capitalLabel.value countryLabel.value  gnd.value population.value
# 0         Klagenfurt          Carinthia  4029175-3           561293
# 1            Bregenz         Vorarlberg  4063944-7           397139
# 2               Graz             Styria  4057092-7          1246395
# 3               Linz      Upper Austria  4075560-5          1490279
# 4         St. Pölten      Lower Austria  4075391-8          1684287
# 5         Eisenstadt         Burgenland  4009114-4           294436
# 6           Salzburg           Salzburg  4051423-7           558410

# %% [markdown]
# # Combining graph patterns in SPARQL
# * Conjunction:  A . B >> Join results of solving A and B
# * Left join: A OPTIONAL { B } >> keep all the results from A whether or not there are results from B
# * Disjunction: { A } UNION { B } >> keep results from solving A and solving B
# * Negation: A MINUS { B } >> Keep only those results from A that are not compatible with B

# %%
sparql.setQuery("""
SELECT 
  # ?country ?countryLabel ?population ?gnd ?capital ?capitalLabel
WHERE {
  # ?country wdt:P31 wd:Q261543.
  OPTIONAL { ?country wdt:P1082 ?population }
  OPTIONAL { ?country wdt:P227 ?gnd }
  OPTIONAL { ?country wdt:P36 ?capital }
SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
}
""")
sparql.setReturnFormat(JSON)
results = sparql.query().convert()

# %%
results_df = pd.json_normalize(results['results']['bindings'])
results_df[['capitalLabel.value', 'countryLabel.value', 'gnd.value', 'population.value']]
# Out:
#   capitalLabel.value countryLabel.value  gnd.value population.value
# 0                NaN             Vienna  4066009-6          1911191
# 1         Klagenfurt          Carinthia  4029175-3           561293
# 2            Bregenz         Vorarlberg  4063944-7           397139
# 3               Graz             Styria  4057092-7          1246395
# 4               Linz      Upper Austria  4075560-5          1490279
# 5         St. Pölten      Lower Austria  4075391-8          1684287
# 6          Innsbruck              Tyrol        NaN           757634
# 7         Eisenstadt         Burgenland  4009114-4           294436
# 8           Salzburg           Salzburg  4051423-7           558410

# %%
sparql.setQuery("""
SELECT DISTINCT
  # ?country ?countryLabel ?population ?gnd ?capital ?capitalLabel ?populationCapital ?populationShareCapital
WHERE {
  # ?country wdt:P31 wd:Q261543.
  OPTIONAL { ?country wdt:P1082 ?population }
  OPTIONAL { ?country wdt:P227 ?gnd }
  OPTIONAL { ?country wdt:P36 ?capital .
          # ?capital wdt:P1082 ?populationCapital
  }
  FILTER(str(?capitalLabel) = 'Graz')
  SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
}
""")
sparql.setReturnFormat(JSON)
results = sparql.query().convert()

# %%
results_df = pd.json_normalize(results['results']['bindings'])
results_df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
sparql.setQuery("""
SELECT DISTINCT
  # ?country ?countryLabel ?population ?gnd ?capital ?capitalLabel ?populationCapital ?populationShareCapital
WHERE {
  # ?country wdt:P31 wd:Q261543.
  OPTIONAL { ?country wdt:P1082 ?population }
  OPTIONAL { ?country wdt:P227 ?gnd }
  OPTIONAL { ?country wdt:P36 ?capital .
          # ?capital wdt:P1082 ?populationCapital;
                    rdfs:label ?labelcapital
  }
  FILTER(str(?labelcapital) = 'Graz')
  SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
}
""")
sparql.setReturnFormat(JSON)
results = sparql.query().convert()

# %%
results_df = pd.json_normalize(results['results']['bindings'])
results_df[['capitalLabel.value', 'countryLabel.value', 'gnd.value', 'population.value', 'populationCapital.value']]
# Out:
#   capitalLabel.value countryLabel.value  gnd.value population.value populationCapital.value
# 0               Graz             Styria  4057092-7          1246395                  289440

# %% [markdown]
# ![title](img/filters_sparql.png)

# %%
sparql.setQuery("""
SELECT DISTINCT
  # ?country ?countryLabel ?population ?gnd ?capital ?capitalLabel ?populationCapital ?populationShareCapital
WHERE {
  # ?country wdt:P31 wd:Q261543.
  OPTIONAL { ?country wdt:P1082 ?population }
  OPTIONAL { ?country wdt:P227 ?gnd }
  OPTIONAL { ?country wdt:P36 ?capital .
          # ?capital wdt:P1082 ?populationCapital
  }
  BIND(?populationCapital / ?population AS ?populationShareCapital)
  SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
}
""")
sparql.setReturnFormat(JSON)
results = sparql.query().convert()

# %%
results_df = pd.json_normalize(results['results']['bindings'])
results_df[['capitalLabel.value', 'countryLabel.value', 'gnd.value', 'population.value', 'populationShareCapital.value']]
# Out:
#   capitalLabel.value countryLabel.value  gnd.value population.value populationShareCapital.value
# 0            Bregenz         Vorarlberg  4063944-7           397139        0.0750518080571286124
# 1               Linz      Upper Austria  4075560-5          1490279       0.13745479873231790826
# 2          Innsbruck              Tyrol        NaN           757634       0.17487731543198958864
# 3           Salzburg           Salzburg  4051423-7           558410       0.27761143246002041511
# 4                NaN             Vienna  4066009-6          1911191                          NaN
# 5         Eisenstadt         Burgenland  4009114-4           294436       0.04916518360526566045
# 6         St. Pölten      Lower Austria  4075391-8          1684287       0.03295994091268293349
# 7         Klagenfurt          Carinthia  4029175-3           561293       0.18065965547405722145
# 8               Graz             Styria  4057092-7          1246395       0.23222172746200040918

# %%
sparql.setQuery("""
SELECT DISTINCT
  # ?country ?countryLabel ?population ?gnd ?capital ?capitalLabel ?populationCapital ?lat_long
WHERE {
  # ?country wdt:P31 wd:Q261543.
  OPTIONAL { ?country wdt:P1082 ?population }
  OPTIONAL { ?country wdt:P3529 ?medianIncome }
  OPTIONAL { ?country wdt:P227 ?gnd }
  OPTIONAL { ?country wdt:P36 ?capital .
          # ?capital wdt:P1082 ?populationCapital
  }
  OPTIONAL { ?country wdt:P625 ?lat_long }
  SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
}
""")
sparql.setReturnFormat(JSON)
results = sparql.query().convert()

# %%
results_df = pd.json_normalize(results['results']['bindings'])
results_df[['countryLabel.value', 'lat_long.value',]]
# Out:
#   countryLabel.value                    lat_long.value
# 0           Salzburg  Point(13.364166666 47.766944444)
# 1      Upper Austria                  Point(14.0 48.2)
# 2         Burgenland          Point(16.416666666 47.5)
# 3             Styria         Point(15.166666666 47.25)
# 4      Lower Austria         Point(15.75 48.333333333)
# 5              Tyrol          Point(11.4 47.266666666)
# 6         Vorarlberg   Point(9.893888888 47.243611111)
# 7          Carinthia            Point(13.8617 46.7525)
# 8             Vienna       Point(16.3725 48.208333333)

# %%
import re
for idx, row in results_df.iterrows():
    print(row['lat_long.value'], type(row['lat_long.value']))
# Out:
# Point(13.364166666 47.766944444) <class 'str'>
# Point(14.0 48.2) <class 'str'>
# Point(16.416666666 47.5) <class 'str'>
# Point(15.166666666 47.25) <class 'str'>
# Point(15.75 48.333333333) <class 'str'>
# Point(11.4 47.266666666) <class 'str'>
# Point(9.893888888 47.243611111) <class 'str'>
# Point(13.8617 46.7525) <class 'str'>
# Point(16.3725 48.208333333) <class 'str'>

# %%
for idx, row in results_df.iterrows():
    lat_long = re.match('Point\(([0-9\.]+)\s([0-9\.]+)\)', row['lat_long.value'])
    if lat_long:
        long = lat_long.group(1)
        lat = lat_long.group(2)
        print(lat, long)
        results_df.at[idx, 'lat'] = lat
        results_df.at[idx, 'long'] = long
# Out:
# 47.766944444 13.364166666
# 48.2 14.0
# 47.5 16.416666666
# 47.25 15.166666666
# 48.333333333 15.75
# 47.266666666 11.4
# 47.243611111 9.893888888
# 46.7525 13.8617
# 48.208333333 16.3725

# %%
results_df[['countryLabel.value', 'lat_long.value', 'lat', 'long']]
# Out:
#   countryLabel.value                    lat_long.value           lat          long
# 0           Salzburg  Point(13.364166666 47.766944444)  47.766944444  13.364166666
# 1      Upper Austria                  Point(14.0 48.2)          48.2          14.0
# 2         Burgenland          Point(16.416666666 47.5)          47.5  16.416666666
# 3             Styria         Point(15.166666666 47.25)         47.25  15.166666666
# 4      Lower Austria         Point(15.75 48.333333333)  48.333333333         15.75
# 5              Tyrol          Point(11.4 47.266666666)  47.266666666          11.4
# 6         Vorarlberg   Point(9.893888888 47.243611111)  47.243611111   9.893888888
# 7          Carinthia            Point(13.8617 46.7525)       46.7525       13.8617
# 8             Vienna       Point(16.3725 48.208333333)  48.208333333       16.3725

# %%
from ipyleaflet import Map, basemaps, basemap_to_tiles, Marker
watercolor = basemap_to_tiles(basemaps.Stamen.Watercolor)
center = (results_df.at[0, 'lat'], results_df.at[0, 'long'])
m = Map(layers=(watercolor, ), center=center, zoom=3)
marker = Marker(location=center, draggable=False)
m.add_layer(marker)
m
# Out:
# Map(center=['47.766944444', '13.364166666'], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_…

# %%
from ipyleaflet import Map, basemaps, basemap_to_tiles, Marker
watercolor = basemap_to_tiles(basemaps.Stamen.Watercolor)
center = (results_df.at[0, 'lat'], results_df.at[0, 'long'])
m = Map(layers=(watercolor, ), center=center, zoom=6)
marker = Marker(location=center, draggable=False)
m.add_layer(marker)
for idx, row in results_df.loc[1:,:].iterrows():
    center = (row['lat'], row['long'])
    marker = Marker(location=center, draggable=False)
    m.add_layer(marker)

# %%
m
# Out:
# Map(center=['47.766944444', '13.364166666'], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_…

# %%
results_df[['capitalLabel.value', 'countryLabel.value', 'gnd.value', 'population.value', 'lat', 'long']]
# Out:
#   capitalLabel.value countryLabel.value  gnd.value population.value           lat          long
# 0           Salzburg           Salzburg  4051423-7           558410  47.766944444  13.364166666
# 1               Linz      Upper Austria  4075560-5          1490279          48.2          14.0
# 2         Eisenstadt         Burgenland  4009114-4           294436          47.5  16.416666666
# 3               Graz             Styria  4057092-7          1246395         47.25  15.166666666
# 4         St. Pölten      Lower Austria  4075391-8          1684287  48.333333333         15.75
# 5          Innsbruck              Tyrol        NaN           757634  47.266666666          11.4
# 6            Bregenz         Vorarlberg  4063944-7           397139  47.243611111   9.893888888
# 7         Klagenfurt          Carinthia  4029175-3           561293       46.7525       13.8617
# 8                NaN             Vienna  4066009-6          1911191  48.208333333       16.3725

# %%
url = 'https://histogis.acdh-dev.oeaw.ac.at/api/where-was'
res_geo = []
for idx, row in results_df.iterrows():
    params = {'lat': row['lat'], 'lng': row['long'], 'when': '1870'}
    res = requests.get(url, params=params)
    df_geo = pd.json_normalize(res.json()['features'])
    df_geo.at[:,'wikidata'] = row['country.value']
    res_geo.append(df_geo)
# Out:
# ---------------------------------------------------------------------------
# CertificateError                          Traceback (most recent call last)
# /usr/local/lib/python3.9/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702             # Make the request on the httplib connection object.
# --> 703             httplib_response = self._make_request(
#     704                 conn,
#
# /usr/local/lib/python3.9/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     385         try:
# --> 386             self._validate_conn(conn)
#     387         except (SocketTimeout, BaseSSLError) as e:
#
# /usr/local/lib/python3.9/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#    1039         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1040             conn.connect()
#    1041
#
# /usr/local/lib/python3.9/site-packages/urllib3/connection.py in connect(self)
#     468                 )
# --> 469             _match_hostname(cert, self.assert_hostname or server_hostname)
#     470
#
# /usr/local/lib/python3.9/site-packages/urllib3/connection.py in _match_hostname(cert, asserted_hostname)
#     541     try:
# --> 542         match_hostname(cert, asserted_hostname)
#     543     except CertificateError as e:
#
# /usr/local/lib/python3.9/site-packages/urllib3/util/ssl_match_hostname.py in match_hostname(cert, hostname)
#     151     if len(dnsnames) > 1:
# --> 152         raise CertificateError(
#     153             "hostname %r "
#
# CertificateError: hostname 'histogis.acdh-dev.oeaw.ac.at' doesn't match either of '*.acdh.oeaw.ac.at', 'acdh.oeaw.ac.at'
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# /usr/local/lib/python3.9/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     439             if not chunked:
# --> 440                 resp = conn.urlopen(
#     441                     method=request.method,
#
# /usr/local/lib/python3.9/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     784
# --> 785             retries = retries.increment(
#     786                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# /usr/local/lib/python3.9/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     591         if new_retry.is_exhausted():
# --> 592             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     593
#
# MaxRetryError: HTTPSConnectionPool(host='histogis.acdh-dev.oeaw.ac.at', port=443): Max retries exceeded with url: /api/where-was?lat=47.766944444&lng=13.364166666&when=1870 (Caused by SSLError(CertificateError("hostname 'histogis.acdh-dev.oeaw.ac.at' doesn't match either of '*.acdh.oeaw.ac.at', 'acdh.oeaw.ac.at'")))
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# /var/folders/sd/1vc_q83x5rn9jjrd0x47_cc00000gn/T/ipykernel_40522/688994946.py in <module>
#       3 for idx, row in results_df.iterrows():
#       4     params = {'lat': row['lat'], 'lng': row['long'], 'when': '1870'}
# ----> 5     res = requests.get(url, params=params)
#       6     df_geo = pd.json_normalize(res.json()['features'])
#       7     df_geo.at[:,'wikidata'] = row['country.value']
#
# /usr/local/lib/python3.9/site-packages/requests/api.py in get(url, params, **kwargs)
#      73     """
#      74
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# /usr/local/lib/python3.9/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# /usr/local/lib/python3.9/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     527         }
#     528         send_kwargs.update(settings)
# --> 529         resp = self.send(prep, **send_kwargs)
#     530
#     531         return resp
#
# /usr/local/lib/python3.9/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     643
#     644         # Send the request
# --> 645         r = adapter.send(request, **kwargs)
#     646
#     647         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python3.9/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     515             if isinstance(e.reason, _SSLError):
#     516                 # This branch is for urllib3 v1.22 and later.
# --> 517                 raise SSLError(e, request=request)
#     518
#     519             raise ConnectionError(e, request=request)
#
# SSLError: HTTPSConnectionPool(host='histogis.acdh-dev.oeaw.ac.at', port=443): Max retries exceeded with url: /api/where-was?lat=47.766944444&lng=13.364166666&when=1870 (Caused by SSLError(CertificateError("hostname 'histogis.acdh-dev.oeaw.ac.at' doesn't match either of '*.acdh.oeaw.ac.at', 'acdh.oeaw.ac.at'")))

# %%
res_geo[0][['@id', 'names', 'properties.adm_name', 'properties.start_date', 'properties.end_date']]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/sd/1vc_q83x5rn9jjrd0x47_cc00000gn/T/ipykernel_40522/2846551608.py in <module>
# ----> 1 res_geo[0][['@id', 'names', 'properties.adm_name', 'properties.start_date', 'properties.end_date']]
#
# IndexError: list index out of range

# %%
url = res_geo[0].at[0, '@id']
HTML('<a href="{}">{}</a>'.format(url, url))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/sd/1vc_q83x5rn9jjrd0x47_cc00000gn/T/ipykernel_40522/809775262.py in <module>
# ----> 1 url = res_geo[0].at[0, '@id']
#       2 HTML('<a href="{}">{}</a>'.format(url, url))
#
# IndexError: list index out of range

# %%
url = res_geo[0].at[0, 'wikidata']
HTML('<a href="{}">{}</a>'.format(url, url))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/sd/1vc_q83x5rn9jjrd0x47_cc00000gn/T/ipykernel_40522/205485530.py in <module>
# ----> 1 url = res_geo[0].at[0, 'wikidata']
#       2 HTML('<a href="{}">{}</a>'.format(url, url))
#
# IndexError: list index out of range

# %% [markdown]
# ### Example request to lobid

# %%
import requests

# %%
headers = {'accept': 'application/json'}
params = {'q': 'preferredName:Kreisky, Bruno', 'filter': 'type:Person'}
url = 'https://lobid.org/gnd/search'
res = requests.get(url, params=params, headers=headers)

# %%
res
# Out:
# <Response [200]>

# %%
res.json()
# Out:
# {'@context': 'https://lobid.org/gnd/context.jsonld',
#  'id': 'https://lobid.org/gnd/search?q=preferredName%3AKreisky%2C+Bruno&filter=type%3APerson',
#  'totalItems': 3,
#  'member': [{'gender': [{'id': 'https://d-nb.info/standards/vocab/gnd/gender#male',
#      'label': 'Männlich'}],
#    'dateOfDeath': ['1990-07-29'],
#    'placeOfExile': [{'id': 'https://d-nb.info/gnd/4077258-5',
#      'label': 'Schweden'}],
#    'placeOfDeath': [{'id': 'https://d-nb.info/gnd/4066009-6',
#      'label': 'Wien'}],
#    'familialRelationship': [{'id': 'https://d-nb.info/gnd/121036073',
#      'label': 'Kreisky, Eva'}],
#    'type': ['Person', 'DifferentiatedPerson', 'AuthorityResource'],
#    'gndSubjectCategory': [{'id': 'https://d-nb.info/standards/vocab/gnd/gnd-sc#16.5p',
#      'label': 'Personen der Geschichte (Politiker und historische Persönlichkeiten)'}],
#    'oldAuthorityNumber': ['(DE-588)1243925787',
#     '(DE-588a)118566512',
#     '(DE-588c)4032993-8'],
#    'geographicAreaCode': [{'id': 'https://d-nb.info/standards/vocab/gnd/geographic-area-code#XA-SE',
#      'label': 'Schweden'},
#     {'id': 'https://d-nb.info/standards/vocab/gnd/geographic-area-code#XA-AT',
#      'label': 'Österreich'}],
#    'biographicalOrHistoricalInformation': ['Bundeskanzler 1970-1983',
#     'Politiker, Oesterreich'],
#    'affiliation': [{'id': 'https://d-nb.info/gnd/2029382-3',
#      'label': 'Österreich. Bundeskanzleramt'}],
#    'describedBy': {'license': {'id': 'http://creativecommons.org/publicdomain/zero/1.0/',
#      'label': 'http://creativecommons.org/publicdomain/zero/1.0/'},
#     'dateModified': '2021-12-15T00:31:22.000',
#     'id': 'https://d-nb.info/gnd/118566512/about'},
#    'gndIdentifier': '118566512',
#    'id': 'https://d-nb.info/gnd/118566512',
#    'preferredName': 'Kreisky, Bruno',
#    'wikipedia': [{'id': 'https://de.wikipedia.org/wiki/Bruno_Kreisky',
#      'label': 'https://de.wikipedia.org/wiki/Bruno_Kreisky'}],
#    'preferredNameEntityForThePerson': {'forename': ['Bruno'],
#     'surname': ['Kreisky']},
#    'professionOrOccupationAsLiteral': ['Bundeskanzler <Österreich>',
#     'Politiker <SPÖ>'],
#    'depiction': [{'thumbnail': 'https://commons.wikimedia.org/wiki/Special:FilePath/Kreisky-Koechler-Vienna-1980%20Crop.jpg?width=270',
#      'id': 'http://commons.wikimedia.org/wiki/Special:FilePath/Kreisky-Koechler-Vienna-1980%20Crop.jpg',
#      'url': 'https://commons.wikimedia.org/wiki/File:Kreisky-Koechler-Vienna-1980%20Crop.jpg?uselang=de'}],
#    'professionOrOccupation': [{'id': 'https://d-nb.info/gnd/4046517-2',
#      'label': 'Politiker'}],
#    'placeOfBirth': [{'id': 'https://d-nb.info/gnd/4066009-6',
#      'label': 'Wien'}],
#    'dateOfBirth': ['1911-01-22'],
#    '@context': 'http://lobid.org/gnd/context.jsonld',
#    'deprecatedUri': ['https://d-nb.info/gnd/1243925787'],
#    'sameAs': [{'collection': {'name': 'Bibliothèque nationale de France',
#       'icon': 'https://www.bnf.fr/themes/custom/bnfsi/favicon.ico',
#       'publisher': 'Bibliothèque nationale de France',
#       'id': 'http://www.wikidata.org/entity/Q19938912',
#       'abbr': 'BNF'},
#      'id': 'http://catalogue.bnf.fr/ark:/12148/cb11910080j'},
#     {'collection': {'name': 'JudaicaLink',
#       'icon': 'https://data.judaicalink.org/static/img/favicon.ico',
#       'publisher': 'Stuttgart Media University',
#       'id': 'http://data.judaicalink.org',
#       'abbr': 'JudaicaLink'},
#      'id': 'http://data.judaicalink.org/data/gnd/118566512'},
#     {'id': 'http://dbpedia.org/resource/Bruno_Kreisky',
#      'collection': {'icon': 'http://dbpedia.org/favicon.ico',
#       'name': 'DBpedia',
#       'publisher': 'DBpedia',
#       'id': 'http://www.wikidata.org/entity/QQ465',
#       'abbr': 'DBpedia'}},
#     {'id': 'http://id.loc.gov/rwo/agents/n50043948',
#      'collection': {'icon': 'http://www.loc.gov/favicon.ico',
#       'name': 'NACO Authority File',
#       'publisher': 'Library of Congress',
#       'id': 'http://www.wikidata.org/entity/Q13219454',
#       'abbr': 'LC'}},
#     {'id': 'http://isni.org/isni/0000000112608767',
#      'collection': {'id': 'http://isni.org'}},
#     {'id': 'http://viaf.org/viaf/31998484',
#      'collection': {'icon': 'http://viaf.org/viaf/images/viaf.ico',
#       'name': 'Virtual International Authority File (VIAF)',
#       'publisher': 'OCLC',
#       'id': 'http://www.wikidata.org/entity/Q54919',
#       'abbr': 'VIAF'}},
#     {'id': 'http://www.filmportal.de/person/5B113A52F8F14A879694D08C56BCEE81',
#      'collection': {'icon': 'http://filmportal.de/misc/favicon.ico',
#       'name': 'Filmportal',
#       'publisher': 'Deutsches Filminstitut',
#       'id': 'http://www.wikidata.org/entity/Q15706812',
#       'abbr': 'filmportal.de'}},
#     {'id': 'http://www.wikidata.org/entity/Q44517',
#      'collection': {'icon': 'https://www.wikidata.org/static/favicon/wikidata.ico',
#       'name': 'Wikidata',
#       'publisher': 'Wikimedia Foundation Inc.',
#       'id': 'http://www.wikidata.org/entity/Q2013',
#       'abbr': 'WIKIDATA'}},
#     {'collection': {'name': 'Gemeinsame Normdatei (GND) im Katalog der Deutschen Nationalbibliothek',
#       'icon': 'https://www.dnb.de/SiteGlobals/Frontend/DNBWeb/Images/favicon.png?__blob=normal&v=4',
#       'publisher': 'Deutsche Nationalbibliothek',
#       'id': 'http://www.wikidata.org/entity/Q36578',
#       'abbr': 'DNB'},
#      'id': 'https://d-nb.info/gnd/118566512/about'},
#     {'id': 'https://d-nb.info/gnd/1243925787',
#      'collection': {'icon': 'http://www.dnb.de/SiteGlobals/StyleBundles/Bilder/favicon.png?__blob=normal&v=1',
#       'name': 'Gemeinsame Normdatei (GND) im Katalog der Deutschen Nationalbibliothek',
#       'publisher': 'Deutsche Nationalbibliothek',
#       'id': 'http://www.wikidata.org/entity/Q36578',
#       'abbr': 'DNB'}},
#     {'collection': {'name': 'Wikipedia (Deutsch)',
#       'icon': 'https://de.wikipedia.org/static/favicon/wikipedia.ico',
#       'publisher': 'Wikimedia Foundation Inc.',
#       'id': 'http://www.wikidata.org/entity/Q48183',
#       'abbr': 'dewiki'},
#      'id': 'https://de.wikipedia.org/wiki/Bruno_Kreisky'},
#     {'collection': {'name': 'Wikipedia (English)',
#       'icon': 'https://en.wikipedia.org/static/favicon/wikipedia.ico',
#       'publisher': 'Wikimedia Foundation Inc.',
#       'id': 'http://www.wikidata.org/entity/Q328',
#       'abbr': 'enwiki'},
#      'id': 'https://en.wikipedia.org/wiki/Bruno_Kreisky'},
#     {'collection': {'name': 'Kalliope Verbundkatalog',
#       'icon': 'https://kalliope-verbund.info/img/favicon.ico',
#       'publisher': 'Staatsbibliothek zu Berlin - Preußischer Kulturbesitz',
#       'id': 'https://kalliope-verbund.info',
#       'abbr': 'DE-611'},
#      'id': 'https://kalliope-verbund.info/gnd/118566512'},
#     {'collection': {'name': 'Archivportal-D',
#       'icon': 'https://www.archivportal-d.de/favicon.ico',
#       'publisher': 'Deutsche Digitale Bibliothek',
#       'id': 'https://www.archivportal-d.de',
#       'abbr': 'ARCHIV-D'},
#      'id': 'https://www.archivportal-d.de/person/gnd/118566512'},
#     {'collection': {'name': 'Deutsche Digitale Bibliothek',
#       'icon': 'https://www.deutsche-digitale-bibliothek.de/favicon.ico',
#       'publisher': 'Deutsche Digitale Bibliothek',
#       'id': 'http://www.wikidata.org/entity/Q621630',
#       'abbr': 'DDB'},
#      'id': 'https://www.deutsche-digitale-bibliothek.de/person/gnd/118566512'}]},
#   {'professionOrOccupation': [{'id': 'https://d-nb.info/gnd/4434804-6',
#      'label': 'Aktivist'},
#     {'id': 'https://d-nb.info/gnd/4029050-5', 'label': 'Jurist'},
#     {'id': 'https://d-nb.info/gnd/4140123-2',
#      'label': 'Sozialwissenschaftler'}],
#    'placeOfBirth': [{'id': 'https://d-nb.info/gnd/4057648-6',
#      'label': 'Stockholm'}],
#    'hasSpouse': [{'id': 'https://d-nb.info/gnd/121036073',
#      'label': 'Kreisky, Eva'}],
#    'gender': [{'id': 'https://d-nb.info/standards/vocab/gnd/gender#male',
#      'label': 'Männlich'}],
#    'dateOfDeath': ['2010'],
#    'dateOfBirth': ['1944'],
#    'placeOfDeath': [{'id': 'https://d-nb.info/gnd/7572205-7',
#      'label': 'Calvia'}],
#    'familialRelationship': [{'id': 'https://d-nb.info/gnd/118566512',
#      'label': 'Kreisky, Bruno'},
#     {'id': 'https://d-nb.info/gnd/121036073', 'label': 'Kreisky, Eva'}],
#    'type': ['Person', 'DifferentiatedPerson', 'AuthorityResource'],
#    '@context': 'http://lobid.org/gnd/context.jsonld',
#    'gndSubjectCategory': [{'id': 'https://d-nb.info/standards/vocab/gnd/gnd-sc#9.5p',
#      'label': 'Personen zu Soziologie, Gesellschaft, Arbeit, Sozialgeschichte'},
#     {'id': 'https://d-nb.info/standards/vocab/gnd/gnd-sc#7.14p',
#      'label': 'Personen zu Recht'}],
#    'oldAuthorityNumber': ['(DE-588a)170686299'],
#    'geographicAreaCode': [{'id': 'https://d-nb.info/standards/vocab/gnd/geographic-area-code#XA-AT',
#      'label': 'Österreich'}],
#    'biographicalOrHistoricalInformation': ['seit 1973 Mitarbeiter der Wirtschaftswissenschaftlichen Abteilung der Arbeiterkammer Wien; in den 70er und 80er Jahren bei zahlreichen Basis- und Bürgerinitiativen aktiv'],
#    'describedBy': {'license': {'id': 'http://creativecommons.org/publicdomain/zero/1.0/',
#      'label': 'http://creativecommons.org/publicdomain/zero/1.0/'},
#     'dateModified': '2021-07-10T06:12:59.000',
#     'id': 'https://d-nb.info/gnd/170686299/about'},
#    'gndIdentifier': '170686299',
#    'id': 'https://d-nb.info/gnd/170686299',
#    'placeOfActivity': [{'id': 'https://d-nb.info/gnd/4066009-6',
#      'label': 'Wien'}],
#    'preferredName': 'Kreisky, Peter',
#    'wikipedia': [{'id': 'https://de.wikipedia.org/wiki/Peter_Kreisky',
#      'label': 'https://de.wikipedia.org/wiki/Peter_Kreisky'}],
#    'preferredNameEntityForThePerson': {'forename': ['Peter'],
#     'surname': ['Kreisky']},
#    'hasParent': [{'id': 'https://d-nb.info/gnd/118566512',
#      'label': 'Kreisky, Bruno'}],
#    'sameAs': [{'id': 'http://id.loc.gov/rwo/agents/no2020126139',
#      'collection': {'icon': 'http://www.loc.gov/favicon.ico',
#       'name': 'NACO Authority File',
#       'publisher': 'Library of Congress',
#       'id': 'http://www.wikidata.org/entity/Q13219454',
#       'abbr': 'LC'}},
#     {'id': 'http://viaf.org/viaf/203136754',
#      'collection': {'icon': 'http://viaf.org/viaf/images/viaf.ico',
#       'name': 'Virtual International Authority File (VIAF)',
#       'publisher': 'OCLC',
#       'id': 'http://www.wikidata.org/entity/Q54919',
#       'abbr': 'VIAF'}},
#     {'id': 'http://www.wikidata.org/entity/Q1322819',
#      'collection': {'icon': 'https://www.wikidata.org/static/favicon/wikidata.ico',
#       'name': 'Wikidata',
#       'publisher': 'Wikimedia Foundation Inc.',
#       'id': 'http://www.wikidata.org/entity/Q2013',
#       'abbr': 'WIKIDATA'}},
#     {'collection': {'name': 'Gemeinsame Normdatei (GND) im Katalog der Deutschen Nationalbibliothek',
#       'icon': 'https://www.dnb.de/SiteGlobals/Frontend/DNBWeb/Images/favicon.png?__blob=normal&v=4',
#       'publisher': 'Deutsche Nationalbibliothek',
#       'id': 'http://www.wikidata.org/entity/Q36578',
#       'abbr': 'DNB'},
#      'id': 'https://d-nb.info/gnd/170686299/about'},
#     {'collection': {'name': 'Wikipedia (Deutsch)',
#       'icon': 'https://de.wikipedia.org/static/favicon/wikipedia.ico',
#       'publisher': 'Wikimedia Foundation Inc.',
#       'id': 'http://www.wikidata.org/entity/Q48183',
#       'abbr': 'dewiki'},
#      'id': 'https://de.wikipedia.org/wiki/Peter_Kreisky'},
#     {'collection': {'name': 'Deutsche Digitale Bibliothek',
#       'icon': 'https://www.deutsche-digitale-bibliothek.de/favicon.ico',
#       'publisher': 'Deutsche Digitale Bibliothek',
#       'id': 'http://www.wikidata.org/entity/Q621630',
#       'abbr': 'DDB'},
#      'id': 'https://www.deutsche-digitale-bibliothek.de/person/gnd/170686299'}],
#    'depiction': [{'thumbnail': 'https://commons.wikimedia.org/wiki/Special:FilePath/Peter%20Kreiky%20in%20Mallorca%2C%20Easter%202002.jpeg?width=270',
#      'id': 'http://commons.wikimedia.org/wiki/Special:FilePath/Peter%20Kreiky%20in%20Mallorca%2C%20Easter%202002.jpeg',
#      'url': 'https://commons.wikimedia.org/wiki/File:Peter%20Kreiky%20in%20Mallorca%2C%20Easter%202002.jpeg?uselang=de'}]},
#   {'professionOrOccupation': [{'id': 'https://d-nb.info/gnd/4130076-2',
#      'label': 'Juristin'},
#     {'id': 'https://d-nb.info/gnd/4629643-8', 'label': 'Politologin'}],
#    'placeOfBirth': [{'id': 'https://d-nb.info/gnd/4066009-6',
#      'label': 'Wien'}],
#    'gender': [{'id': 'https://d-nb.info/standards/vocab/gnd/gender#notKnown',
#      'label': 'Unbekannt'}],
#    'dateOfBirth': ['1944-08-08'],
#    'variantNameEntityForThePerson': [{'forename': ['Hannelore Eva'],
#      'surname': ['Kreisky']}],
#    'familialRelationship': [{'id': 'https://d-nb.info/gnd/118566512',
#      'label': 'Kreisky, Bruno'}],
#    'type': ['AuthorityResource', 'Person', 'DifferentiatedPerson'],
#    '@context': 'http://lobid.org/gnd/context.jsonld',
#    'gndSubjectCategory': [{'id': 'https://d-nb.info/standards/vocab/gnd/gnd-sc#7.14p',
#      'label': 'Personen zu Recht'},
#     {'id': 'https://d-nb.info/standards/vocab/gnd/gnd-sc#8.1p',
#      'label': 'Personen (Politologen, Staatstheoretiker)'}],
#    'oldAuthorityNumber': ['(DE-588a)121036073', '(DE-588c)7705035-6'],
#    'geographicAreaCode': [{'id': 'https://d-nb.info/standards/vocab/gnd/geographic-area-code#XA-AT',
#      'label': 'Österreich'}],
#    'biographicalOrHistoricalInformation': ['Österr. Prof. für Politikwissenschaft mit Schwerpunkt politische Theorie und Ideengeschichte'],
#    'describedBy': {'license': {'id': 'http://creativecommons.org/publicdomain/zero/1.0/',
#      'label': 'http://creativecommons.org/publicdomain/zero/1.0/'},
#     'dateModified': '2010-06-15T21:27:20.000',
#     'id': 'https://d-nb.info/gnd/121036073/about'},
#    'gndIdentifier': '121036073',
#    'id': 'https://d-nb.info/gnd/121036073',
#    'preferredName': 'Kreisky, Eva',
#    'wikipedia': [{'id': 'https://de.wikipedia.org/wiki/Eva_Kreisky',
#      'label': 'https://de.wikipedia.org/wiki/Eva_Kreisky'}],
#    'variantName': ['Kreisky, Hannelore Eva'],
#    'preferredNameEntityForThePerson': {'forename': ['Eva'],
#     'surname': ['Kreisky']},
#    'homepage': [{'id': 'http://evakreisky.at',
#      'label': 'http://evakreisky.at'}],
#    'sameAs': [{'collection': {'name': 'Bibliothèque nationale de France',
#       'icon': 'https://www.bnf.fr/themes/custom/bnfsi/favicon.ico',
#       'publisher': 'Bibliothèque nationale de France',
#       'id': 'http://www.wikidata.org/entity/Q19938912',
#       'abbr': 'BNF'},
#      'id': 'http://catalogue.bnf.fr/ark:/12148/cb134801126'},
#     {'id': 'http://id.loc.gov/rwo/agents/n80152140',
#      'collection': {'icon': 'http://www.loc.gov/favicon.ico',
#       'name': 'NACO Authority File',
#       'publisher': 'Library of Congress',
#       'id': 'http://www.wikidata.org/entity/Q13219454',
#       'abbr': 'LC'}},
#     {'id': 'http://isni.org/isni/0000000108693073',
#      'collection': {'id': 'http://isni.org'}},
#     {'id': 'http://viaf.org/viaf/9997727',
#      'collection': {'icon': 'http://viaf.org/viaf/images/viaf.ico',
#       'name': 'Virtual International Authority File (VIAF)',
#       'publisher': 'OCLC',
#       'id': 'http://www.wikidata.org/entity/Q54919',
#       'abbr': 'VIAF'}},
#     {'id': 'http://www.wikidata.org/entity/Q1379274',
#      'collection': {'icon': 'https://www.wikidata.org/static/favicon/wikidata.ico',
#       'name': 'Wikidata',
#       'publisher': 'Wikimedia Foundation Inc.',
#       'id': 'http://www.wikidata.org/entity/Q2013',
#       'abbr': 'WIKIDATA'}},
#     {'collection': {'name': 'Gemeinsame Normdatei (GND) im Katalog der Deutschen Nationalbibliothek',
#       'icon': 'https://www.dnb.de/SiteGlobals/Frontend/DNBWeb/Images/favicon.png?__blob=normal&v=4',
#       'publisher': 'Deutsche Nationalbibliothek',
#       'id': 'http://www.wikidata.org/entity/Q36578',
#       'abbr': 'DNB'},
#      'id': 'https://d-nb.info/gnd/121036073/about'},
#     {'collection': {'name': 'Wikipedia (Deutsch)',
#       'icon': 'https://de.wikipedia.org/static/favicon/wikipedia.ico',
#       'publisher': 'Wikimedia Foundation Inc.',
#       'id': 'http://www.wikidata.org/entity/Q48183',
#       'abbr': 'dewiki'},
#      'id': 'https://de.wikipedia.org/wiki/Eva_Kreisky'},
#     {'collection': {'name': 'Wikipedia (English)',
#       'icon': 'https://en.wikipedia.org/static/favicon/wikipedia.ico',
#       'publisher': 'Wikimedia Foundation Inc.',
#       'id': 'http://www.wikidata.org/entity/Q328',
#       'abbr': 'enwiki'},
#      'id': 'https://en.wikipedia.org/wiki/Eva_Kreisky'},
#     {'collection': {'name': 'Deutsche Digitale Bibliothek',
#       'icon': 'https://www.deutsche-digitale-bibliothek.de/favicon.ico',
#       'publisher': 'Deutsche Digitale Bibliothek',
#       'id': 'http://www.wikidata.org/entity/Q621630',
#       'abbr': 'DDB'},
#      'id': 'https://www.deutsche-digitale-bibliothek.de/person/gnd/121036073'}]}],
#  'aggregation': {'gndSubjectCategory.id': [{'key': 'https://d-nb.info/standards/vocab/gnd/gnd-sc#7.14p',
#     'doc_count': 2},
#    {'key': 'https://d-nb.info/standards/vocab/gnd/gnd-sc#16.5p',
#     'doc_count': 1},
#    {'key': 'https://d-nb.info/standards/vocab/gnd/gnd-sc#8.1p',
#     'doc_count': 1},
#    {'key': 'https://d-nb.info/standards/vocab/gnd/gnd-sc#9.5p',
#     'doc_count': 1}],
#   'professionOrOccupation.id': [{'key': 'https://d-nb.info/gnd/4029050-5',
#     'doc_count': 1},
#    {'key': 'https://d-nb.info/gnd/4046517-2', 'doc_count': 1},
#    {'key': 'https://d-nb.info/gnd/4130076-2', 'doc_count': 1},
#    {'key': 'https://d-nb.info/gnd/4140123-2', 'doc_count': 1},
#    {'key': 'https://d-nb.info/gnd/4434804-6', 'doc_count': 1},
#    {'key': 'https://d-nb.info/gnd/4629643-8', 'doc_count': 1}],
#   'geographicAreaCode.id': [{'key': 'https://d-nb.info/standards/vocab/gnd/geographic-area-code#XA-AT',
#     'doc_count': 3},
#    {'key': 'https://d-nb.info/standards/vocab/gnd/geographic-area-code#XA-SE',
#     'doc_count': 1}],
#   'dateOfBirth': [{'key': '1911-01-22', 'doc_count': 1},
#    {'key': '1944', 'doc_count': 1},
#    {'key': '1944-08-08', 'doc_count': 1}],
#   'type': [{'key': 'DifferentiatedPerson', 'doc_count': 3},
#    {'key': 'Person', 'doc_count': 3}]}}

# %%
res_dict = res.json()
res_df = pd.json_normalize(res_dict['member'])

# %%
res_df[['@context', 'preferredName', 'describedBy.id', 'biographicalOrHistoricalInformation', 'dateOfBirth', 'dateOfDeath']]
# Out:
#                               @context   preferredName                         describedBy.id  \
# 0  http://lobid.org/gnd/context.jsonld  Kreisky, Bruno  https://d-nb.info/gnd/118566512/about
# 1  http://lobid.org/gnd/context.jsonld  Kreisky, Peter  https://d-nb.info/gnd/170686299/about
# 2  http://lobid.org/gnd/context.jsonld    Kreisky, Eva  https://d-nb.info/gnd/121036073/about
#
#                                                biographicalOrHistoricalInformation   dateOfBirth  \
# 0                                [Bundeskanzler 1970-1983, Politiker, Oesterreich]  [1911-01-22]
# 1  [seit 1973 Mitarbeiter der Wirtschaftswissenschaftlichen Abteilung der Arbei...        [1944]
# 2  [Österr. Prof. für Politikwissenschaft mit Schwerpunkt politische Theorie un...  [1944-08-08]
#
#     dateOfDeath
# 0  [1990-07-29]
# 1        [2010]
# 2           NaN

# %%
headers = {'accept': 'application/json'}
params = {'q': 'preferredName:Graz', 'filter': 'type:TerritorialCorporateBodyOrAdministrativeUnit'}
url = 'https://lobid.org/gnd/search'
res = requests.get(url, params=params, headers=headers)

# %%
res
# Out:
# <Response [200]>

# %%
res.json()
# Out:
# {'@context': 'https://lobid.org/gnd/context.jsonld',
#  'id': 'https://lobid.org/gnd/search?q=preferredName%3AGraz&filter=type%3ATerritorialCorporateBodyOrAdministrativeUnit',
#  'totalItems': 38,
#  'member': [{'type': ['AuthorityResource',
#     'PlaceOrGeographicName',
#     'TerritorialCorporateBodyOrAdministrativeUnit'],
#    '@context': 'http://lobid.org/gnd/context.jsonld',
#    'oldAuthorityNumber': ['(DE-588)2028261-8',
#     '(DE-588b)10097697-9',
#     '(DE-588c)4021912-4',
#     '(DE-588b)2028261-8'],
#    'geographicAreaCode': [{'id': 'https://d-nb.info/standards/vocab/gnd/geographic-area-code#XA-AT-6',
#      'label': 'Österreich'}],
#    'hasGeometry': [{'asWKT': ['Point ( +015.450000 +047.066666 )'],
#      'type': 'Point'}],
#    'deprecatedUri': ['https://d-nb.info/gnd/2028261-8'],
#    'biographicalOrHistoricalInformation': ['Hauptstadt der Steiermark, 1128/29 urkundl. erwähnt, 1172 Markt, 1189 Stadt'],
#    'relatedDdcWithDegreeOfDeterminacy4': [{'id': 'http://dewey.info/class/2--43655/',
#      'label': 'http://dewey.info/class/2--43655/'}],
#    'describedBy': {'license': {'id': 'http://creativecommons.org/publicdomain/zero/1.0/',
#      'label': 'http://creativecommons.org/publicdomain/zero/1.0/'},
#     'dateModified': '2021-12-17T17:31:58.000',
#     'id': 'https://d-nb.info/gnd/4021912-4/about'},
#    'gndIdentifier': '4021912-4',
#    'id': 'https://d-nb.info/gnd/4021912-4',
#    'preferredName': 'Graz',
#    'wikipedia': [{'id': 'https://de.wikipedia.org/wiki/Graz',
#      'label': 'https://de.wikipedia.org/wiki/Graz'}],
#    'variantName': ['Grecium Styriae',
#     'Grätz',
#     'Graecii',
#     'Graetz',
#     'Grác',
#     'Graecium',
#     'Gräz',
#     'Grätz (Graz)',
#     'Gradc',
#     'Graecia',
#     'Stadt Graz',
#     'Graezi',
#     'Gratz',
#     'Gradec',
#     'Graecii Styrorum',
#     'Gracia',
#     'Štýrský Hradec',
#     'Gracensis'],
#    'homepage': [{'id': 'https://www.graz.at/',
#      'label': 'https://www.graz.at/'}],
#    'sameAs': [{'id': 'http://id.loc.gov/rwo/agents/n79064653',
#      'collection': {'icon': 'http://www.loc.gov/favicon.ico',
#       'name': 'NACO Authority File',
#       'publisher': 'Library of Congress',
#       'id': 'http://www.wikidata.org/entity/Q13219454',
#       'abbr': 'LC'}},
#     {'id': 'http://viaf.org/viaf/160255975',
#      'collection': {'icon': 'http://viaf.org/viaf/images/viaf.ico',
#       'name': 'Virtual International Authority File (VIAF)',
#       'publisher': 'OCLC',
#       'id': 'http://www.wikidata.org/entity/Q54919',
#       'abbr': 'VIAF'}},
#     {'id': 'http://www.wikidata.org/entity/Q13298',
#      'collection': {'icon': 'https://www.wikidata.org/static/favicon/wikidata.ico',
#       'name': 'Wikidata',
#       'publisher': 'Wikimedia Foundation Inc.',
#       'id': 'http://www.wikidata.org/entity/Q2013',
#       'abbr': 'WIKIDATA'}},
#     {'id': 'https://d-nb.info/gnd/2028261-8',
#      'collection': {'icon': 'http://www.dnb.de/SiteGlobals/StyleBundles/Bilder/favicon.png?__blob=normal&v=1',
#       'name': 'Gemeinsame Normdatei (GND) im Katalog der Deutschen Nationalbibliothek',
#       'publisher': 'Deutsche Nationalbibliothek',
#       'id': 'http://www.wikidata.org/entity/Q36578',
#       'abbr': 'DNB'}},
#     {'collection': {'name': 'Gemeinsame Normdatei (GND) im Katalog der Deutschen Nationalbibliothek',
#       'icon': 'https://www.dnb.de/SiteGlobals/Frontend/DNBWeb/Images/favicon.png?__blob=normal&v=4',
#       'publisher': 'Deutsche Nationalbibliothek',
#       'id': 'http://www.wikidata.org/entity/Q36578',
#       'abbr': 'DNB'},
#      'id': 'https://d-nb.info/gnd/4021912-4/about'},
#     {'collection': {'name': 'Wikipedia (Deutsch)',
#       'icon': 'https://de.wikipedia.org/static/favicon/wikipedia.ico',
#       'publisher': 'Wikimedia Foundation Inc.',
#       'id': 'http://www.wikidata.org/entity/Q48183',
#       'abbr': 'dewiki'},
#      'id': 'https://de.wikipedia.org/wiki/Graz'},
#     {'collection': {'name': 'Wikisource',
#       'icon': 'https://wikisource.org/static/favicon/wikisource.ico',
#       'publisher': 'Wikimedia Foundation Inc.',
#       'id': 'http://www.wikidata.org/entity/Q263',
#       'abbr': 'WIKISOURCE'},
#      'id': 'https://de.wikisource.org/wiki/Graz'},
#     {'collection': {'name': 'Wikipedia (English)',
#       'icon': 'https://en.wikipedia.org/static/favicon/wikipedia.ico',
#       'publisher': 'Wikimedia Foundation Inc.',
#       'id': 'http://www.wikidata.org/entity/Q328',
#       'abbr': 'enwiki'},
#      'id': 'https://en.wikipedia.org/wiki/Graz'},
#     {'collection': {'name': 'Kalliope Verbundkatalog',
#       'icon': 'https://kalliope-verbund.info/img/favicon.ico',
#       'publisher': 'Staatsbibliothek zu Berlin - Preußischer Kulturbesitz',
#       'id': 'https://kalliope-verbund.info',
#       'abbr': 'DE-611'},
#      'id': 'https://kalliope-verbund.info/gnd/4021912-4'},
#     {'id': 'https://sws.geonames.org/2778067',
#      'collection': {'id': 'https://sws.geonames.org'}}],
#    'depiction': [{'thumbnail': 'https://commons.wikimedia.org/wiki/Special:FilePath/AUT%20Graz%20COA.svg?width=270',
#      'id': 'http://commons.wikimedia.org/wiki/Special:FilePath/AUT%20Graz%20COA.svg',
#      'url': 'https://commons.wikimedia.org/wiki/File:AUT%20Graz%20COA.svg?uselang=de'}]},
#   {'geographicAreaCode': [{'id': 'https://d-nb.info/standards/vocab/gnd/geographic-area-code#XA-AT-6',
#      'label': 'Österreich'}],
#    'succeedingPlaceOrGeographicName': [{'id': 'https://d-nb.info/gnd/4288430-5',
#      'label': 'Graz-Waltendorf'}],
#    'relatedDdcWithDegreeOfDeterminacy2': [{'id': 'http://dewey.info/class/2--4365/',
#      'label': 'http://dewey.info/class/2--4365/'}],
#    'describedBy': {'license': {'id': 'http://creativecommons.org/publicdomain/zero/1.0/',
#      'label': 'http://creativecommons.org/publicdomain/zero/1.0/'},
#     'dateModified': '2019-03-01T16:44:53.000',
#     'id': 'https://d-nb.info/gnd/4290358-0/about'},
#    'gndIdentifier': '4290358-0',
#    'id': 'https://d-nb.info/gnd/4290358-0',
#    'preferredName': 'Waltendorf (Graz)',
#    'type': ['PlaceOrGeographicName',
#     'TerritorialCorporateBodyOrAdministrativeUnit',
#     'AuthorityResource'],
#    '@context': 'http://lobid.org/gnd/context.jsonld',
#    'dateOfTermination': ['1938'],
#    'oldAuthorityNumber': ['(DE-588c)4290358-0'],
#    'sameAs': [{'id': 'http://viaf.org/viaf/233818018',
#      'collection': {'icon': 'http://viaf.org/viaf/images/viaf.ico',
#       'name': 'Virtual International Authority File (VIAF)',
#       'publisher': 'OCLC',
#       'id': 'http://www.wikidata.org/entity/Q54919',
#       'abbr': 'VIAF'}},
#     {'collection': {'name': 'Gemeinsame Normdatei (GND) im Katalog der Deutschen Nationalbibliothek',
#       'icon': 'https://www.dnb.de/SiteGlobals/Frontend/DNBWeb/Images/favicon.png?__blob=normal&v=4',
#       'publisher': 'Deutsche Nationalbibliothek',
#       'id': 'http://www.wikidata.org/entity/Q36578',
#       'abbr': 'DNB'},
#      'id': 'https://d-nb.info/gnd/4290358-0/about'}]},
#   {'geographicAreaCode': [{'id': 'https://d-nb.info/standards/vocab/gnd/geographic-area-code#XA-AT-6',
#      'label': 'Österreich'}],
#    'deprecatedUri': ['https://d-nb.info/gnd/408676-4'],
#    'describedBy': {'license': {'id': 'http://creativecommons.org/publicdomain/zero/1.0/',
#      'label': 'http://creativecommons.org/publicdomain/zero/1.0/'},
#     'dateModified': '2013-09-25T05:02:49.000',
#     'id': 'https://d-nb.info/gnd/4325211-4/about'},
#    'gndIdentifier': '4325211-4',
#    'id': 'https://d-nb.info/gnd/4325211-4',
#    'preferredName': 'Graz-Jakomini',
#    'type': ['AuthorityResource',
#     'PlaceOrGeographicName',
#     'TerritorialCorporateBodyOrAdministrativeUnit'],
#    'variantName': ['Graz / Bezirk (6)', 'Jakomini'],
#    '@context': 'http://lobid.org/gnd/context.jsonld',
#    'oldAuthorityNumber': ['(DE-588c)4325211-4',
#     '(DE-588b)408676-4',
#     '(DE-588)408676-4'],
#    'sameAs': [{'id': 'http://viaf.org/viaf/236518932',
#      'collection': {'icon': 'http://viaf.org/viaf/images/viaf.ico',
#       'name': 'Virtual International Authority File (VIAF)',
#       'publisher': 'OCLC',
#       'id': 'http://www.wikidata.org/entity/Q54919',
#       'abbr': 'VIAF'}},
#     {'id': 'https://d-nb.info/gnd/408676-4',
#      'collection': {'icon': 'http://www.dnb.de/SiteGlobals/StyleBundles/Bilder/favicon.png?__blob=normal&v=1',
#       'name': 'Gemeinsame Normdatei (GND) im Katalog der Deutschen Nationalbibliothek',
#       'publisher': 'Deutsche Nationalbibliothek',
#       'id': 'http://www.wikidata.org/entity/Q36578',
#       'abbr': 'DNB'}},
#     {'collection': {'name': 'Gemeinsame Normdatei (GND) im Katalog der Deutschen Nationalbibliothek',
#       'icon': 'https://www.dnb.de/SiteGlobals/Frontend/DNBWeb/Images/favicon.png?__blob=normal&v=4',
#       'publisher': 'Deutsche Nationalbibliothek',
#       'id': 'http://www.wikidata.org/entity/Q36578',
#       'abbr': 'DNB'},
#      'id': 'https://d-nb.info/gnd/4325211-4/about'}]},
#   {'geographicAreaCode': [{'id': 'https://d-nb.info/standards/vocab/gnd/geographic-area-code#XA-AT-6',
#      'label': 'Österreich'}],
#    'deprecatedUri': ['https://d-nb.info/gnd/411208-8'],
#    'describedBy': {'license': {'id': 'http://creativecommons.org/publicdomain/zero/1.0/',
#      'label': 'http://creativecommons.org/publicdomain/zero/1.0/'},
#     'dateModified': '2020-02-21T05:36:39.000',
#     'id': 'https://d-nb.info/gnd/4464011-0/about'},
#    'gndIdentifier': '4464011-0',
#    'id': 'https://d-nb.info/gnd/4464011-0',
#    'preferredName': 'Graz-Geidorf',
#    'type': ['TerritorialCorporateBodyOrAdministrativeUnit',
#     'AuthorityResource',
#     'PlaceOrGeographicName'],
#    'variantName': ['Geidorf', 'Graz / Bezirk (3)'],
#    '@context': 'http://lobid.org/gnd/context.jsonld',
#    'oldAuthorityNumber': ['(DE-588b)411208-8',
#     '(DE-588c)4464011-0',
#     '(DE-588)411208-8'],
#    'sameAs': [{'id': 'http://viaf.org/viaf/246272372',
#      'collection': {'icon': 'http://viaf.org/viaf/images/viaf.ico',
#       'name': 'Virtual International Authority File (VIAF)',
#       'publisher': 'OCLC',
#       'id': 'http://www.wikidata.org/entity/Q54919',
#       'abbr': 'VIAF'}},
#     {'id': 'https://d-nb.info/gnd/411208-8',
#      'collection': {'icon': 'http://www.dnb.de/SiteGlobals/StyleBundles/Bilder/favicon.png?__blob=normal&v=1',
#       'name': 'Gemeinsame Normdatei (GND) im Katalog der Deutschen Nationalbibliothek',
#       'publisher': 'Deutsche Nationalbibliothek',
#       'id': 'http://www.wikidata.org/entity/Q36578',
#       'abbr': 'DNB'}},
#     {'collection': {'name': 'Gemeinsame Normdatei (GND) im Katalog der Deutschen Nationalbibliothek',
#       'icon': 'https://www.dnb.de/SiteGlobals/Frontend/DNBWeb/Images/favicon.png?__blob=normal&v=4',
#       'publisher': 'Deutsche Nationalbibliothek',
#       'id': 'http://www.wikidata.org/entity/Q36578',
#       'abbr': 'DNB'},
#      'id': 'https://d-nb.info/gnd/4464011-0/about'}]},
#   {'geographicAreaCode': [{'id': 'https://d-nb.info/standards/vocab/gnd/geographic-area-code#XA-AT-6',
#      'label': 'Österreich'}],
#    'deprecatedUri': ['https://d-nb.info/gnd/10035005-7'],
#    'describedBy': {'license': {'id': 'http://creativecommons.org/publicdomain/zero/1.0/',
#      'label': 'http://creativecommons.org/publicdomain/zero/1.0/'},
#     'dateModified': '2018-02-01T06:46:25.000',
#     'id': 'https://d-nb.info/gnd/4438909-7/about'},
#    'gndIdentifier': '4438909-7',
#    'id': 'https://d-nb.info/gnd/4438909-7',
#    'preferredName': 'Graz-Andritz',
#    'type': ['PlaceOrGeographicName',
#     'TerritorialCorporateBodyOrAdministrativeUnit',
#     'AuthorityResource'],
#    'variantName': ['Andritz', 'Graz / Bezirk (12)'],
#    '@context': 'http://lobid.org/gnd/context.jsonld',
#    'oldAuthorityNumber': ['(DE-588)10035005-7',
#     '(DE-588c)4438909-7',
#     '(DE-588b)10035005-7'],
#    'sameAs': [{'id': 'http://viaf.org/viaf/235208560',
#      'collection': {'icon': 'http://viaf.org/viaf/images/viaf.ico',
#       'name': 'Virtual International Authority File (VIAF)',
#       'publisher': 'OCLC',
#       'id': 'http://www.wikidata.org/entity/Q54919',
#       'abbr': 'VIAF'}},
#     {'id': 'https://d-nb.info/gnd/10035005-7',
#      'collection': {'icon': 'http://www.dnb.de/SiteGlobals/StyleBundles/Bilder/favicon.png?__blob=normal&v=1',
#       'name': 'Gemeinsame Normdatei (GND) im Katalog der Deutschen Nationalbibliothek',
#       'publisher': 'Deutsche Nationalbibliothek',
#       'id': 'http://www.wikidata.org/entity/Q36578',
#       'abbr': 'DNB'}},
#     {'collection': {'name': 'Gemeinsame Normdatei (GND) im Katalog der Deutschen Nationalbibliothek',
#       'icon': 'https://www.dnb.de/SiteGlobals/Frontend/DNBWeb/Images/favicon.png?__blob=normal&v=4',
#       'publisher': 'Deutsche Nationalbibliothek',
#       'id': 'http://www.wikidata.org/entity/Q36578',
#       'abbr': 'DNB'},
#      'id': 'https://d-nb.info/gnd/4438909-7/about'}]},
#   {'geographicAreaCode': [{'id': 'https://d-nb.info/standards/vocab/gnd/geographic-area-code#XA-AT-6',
#      'label': 'Österreich'}],
#    'succeedingPlaceOrGeographicName': [{'id': 'https://d-nb.info/gnd/4288429-9',
#      'label': 'Graz-Ries'}],
#    'describedBy': {'license': {'id': 'http://creativecommons.org/publicdomain/zero/1.0/',
#      'label': 'http://creativecommons.org/publicdomain/zero/1.0/'},
#     'dateModified': '2019-01-24T08:13:34.000',
#     'id': 'https://d-nb.info/gnd/4290717-2/about'},
#    'gndIdentifier': '4290717-2',
#    'id': 'https://d-nb.info/gnd/4290717-2',
#    'preferredName': 'Ries (Graz)',
#    'type': ['TerritorialCorporateBodyOrAdministrativeUnit',
#     'PlaceOrGeographicName',
#     'AuthorityResource'],
#    '@context': 'http://lobid.org/gnd/context.jsonld',
#    'oldAuthorityNumber': ['(DE-588c)4290717-2'],
#    'sameAs': [{'id': 'http://viaf.org/viaf/235617030',
#      'collection': {'icon': 'http://viaf.org/viaf/images/viaf.ico',
#       'name': 'Virtual International Authority File (VIAF)',
#       'publisher': 'OCLC',
#       'id': 'http://www.wikidata.org/entity/Q54919',
#       'abbr': 'VIAF'}},
#     {'collection': {'name': 'Gemeinsame Normdatei (GND) im Katalog der Deutschen Nationalbibliothek',
#       'icon': 'https://www.dnb.de/SiteGlobals/Frontend/DNBWeb/Images/favicon.png?__blob=normal&v=4',
#       'publisher': 'Deutsche Nationalbibliothek',
#       'id': 'http://www.wikidata.org/entity/Q36578',
#       'abbr': 'DNB'},
#      'id': 'https://d-nb.info/gnd/4290717-2/about'}]},
#   {'type': ['TerritorialCorporateBodyOrAdministrativeUnit',
#     'AuthorityResource',
#     'PlaceOrGeographicName'],
#    '@context': 'http://lobid.org/gnd/context.jsonld',
#    'oldAuthorityNumber': ['(DE-588b)2146671-3',
#     '(DE-588)2146671-3',
#     '(DE-588c)4093912-1'],
#    'geographicAreaCode': [{'id': 'https://d-nb.info/standards/vocab/gnd/geographic-area-code#XA-AT-6',
#      'label': 'Österreich'}],
#    'hasGeometry': [{'asWKT': ['Point ( +015.400000 +047.083329 )'],
#      'type': 'Point'}],
#    'deprecatedUri': ['https://d-nb.info/gnd/2146671-3'],
#    'describedBy': {'license': {'id': 'http://creativecommons.org/publicdomain/zero/1.0/',
#      'label': 'http://creativecommons.org/publicdomain/zero/1.0/'},
#     'dateModified': '2021-07-31T23:44:11.000',
#     'id': 'https://d-nb.info/gnd/4093912-1/about'},
#    'definition': ['Stadtbezirk von Graz, 1850 gebildet, 1906 Markt, 1938 eingemeindet'],
#    'gndIdentifier': '4093912-1',
#    'id': 'https://d-nb.info/gnd/4093912-1',
#    'preferredName': 'Graz-Eggenberg',
#    'variantName': ['Eggenberg (Graz)', 'Graz / Bezirk (14)'],
#    'hierarchicalSuperiorOfPlaceOrGeographicName': [{'id': 'https://d-nb.info/gnd/4021912-4',
#      'label': 'Graz'}],
#    'sameAs': [{'id': 'http://viaf.org/viaf/244562889',
#      'collection': {'icon': 'http://viaf.org/viaf/images/viaf.ico',
#       'name': 'Virtual International Authority File (VIAF)',
#       'publisher': 'OCLC',
#       'id': 'http://www.wikidata.org/entity/Q54919',
#       'abbr': 'VIAF'}},
#     {'id': 'http://www.wikidata.org/entity/Q1297479',
#      'collection': {'icon': 'https://www.wikidata.org/static/favicon/wikidata.ico',
#       'name': 'Wikidata',
#       'publisher': 'Wikimedia Foundation Inc.',
#       'id': 'http://www.wikidata.org/entity/Q2013',
#       'abbr': 'WIKIDATA'}},
#     {'id': 'https://d-nb.info/gnd/2146671-3',
#      'collection': {'icon': 'http://www.dnb.de/SiteGlobals/StyleBundles/Bilder/favicon.png?__blob=normal&v=1',
#       'name': 'Gemeinsame Normdatei (GND) im Katalog der Deutschen Nationalbibliothek',
#       'publisher': 'Deutsche Nationalbibliothek',
#       'id': 'http://www.wikidata.org/entity/Q36578',
#       'abbr': 'DNB'}},
#     {'collection': {'name': 'Gemeinsame Normdatei (GND) im Katalog der Deutschen Nationalbibliothek',
#       'icon': 'https://www.dnb.de/SiteGlobals/Frontend/DNBWeb/Images/favicon.png?__blob=normal&v=4',
#       'publisher': 'Deutsche Nationalbibliothek',
#       'id': 'http://www.wikidata.org/entity/Q36578',
#       'abbr': 'DNB'},
#      'id': 'https://d-nb.info/gnd/4093912-1/about'},
#     {'id': 'https://sws.geonames.org/2780361',
#      'collection': {'id': 'https://sws.geonames.org'}}],
#    'depiction': [{'thumbnail': 'https://commons.wikimedia.org/wiki/Special:FilePath/Graz%20Schloss%20Eggenberg%20Seitansicht.jpg?width=270',
#      'id': 'http://commons.wikimedia.org/wiki/Special:FilePath/Graz%20Schloss%20Eggenberg%20Seitansicht.jpg',
#      'url': 'https://commons.wikimedia.org/wiki/File:Graz%20Schloss%20Eggenberg%20Seitansicht.jpg?uselang=de'}]},
#   {'geographicAreaCode': [{'id': 'https://d-nb.info/standards/vocab/gnd/geographic-area-code#XA-AT-6',
#      'label': 'Österreich'}],
#    'precedingPlaceOrGeographicName': [{'id': 'https://d-nb.info/gnd/4290717-2',
#      'label': 'Ries (Graz)'}],
#    'describedBy': {'license': {'id': 'http://creativecommons.org/publicdomain/zero/1.0/',
#      'label': 'http://creativecommons.org/publicdomain/zero/1.0/'},
#     'dateModified': '2016-02-04T11:59:51.000',
#     'id': 'https://d-nb.info/gnd/4288429-9/about'},
#    'definition': ['d. heutige Bezirk Ries war bis 1939 Teil der Gmde. Kainbach'],
#    'gndIdentifier': '4288429-9',
#    'id': 'https://d-nb.info/gnd/4288429-9',
#    'preferredName': 'Graz-Ries',
#    'type': ['AuthorityResource',
#     'PlaceOrGeographicName',
#     'TerritorialCorporateBodyOrAdministrativeUnit'],
#    'variantName': ['Graz / Bezirk (10)'],
#    '@context': 'http://lobid.org/gnd/context.jsonld',
#    'oldAuthorityNumber': ['(DE-588c)4288429-9'],
#    'sameAs': [{'id': 'http://viaf.org/viaf/244209563',
#      'collection': {'icon': 'http://viaf.org/viaf/images/viaf.ico',
#       'name': 'Virtual International Authority File (VIAF)',
#       'publisher': 'OCLC',
#       'id': 'http://www.wikidata.org/entity/Q54919',
#       'abbr': 'VIAF'}},
#     {'collection': {'name': 'Gemeinsame Normdatei (GND) im Katalog der Deutschen Nationalbibliothek',
#       'icon': 'https://www.dnb.de/SiteGlobals/Frontend/DNBWeb/Images/favicon.png?__blob=normal&v=4',
#       'publisher': 'Deutsche Nationalbibliothek',
#       'id': 'http://www.wikidata.org/entity/Q36578',
#       'abbr': 'DNB'},
#      'id': 'https://d-nb.info/gnd/4288429-9/about'}]},
#   {'type': ['AuthorityResource',
#     'TerritorialCorporateBodyOrAdministrativeUnit',
#     'PlaceOrGeographicName'],
#    '@context': 'http://lobid.org/gnd/context.jsonld',
#    'oldAuthorityNumber': ['(DE-588c)4438908-5',
#     '(DE-588)10136052-6',
#     '(DE-588b)10136052-6'],
#    'geographicAreaCode': [{'id': 'https://d-nb.info/standards/vocab/gnd/geographic-area-code#XA-AT-6',
#      'label': 'Österreich'}],
#    'deprecatedUri': ['https://d-nb.info/gnd/10136052-6'],
#    'dateOfEstablishment': ['1988'],
#    'describedBy': {'license': {'id': 'http://creativecommons.org/publicdomain/zero/1.0/',
#      'label': 'http://creativecommons.org/publicdomain/zero/1.0/'},
#     'dateModified': '2016-05-25T06:00:54.000',
#     'id': 'https://d-nb.info/gnd/4438908-5/about'},
#    'definition': ['War bis 1988 Teil des 16. Bezirks.'],
#    'gndIdentifier': '4438908-5',
#    'id': 'https://d-nb.info/gnd/4438908-5',
#    'preferredName': 'Graz-Puntigam',
#    'variantName': ['Graz / Bezirk (17)', 'Puntigam'],
#    'sameAs': [{'id': 'http://viaf.org/viaf/234762890',
#      'collection': {'icon': 'http://viaf.org/viaf/images/viaf.ico',
#       'name': 'Virtual International Authority File (VIAF)',
#       'publisher': 'OCLC',
#       'id': 'http://www.wikidata.org/entity/Q54919',
#       'abbr': 'VIAF'}},
#     {'id': 'https://d-nb.info/gnd/10136052-6',
#      'collection': {'icon': 'http://www.dnb.de/SiteGlobals/StyleBundles/Bilder/favicon.png?__blob=normal&v=1',
#       'name': 'Gemeinsame Normdatei (GND) im Katalog der Deutschen Nationalbibliothek',
#       'publisher': 'Deutsche Nationalbibliothek',
#       'id': 'http://www.wikidata.org/entity/Q36578',
#       'abbr': 'DNB'}},
#     {'collection': {'name': 'Gemeinsame Normdatei (GND) im Katalog der Deutschen Nationalbibliothek',
#       'icon': 'https://www.dnb.de/SiteGlobals/Frontend/DNBWeb/Images/favicon.png?__blob=normal&v=4',
#       'publisher': 'Deutsche Nationalbibliothek',
#       'id': 'http://www.wikidata.org/entity/Q36578',
#       'abbr': 'DNB'},
#      'id': 'https://d-nb.info/gnd/4438908-5/about'}]},
#   {'type': ['AdministrativeUnit',
#     'AuthorityResource',
#     'PlaceOrGeographicName',
#     'TerritorialCorporateBodyOrAdministrativeUnit'],
#    '@context': 'http://lobid.org/gnd/context.jsonld',
#    'oldAuthorityNumber': ['(DE-588c)4799137-9',
#     '(DE-588b)10133346-8',
#     '(DE-588)10133346-8'],
#    'geographicAreaCode': [{'id': 'https://d-nb.info/standards/vocab/gnd/geographic-area-code#XA-AT-6',
#      'label': 'Österreich'}],
#    'deprecatedUri': ['https://d-nb.info/gnd/10133346-8'],
#    'relatedDdcWithDegreeOfDeterminacy4': [{'id': 'http://dewey.info/class/2--436542/',
#      'label': 'http://dewey.info/class/2--436542/'}],
#    'describedBy': {'license': {'id': 'http://creativecommons.org/publicdomain/zero/1.0/',
#      'label': 'http://creativecommons.org/publicdomain/zero/1.0/'},
#     'dateModified': '2016-02-04T11:56:23.000',
#     'id': 'https://d-nb.info/gnd/4799137-9/about'},
#    'gndIdentifier': '4799137-9',
#    'id': 'https://d-nb.info/gnd/4799137-9',
#    'preferredName': 'Graz-Umgebung',
#    'wikipedia': [{'id': 'https://de.wikipedia.org/wiki/Bezirk_Graz-Umgebung',
#      'label': 'https://de.wikipedia.org/wiki/Bezirk_Graz-Umgebung'}],
#    'variantName': ['Bezirk Graz',
#     'Graz-Umgebung / Bezirkshauptmannschaft',
#     'Bezirkshauptmannschaft (Graz-Umgebung)',
#     'Politischer Bezirk Graz-Umgebung'],
#    'homepage': [{'id': 'http://www.bh-grazumgebung.steiermark.at',
#      'label': 'http://www.bh-grazumgebung.steiermark.at'}],
#    'sameAs': [{'id': 'http://id.loc.gov/rwo/agents/n88080960',
#      'collection': {'icon': 'http://www.loc.gov/favicon.ico',
#       'name': 'NACO Authority File',
#       'publisher': 'Library of Congress',
#       'id': 'http://www.wikidata.org/entity/Q13219454',
#       'abbr': 'LC'}},
#     {'id': 'http://viaf.org/viaf/123257326',
#      'collection': {'icon': 'http://viaf.org/viaf/images/viaf.ico',
#       'name': 'Virtual International Authority File (VIAF)',
#       'publisher': 'OCLC',
#       'id': 'http://www.wikidata.org/entity/Q54919',
#       'abbr': 'VIAF'}},
#     {'id': 'http://www.wikidata.org/entity/Q672475',
#      'collection': {'icon': 'https://www.wikidata.org/static/favicon/wikidata.ico',
#       'name': 'Wikidata',
#       'publisher': 'Wikimedia Foundation Inc.',
#       'id': 'http://www.wikidata.org/entity/Q2013',
#       'abbr': 'WIKIDATA'}},
#     {'id': 'https://d-nb.info/gnd/10133346-8',
#      'collection': {'icon': 'http://www.dnb.de/SiteGlobals/StyleBundles/Bilder/favicon.png?__blob=normal&v=1',
#       'name': 'Gemeinsame Normdatei (GND) im Katalog der Deutschen Nationalbibliothek',
#       'publisher': 'Deutsche Nationalbibliothek',
#       'id': 'http://www.wikidata.org/entity/Q36578',
#       'abbr': 'DNB'}},
#     {'collection': {'name': 'Gemeinsame Normdatei (GND) im Katalog der Deutschen Nationalbibliothek',
#       'icon': 'https://www.dnb.de/SiteGlobals/Frontend/DNBWeb/Images/favicon.png?__blob=normal&v=4',
#       'publisher': 'Deutsche Nationalbibliothek',
#       'id': 'http://www.wikidata.org/entity/Q36578',
#       'abbr': 'DNB'},
#      'id': 'https://d-nb.info/gnd/4799137-9/about'},
#     {'collection': {'name': 'Wikipedia (Deutsch)',
#       'icon': 'https://de.wikipedia.org/static/favicon/wikipedia.ico',
#       'publisher': 'Wikimedia Foundation Inc.',
#       'id': 'http://www.wikidata.org/entity/Q48183',
#       'abbr': 'dewiki'},
#      'id': 'https://de.wikipedia.org/wiki/Bezirk_Graz-Umgebung'},
#     {'collection': {'name': 'Wikipedia (English)',
#       'icon': 'https://en.wikipedia.org/static/favicon/wikipedia.ico',
#       'publisher': 'Wikimedia Foundation Inc.',
#       'id': 'http://www.wikidata.org/entity/Q328',
#       'abbr': 'enwiki'},
#      'id': 'https://en.wikipedia.org/wiki/Graz-Umgebung_District'}]}],
#  'aggregation': {'gndSubjectCategory.id': [],
#   'professionOrOccupation.id': [],
#   'geographicAreaCode.id': [{'key': 'https://d-nb.info/standards/vocab/gnd/geographic-area-code#XA-AT-6',
#     'doc_count': 35},
#    {'key': 'https://d-nb.info/standards/vocab/gnd/geographic-area-code#XA-AT',
#     'doc_count': 3}],
#   'dateOfBirth': [],
#   'type': [{'key': 'PlaceOrGeographicName', 'doc_count': 38},
#    {'key': 'TerritorialCorporateBodyOrAdministrativeUnit', 'doc_count': 38},
#    {'key': 'AdministrativeUnit', 'doc_count': 2}]}}

# %%
res_dict = res.json()
res_df = pd.json_normalize(res_dict['member'])

# %%
res_df[['@context', 'preferredName', 'describedBy.id', 'biographicalOrHistoricalInformation']]
# Out:
#                               @context      preferredName                         describedBy.id  \
# 0  http://lobid.org/gnd/context.jsonld               Graz  https://d-nb.info/gnd/4021912-4/about
# 1  http://lobid.org/gnd/context.jsonld  Waltendorf (Graz)  https://d-nb.info/gnd/4290358-0/about
# 2  http://lobid.org/gnd/context.jsonld      Graz-Jakomini  https://d-nb.info/gnd/4325211-4/about
# 3  http://lobid.org/gnd/context.jsonld       Graz-Geidorf  https://d-nb.info/gnd/4464011-0/about
# 4  http://lobid.org/gnd/context.jsonld       Graz-Andritz  https://d-nb.info/gnd/4438909-7/about
# 5  http://lobid.org/gnd/context.jsonld        Ries (Graz)  https://d-nb.info/gnd/4290717-2/about
# 6  http://lobid.org/gnd/context.jsonld     Graz-Eggenberg  https://d-nb.info/gnd/4093912-1/about
# 7  http://lobid.org/gnd/context.jsonld          Graz-Ries  https://d-nb.info/gnd/4288429-9/about
# 8  http://lobid.org/gnd/context.jsonld      Graz-Puntigam  https://d-nb.info/gnd/4438908-5/about
# 9  http://lobid.org/gnd/context.jsonld      Graz-Umgebung  https://d-nb.info/gnd/4799137-9/about
#
#                                              biographicalOrHistoricalInformation
# 0  [Hauptstadt der Steiermark, 1128/29 urkundl. erwähnt, 1172 Markt, 1189 Stadt]
# 1                                                                            NaN
# 2                                                                            NaN
# 3                                                                            NaN
# 4                                                                            NaN
# 5                                                                            NaN
# 6                                                                            NaN
# 7                                                                            NaN
# 8                                                                            NaN
# 9                                                                            NaN

# %%
res_df[['sameAs', 'preferredName']]
# Out:
#                                                                             sameAs  \
# 0  [{'id': 'http://id.loc.gov/rwo/agents/n79064653', 'collection': {'icon': 'ht...
# 1  [{'id': 'http://viaf.org/viaf/233818018', 'collection': {'icon': 'http://via...
# 2  [{'id': 'http://viaf.org/viaf/236518932', 'collection': {'icon': 'http://via...
# 3  [{'id': 'http://viaf.org/viaf/246272372', 'collection': {'icon': 'http://via...
# 4  [{'id': 'http://viaf.org/viaf/235208560', 'collection': {'icon': 'http://via...
# 5  [{'id': 'http://viaf.org/viaf/235617030', 'collection': {'icon': 'http://via...
# 6  [{'id': 'http://viaf.org/viaf/244562889', 'collection': {'icon': 'http://via...
# 7  [{'id': 'http://viaf.org/viaf/244209563', 'collection': {'icon': 'http://via...
# 8  [{'id': 'http://viaf.org/viaf/234762890', 'collection': {'icon': 'http://via...
# 9  [{'id': 'http://id.loc.gov/rwo/agents/n88080960', 'collection': {'icon': 'ht...
#
#        preferredName
# 0               Graz
# 1  Waltendorf (Graz)
# 2      Graz-Jakomini
# 3       Graz-Geidorf
# 4       Graz-Andritz
# 5        Ries (Graz)
# 6     Graz-Eggenberg
# 7          Graz-Ries
# 8      Graz-Puntigam
# 9      Graz-Umgebung

# %% [markdown]
# # Researchspace/Metaphacts
# * CMS based on triplestore
# * out of the box RDF navigation and viewing
# * allows to use SPARQL directly in HTML templates
# * webpack components for visualization of SPARQL results

# %%
from SPARQLWrapper import SPARQLWrapper, POST, BASIC

# %%
sparql = SPARQLWrapper("https://triplestore.acdh-dev.oeaw.ac.at/summer2020/sparql")

sparql.setHTTPAuth(BASIC)
sparql.setCredentials("", "")
sparql.setMethod(POST)

# %%
sparql.setQuery("""
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX crm: <http://www.cidoc-crm.org/cidoc-crm/>
PREFIX frbroo: <http://iflastandards.info/ns/fr/frbr/frbroo#>
PREFIX bds: <http://www.bigdata.com/rdf/search#>
SELECT ?name ?sub ?prof_val WHERE {
  # ?sub a crm:E21_Person ;
    rdfs:label ?name ;
        crm:P14i_performed ?prof .
  # ?prof rdf:value ?prof_val .
  FILTER CONTAINS(str(?prof), "Architekt")
}

LIMIT 100
""")
sparql.setReturnFormat(JSON)
results = sparql.query().convert()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.9/site-packages/SPARQLWrapper/Wrapper.py in _query(self)
#    1072             else:
# -> 1073                 response = urlopener(request)
#    1074             return response, self.returnFormat
#
# /usr/local/Cellar/python@3.9/3.9.10/Frameworks/Python.framework/Versions/3.9/lib/python3.9/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     213         opener = _opener
# --> 214     return opener.open(url, data, timeout)
#     215
#
# /usr/local/Cellar/python@3.9/3.9.10/Frameworks/Python.framework/Versions/3.9/lib/python3.9/urllib/request.py in open(self, fullurl, data, timeout)
#     522             meth = getattr(processor, meth_name)
# --> 523             response = meth(req, response)
#     524
#
# /usr/local/Cellar/python@3.9/3.9.10/Frameworks/Python.framework/Versions/3.9/lib/python3.9/urllib/request.py in http_response(self, request, response)
#     631         if not (200 <= code < 300):
# --> 632             response = self.parent.error(
#     633                 'http', request, response, code, msg, hdrs)
#
# /usr/local/Cellar/python@3.9/3.9.10/Frameworks/Python.framework/Versions/3.9/lib/python3.9/urllib/request.py in error(self, proto, *args)
#     560             args = (dict, 'default', 'http_error_default') + orig_args
# --> 561             return self._call_chain(*args)
#     562
#
# /usr/local/Cellar/python@3.9/3.9.10/Frameworks/Python.framework/Versions/3.9/lib/python3.9/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     493             func = getattr(handler, meth_name)
# --> 494             result = func(*args)
#     495             if result is not None:
#
# /usr/local/Cellar/python@3.9/3.9.10/Frameworks/Python.framework/Versions/3.9/lib/python3.9/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     640     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 641         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     642
#
# HTTPError: HTTP Error 401: Unauthorized
#
# During handling of the above exception, another exception occurred:
#
# Unauthorized                              Traceback (most recent call last)
# /var/folders/sd/1vc_q83x5rn9jjrd0x47_cc00000gn/T/ipykernel_40522/2928772523.py in <module>
#      16 """)
#      17 sparql.setReturnFormat(JSON)
# ---> 18 results = sparql.query().convert()
#
# /usr/local/lib/python3.9/site-packages/SPARQLWrapper/Wrapper.py in query(self)
#    1105             :rtype: :class:`QueryResult` instance
#    1106         """
# -> 1107         return QueryResult(self._query())
#    1108
#    1109     def queryAndConvert(self):
#
# /usr/local/lib/python3.9/site-packages/SPARQLWrapper/Wrapper.py in _query(self)
#    1079                 raise EndPointNotFound(e.read())
#    1080             elif e.code == 401:
# -> 1081                 raise Unauthorized(e.read())
#    1082             elif e.code == 414:
#    1083                 raise URITooLong(e.read())
#
# Unauthorized: Unauthorized: access is denied due to invalid credentials (unauthorized). Check the credentials.

# %%
results_df = pd.json_normalize(results['results']['bindings'])
results_df
# Out:
#   country.type                          country.value                       population.datatype  \
# 0          uri  http://www.wikidata.org/entity/Q43325  http://www.w3.org/2001/XMLSchema#decimal
# 1          uri  http://www.wikidata.org/entity/Q41967  http://www.w3.org/2001/XMLSchema#decimal
# 2          uri  http://www.wikidata.org/entity/Q43210  http://www.w3.org/2001/XMLSchema#decimal
# 3          uri  http://www.wikidata.org/entity/Q41358  http://www.w3.org/2001/XMLSchema#decimal
# 4          uri  http://www.wikidata.org/entity/Q42497  http://www.w3.org/2001/XMLSchema#decimal
# 5          uri  http://www.wikidata.org/entity/Q42880  http://www.w3.org/2001/XMLSchema#decimal
# 6          uri  http://www.wikidata.org/entity/Q38981  http://www.w3.org/2001/XMLSchema#decimal
# 7          uri  http://www.wikidata.org/entity/Q37985  http://www.w3.org/2001/XMLSchema#decimal
# 8          uri   http://www.wikidata.org/entity/Q1741  http://www.w3.org/2001/XMLSchema#decimal
#
#   population.type population.value gnd.type  gnd.value  \
# 0         literal           558410  literal  4051423-7
# 1         literal          1490279  literal  4075560-5
# 2         literal           294436  literal  4009114-4
# 3         literal          1246395  literal  4057092-7
# 4         literal          1684287  literal  4075391-8
# 5         literal           757634      NaN        NaN
# 6         literal           397139  literal  4063944-7
# 7         literal           561293  literal  4029175-3
# 8         literal          1911191  literal  4066009-6
#
#                                  lat_long.datatype lat_long.type  \
# 0  http://www.opengis.net/ont/geosparql#wktLiteral       literal
# 1  http://www.opengis.net/ont/geosparql#wktLiteral       literal
# 2  http://www.opengis.net/ont/geosparql#wktLiteral       literal
# 3  http://www.opengis.net/ont/geosparql#wktLiteral       literal
# 4  http://www.opengis.net/ont/geosparql#wktLiteral       literal
# 5  http://www.opengis.net/ont/geosparql#wktLiteral       literal
# 6  http://www.opengis.net/ont/geosparql#wktLiteral       literal
# 7  http://www.opengis.net/ont/geosparql#wktLiteral       literal
# 8  http://www.opengis.net/ont/geosparql#wktLiteral       literal
#
#                      lat_long.value  ... countryLabel.type countryLabel.value capital.type  \
# 0  Point(13.364166666 47.766944444)  ...           literal           Salzburg          uri
# 1                  Point(14.0 48.2)  ...           literal      Upper Austria          uri
# 2          Point(16.416666666 47.5)  ...           literal         Burgenland          uri
# 3         Point(15.166666666 47.25)  ...           literal             Styria          uri
# 4         Point(15.75 48.333333333)  ...           literal      Lower Austria          uri
# 5          Point(11.4 47.266666666)  ...           literal              Tyrol          uri
# 6   Point(9.893888888 47.243611111)  ...           literal         Vorarlberg          uri
# 7            Point(13.8617 46.7525)  ...           literal          Carinthia          uri
# 8       Point(16.3725 48.208333333)  ...           literal             Vienna          NaN
#
#                             capital.value                populationCapital.datatype  \
# 0   http://www.wikidata.org/entity/Q34713  http://www.w3.org/2001/XMLSchema#decimal
# 1   http://www.wikidata.org/entity/Q41329  http://www.w3.org/2001/XMLSchema#decimal
# 2  http://www.wikidata.org/entity/Q126321  http://www.w3.org/2001/XMLSchema#decimal
# 3   http://www.wikidata.org/entity/Q13298  http://www.w3.org/2001/XMLSchema#decimal
# 4   http://www.wikidata.org/entity/Q82500  http://www.w3.org/2001/XMLSchema#decimal
# 5    http://www.wikidata.org/entity/Q1735  http://www.w3.org/2001/XMLSchema#decimal
# 6    http://www.wikidata.org/entity/Q1737  http://www.w3.org/2001/XMLSchema#decimal
# 7   http://www.wikidata.org/entity/Q41753  http://www.w3.org/2001/XMLSchema#decimal
# 8                                     NaN                                       NaN
#
#   populationCapital.type populationCapital.value capitalLabel.xml:lang capitalLabel.type  \
# 0                literal                  155021                    en           literal
# 1                literal                  204846                    en           literal
# 2                literal                   14476                    en           literal
# 3                literal                  289440                    en           literal
# 4                literal                   55514                    en           literal
# 5                literal                  132493                    en           literal
# 6                literal                   29806                    en           literal
# 7                literal                  101403                    en           literal
# 8                    NaN                     NaN                   NaN               NaN
#
#   capitalLabel.value
# 0           Salzburg
# 1               Linz
# 2         Eisenstadt
# 3               Graz
# 4         St. Pölten
# 5          Innsbruck
# 6            Bregenz
# 7         Klagenfurt
# 8                NaN
#
# [9 rows x 21 columns]
