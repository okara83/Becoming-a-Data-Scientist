# %% [markdown]
# <font size="4" style="color:red;"> **IMPORTANT: ** When submitting this homework notebook, please modify only the cells that start with:</font>
#
# ```python
# # modify this cell
# ```
#
# <font style="color:red;"> Do not add any new cells. To test out new code, use the coding **scratchpad** by clicking the triangular icon in the bottom right corner of the screen. (**hotkey:** control-B)  </font>

# %% [markdown]
# # Sets: The Inclusion-Exclusion Principle
# [Read this notebook](http://70.95.166.175:8888/notebooks/SAFETY/probability-and-statistics-using-python/notebooks/Week%209-%20RegressionPCA/1.Linear%20Algebra%20Review.ipynb)
# before attempting exercises in this section.

# %% [markdown]
# ## Problem 1

# %% [markdown]
# The inclusion-exclusion principle states that for two sets $A$ and $B$,
#
# $$|A\cup B|=|A|+|B|-|A\cap B|.$$
#
# Write the following functions to determine $|A\cup B|$ in two different ways.
#
# **a.** A function **union** that determines first $A\cup B$ and then evaluates the union's size.
# Output the ordered pair $(A\cup B, |A\cup B|)$.
#
# <font  style="color:blue"> * **Sample run:** *</font>
# ```python
# A = {1, 2, 3}
# B = {3, -6, 2, 0}
# print union(A, B)
# ```
#
# <font  style="color:magenta"> * **Expected Output:** *</font>
# ```
# ({-6, 0, 1, 2, 3}, 5)
# ```
# ** Question: Should we give an example where A=B={} and the output is {}? **
#
# **b.** A function **inclusion_exclusion** that first deterimines $|A|$, $|B|$, $A\cap B$, and $|A\cap B|$, and then uses the inclusion-exclusion formula to determine $|A\cup B|$.
# Output the tuple $(|A|, |B|, |A\cap B|, |A\cup B|)$.
#
# <font  style="color:blue"> * **Sample run:** *</font>
# ```python
# A = {1, 2, 3}
# B = {3, -6, 2, 0}
# print inclusion_exclusion(A, B)
# ```
#
# <font  style="color:magenta"> * **Expected Output:** *</font>
# ```
# (3, 4, 2, 5)
# ```

# %%
# modify this cell

def union(A, B):
    # inputs: A and B are of type 'set'
    # output: a tuple of the type (set, int)
    
    ### BEGIN SOLUTION
    
    ### END SOLUTION

# modify this cell
# Out:
#   File "<ipython-input-1-248e721ec972>", line 11
#     # modify this cell
#                       ^
# SyntaxError: unexpected EOF while parsing

# %%
# Check Function

A = {1, 2, 3, 4, 5}
B = {0, 2, -6, 5, 8, 9}

assert (# please complete this)

### BEGIN HIDDEN TESTS
# please complete this
### END HIDDEN TESTS

# %%
# modify this cell

def inclusion_exclusion(A, B):
    # inputs: A and B are of type 'set'
    # output: a tuple of four integers
    
    ### BEGIN SOLUTION
    
    ### END SOLUTION

# modify this cell

# %%
# Check Function

A = {1, 2, 3, 4, 5}
B = {0, 2, -6, 5, 8, 9}

assert (# please complete this)

### BEGIN HIDDEN TESTS
# please complete this
### END HIDDEN TESTS

# %% [markdown]
# ## Problem 2

# %% [markdown]
# The inclusion-exclusion principle says that for three sets $A$, $B$ and $C$,
#
# $$|A\cup B\cup C|=|A|+|B|+|C|-|A\cap B|-|B\cap C|-|C\cap A|+|A\cap B\cap C|$$
#
# Write the following functions to determine $|A\cup B\cup C|$ in two different ways.
#
# **a.** A function **union3** that first determines $A\cup B\cup C$ and then evaluates the size of this union.
# Output the tuple $(A\cup B\cup C, |A\cup B\cup C|)$.
#
# <font  style="color:blue"> * **Sample run:** *</font>
# ```python
# A = {1, 2, 3, 4, 5}
# B = {0, 2, -6, 5, 8, 9}
# C = {2, 10}
# print union3(A, B, C)
# ```
#
#
# <font  style="color:magenta"> * **Expected Output:** *</font>
# ```
# ({-6, 0, 1, 2, 3, 4, 5, 8, 9, 10}, 10)
# ```
#
# **b.** A function **inclusion_exclusion3** that first deterimines the sizes of $A$, $B$, $C$ and their mutual intersections, and then uses the inclusion-exclusion principle to determine the size of the union. Output the tuple $(|A\cap B\cap C|, |A\cup B\cup C|)$. Note that for brevity we are asking you to output the intermediate answer just for $A\cap B\cap C$, but you need to calculate all.
#
# <font  style="color:blue"> * **Sample run:** *</font>
# ```python
# A = {1, 2, 3, 4, 5}
# B = {0, 2, -6, 5, 8, 9}
# C = {2, 10}
# print inclusion_exclusion3(A, B, C)
# ```
#
#
# <font  style="color:magenta"> * **Expected Output:** *</font>
# ```
# (1, 10)
# ```

# %%
# modify this cell

def error_probability():
    ### BEGIN SOLUTION
    
    ### END SOLUTION

# modify this cell

# %%
# Check Function

assert (# please complete this)

### BEGIN HIDDEN TESTS
# please complete this
### END HIDDEN TESTS

# %%
A = {1, 2, 3, 4, 5}
B = {0, 2, -6, 5, 8, 9}
A.union(B), len(A.union(B))
# Out:
# ({-6, 0, 1, 2, 3, 4, 5, 8, 9}, 9)

# %%
A = {1, 2, 3, 4, 5}
B = {0, 2, -6, 5, 8, 9}
C = {2, 10}
A.union(B).union(C), len(A.union(B).union(C))
# Out:
# ({-6, 0, 1, 2, 3, 4, 5, 8, 9, 10}, 10)

# %%
# modify this cell

def union3(A, B, C):
    # inputs: A, B and C are of type 'set'
    # output: a tuple of the type (set, int)
    
    ### BEGIN SOLUTION
    
    ### END SOLUTION

# modify this cell
# Out:
#   File "<ipython-input-1-d5239f7baeab>", line 11
#     # modify this cell
#                       ^
# SyntaxError: unexpected EOF while parsing

# %%
# Check Function

A = {1, 2, 3, 4, 5}
B = {0, 2, -6, 5, 8, 9}
C = {2, 10}

assert (# please complete this)

### BEGIN HIDDEN TESTS
# please complete this
### END HIDDEN TESTS

# %%
# modify this cell

def inclusion_exclusion3(A, B, C):
    # inputs: A, B and C are of type 'set'
    # output: a tuple of two integers
    
    ### BEGIN SOLUTION
    
    ### END SOLUTION

# modify this cell

# %%
# Check Function

A = {1, 2, 3, 4, 5}
B = {0, 2, -6, 5, 8, 9}
C = {2, 10}

assert (# please complete this)

### BEGIN HIDDEN TESTS
# please complete this
### END HIDDEN TESTS
