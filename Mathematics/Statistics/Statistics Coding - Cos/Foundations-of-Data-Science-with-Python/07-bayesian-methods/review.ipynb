# %% [markdown]
# # Review

# %% [markdown]
# ## Terminology Review
#
# Use the flashcards below to help you review the terminology introduced in this chapter.

# %%
from jupytercards import display_flashcards
github='https://raw.githubusercontent.com/jmshea/Foundations-of-Data-Science-with-Python/main/07-bayesian-methods/flashcards/'

display_flashcards(github+'review.json')
#display_flashcards("flashcards/"+'review.json')
# Out:
# <style>
# :root{
# --asparagus: #87a878ff;
# --terra-cotta: #e26d5aff;
# --cyan-process: #5bc0ebff;
# --dark-blue-gray: #666a86ff;
# --snow: #fffafbff;
# --rich-black-fogra-39: #090c08ff;
# }
#
#
# /* entire container, keeps perspective */
# .flip-container {
# 	perspective: 1000px;
#   touch-action: pinch-zoom pan-y;
# }
#
#
# .flip-container.flip .flipper {
# 	transform: rotateY(180deg)  translateX(-10%);
# }
#
#
# .flip-container.slide .flipper.frontcard {
#     filter: brightness(90%);
#     position:absolute;
#     z-index: -20;
# }
#
# .flip-container.prepare .flipper.backcard {
#     opacity:1;
#     transform:  translateX(20px);
#     transition: display 0s;
# }
#
#
# .flip-container.slide .flipper.backcard {
#     filter: brightness(115%);
#     height: 360px;
#     opacity:1;
# 	  transform:  rotateY(3deg)  translateX(700px) translateZ(20px) scale(1, 1.05) rotate(3deg);
#     z-index: 20;
# }
#
#
#
#
# .flip-container.slideback .flipper.backcard {
# ...

# %% [markdown]
# ## Self Assessment Exercises
#
# Answer the questions below to assess your understanding of the material in this chapter.

# %% [markdown]
# $\mbox{ }$

# %%
from jupyterquiz import display_quiz
github='https://raw.githubusercontent.com/jmshea/Foundations-of-Data-Science-with-Python/main/07-bayesian-methods/quiz/'

print("Review questions to be added later")
# display_quiz('quiz/review.json')
#display_quiz(github+'review.json')
# Out:
# Review questions to be added later
