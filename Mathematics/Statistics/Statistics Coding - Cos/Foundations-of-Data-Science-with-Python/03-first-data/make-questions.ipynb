# %% [markdown]
# # Review

# %% [markdown]
# In this Chapter, we started working with real data, introduced Pands, partitions, summary statistics, binary hypothesis testing via bootstrap resampling, and two-dimensional statistics.

# %%
import sys
sys.path.insert(1, "..")

from quizlet import display_quiz

# %%
questions=[]

# %% [markdown]
# **Self-assessment:**

# %%
question='''Choose all of the following that are useful error metrics that can be minimized to create a summary statistic:'''
answers=[
    {'answer':"sum of squared errors",
     'correct': True,
     'feedback': "Correct."
    },
    {'answer': "sum of absolute errors",
     'correct': True,
     'feedback': "Correct."
    },
    {'answer': "total number of errors",
     'correct': True,
     'feedback': "Correct."
    },
    {'answer': "sum of errors",
     'correct': False,
     'feedback': "There is no minimum value for this metric."
    }
]
questions+=[ {'question':question, 'type':'many_choice', 'answers':answers} ]

display_quiz(question, answers, multiple=True,
             question_background="#feb44A")
# Out:
# <div id="quizWrap" style="max-width: 600px; margin: 0 auto;">
#       <!-- QUESTION -->
#       <div id="quizQn" style="padding: 20px;
#       background: #feb44A;
#       color: #fff;
#       font-size: 20px;
#       border-radius: 10px;">
#       Choose all of the following that are useful error metrics that can be minimized to create a summary statistic:</div>
#       <!-- ANSWER -->
#       <div id="quizAns" style="margin: 10px 0;
#       display: grid;
#       grid-template-columns: auto auto;
#       grid-gap: 10px;">
#       <input type="radio" name="quiz" id="quizo0" style="display:none;" ><label style="background: #fafafa;
#       border: 1px solid #eee;  border-radius: 10px; padding: 10px;
#       font-size: 16px; cursor: pointer; text-align: center;"
#       onclick="checkUERWLaumYrNP()"
# ...

# %%
question='''Which of the following summary statistics minimizes the sum of squared errors to the data:'''
answers=[
    {'answer':"average",
     'correct': True,
     'feedback': "Correct."
    },
    {'answer': "median",
     'correct': False,
     'feedback': "Try again."
    },
    {'answer': "mode",
     'correct': False,
     'feedback': "Try again."
    }
]

questions+=[ {'question':question, 'type':'multiple_choice', 'answers':answers} ]



display_quiz(question, answers, )
# Out:
# <div id="quizWrap" style="max-width: 600px; margin: 0 auto;">
#       <!-- QUESTION -->
#       <div id="quizQn" style="padding: 20px;
#       background: ;
#       color: #fff;
#       font-size: 20px;
#       border-radius: 10px;">
#       Which of the following summary statistics minimizes the sum of squared errors to the data:</div>
#       <!-- ANSWER -->
#       <div id="quizAns" style="margin: 10px 0;
#       display: grid;
#       grid-template-columns: auto auto;
#       grid-gap: 10px;">
#       <input type="radio" name="quiz" id="quizo0" style="display:none;" ><label style="background: #fafafa;
#       border: 1px solid #eee;  border-radius: 10px; padding: 10px;
#       font-size: 16px; cursor: pointer; text-align: center;"
#       onclick="checkKJrmYzKYvUGX()"
#       id="quizo0" data-correct="False" data-feedback="Try again." data-answered=0>mode  </label><input type="radio" name="quiz" id="quizo1" style="display:none;" ><label style="background: #fafafa;
# ...

# %%
question='''Which of the following summary statistics minimizes the sum of absolute errors to the data:'''
answers=[
    {'answer':"average",
     'correct': False,
     'feedback': "Try again."
    },
    {'answer': "median",
     'correct': True,
     'feedback': "Correct."
    },
    {'answer': "mode",
     'correct': False,
     'feedback': "Try again."
    }
]

questions+=[ {'question':question, 'type':'multiple_choice', 'answers':answers} ]



display_quiz(question, answers)
# Out:
# <div id="quizWrap" style="max-width: 600px; margin: 0 auto;">
#       <!-- QUESTION -->
#       <div id="quizQn" style="padding: 20px;
#       background: ;
#       color: #fff;
#       font-size: 20px;
#       border-radius: 10px;">
#       Which of the following summary statistics minimizes the sum of absolute errors to the data:</div>
#       <!-- ANSWER -->
#       <div id="quizAns" style="margin: 10px 0;
#       display: grid;
#       grid-template-columns: auto auto;
#       grid-gap: 10px;">
#       <input type="radio" name="quiz" id="quizo0" style="display:none;" ><label style="background: #fafafa;
#       border: 1px solid #eee;  border-radius: 10px; padding: 10px;
#       font-size: 16px; cursor: pointer; text-align: center;"
#       onclick="checkNGDbokJYQfEX()"
#       id="quizo0" data-correct="False" data-feedback="Try again." data-answered=0>average  </label><input type="radio" name="quiz" id="quizo1" style="display:none;" ><label style="background: #fafafa;
# ...

# %%
question='''Which of the following summary statistics minimizes the number of non-zero errors to the data:'''
answers=[
    {'answer':"average",
     'correct': False,
     'feedback': "Try again."
    },
    {'answer': "median",
     'correct': False,
     'feedback': "Try again."
    },
    {'answer': "mode",
     'correct': True,
     'feedback': "Correct."
    }
]
questions+=[ {'question':question, 'type':'multiple_choice', 'answers':answers} ]





display_quiz(question, answers)
# Out:
# <div id="quizWrap" style="max-width: 600px; margin: 0 auto;">
#       <!-- QUESTION -->
#       <div id="quizQn" style="padding: 20px;
#       background: ;
#       color: #fff;
#       font-size: 20px;
#       border-radius: 10px;">
#       Which of the following summary statistics minimizes the number of non-zero errors to the data:</div>
#       <!-- ANSWER -->
#       <div id="quizAns" style="margin: 10px 0;
#       display: grid;
#       grid-template-columns: auto auto;
#       grid-gap: 10px;">
#       <input type="radio" name="quiz" id="quizo0" style="display:none;" ><label style="background: #fafafa;
#       border: 1px solid #eee;  border-radius: 10px; padding: 10px;
#       font-size: 16px; cursor: pointer; text-align: center;"
#       onclick="checkgyULSczyhVXB()"
#       id="quizo0" data-correct="True" data-feedback="Correct." data-answered=0>mode  </label><input type="radio" name="quiz" id="quizo1" style="display:none;" ><label style="background: #fafafa;
# ...

# %%
question='''Choose all of the following that are typical causes of outliers in data sets:'''
answers=[
    {'answer':"data entry errors",
     'correct': True,
     'feedback': "Correct."
    },
    {'answer': "unit conversion errors",
     'correct': True,
     'feedback': "Correct."
    },
    {'answer': "measurement errors",
     'correct': True,
     'feedback': "Correct."
    },
    {'answer': "different population characteristics",
     'correct': False,
     'feedback': "Different population characteristics often produce variations in data, but these are not erroneous values and not considered outliers."
    }
]

questions+=[ {'question':question, 'type':'many_choice', 'answers':answers} ]



display_quiz(question, answers, multiple=True,
             question_background="#feb44A")
# Out:
# <div id="quizWrap" style="max-width: 600px; margin: 0 auto;">
#       <!-- QUESTION -->
#       <div id="quizQn" style="padding: 20px;
#       background: #feb44A;
#       color: #fff;
#       font-size: 20px;
#       border-radius: 10px;">
#       Choose all of the following that are typical causes of outliers in data sets:</div>
#       <!-- ANSWER -->
#       <div id="quizAns" style="margin: 10px 0;
#       display: grid;
#       grid-template-columns: auto auto;
#       grid-gap: 10px;">
#       <input type="radio" name="quiz" id="quizo0" style="display:none;" ><label style="background: #fafafa;
#       border: 1px solid #eee;  border-radius: 10px; padding: 10px;
#       font-size: 16px; cursor: pointer; text-align: center;"
#       onclick="checkmJSiklLwMPgI()"
#       id="quizo0" data-correct="True" data-feedback="Correct." data-answered=0>measurement errors  </label><input type="radio" name="quiz" id="quizo1" style="display:none;" ><label style="background: #fafafa;
# ...

# %% [markdown]
# # Now write out to file

# %%
import json
with open('../questions/ch3.txt', 'w') as outfile:
    json.dump(questions, outfile, indent=4)

# %% [markdown]
# # Read back and display questions

# %%
import json

questions=[]
with open('../questions/ch3.txt', 'r') as infile:
    questions=json.load(infile)

# %%
len(questions)
# Out:
# 5

# %%
questions
# Out:
# [{'question': 'Choose all of the following that are useful error metrics that can be minimized to create a summary statistic:',
#   'type': 'many_choice',
#   'answers': [{'answer': 'sum of absolute errors',
#     'correct': True,
#     'feedback': 'Correct.'},
#    {'answer': 'total number of errors',
#     'correct': True,
#     'feedback': 'Correct.'},
#    {'answer': 'sum of errors',
#     'correct': False,
#     'feedback': 'There is no minimum value for this metric.'},
#    {'answer': 'sum of squared errors',
#     'correct': True,
#     'feedback': 'Correct.'}]},
#  {'question': 'Which of the following summary statistics minimizes the sum of squared errors to the data:',
#   'type': 'multiple_choice',
#   'answers': [{'answer': 'mode', 'correct': False, 'feedback': 'Try again.'},
#    {'answer': 'median', 'correct': False, 'feedback': 'Try again.'},
#    {'answer': 'average', 'correct': True, 'feedback': 'Correct.'}]},
# ...

# %%
from quizlet import display_multiple
display_multiple(questions)
# Out:
# <div id="quizWrap" style="max-width: 600px; margin: 0 auto;">
#       <!-- QUESTION -->
#       <div id="quizQn" style="padding: 20px;
#       background: #FEB44A;
#       color: #fff;
#       font-size: 20px;
#       border-radius: 10px;">
#       Choose all of the following that are useful error metrics that can be minimized to create a summary statistic:</div>
#       <!-- ANSWER -->
#       <div id="quizAns" style="margin: 10px 0;
#       display: grid;
#       grid-template-columns: auto auto;
#       grid-gap: 10px;">
#       <input type="radio" name="quiz" id="quizo0" style="display:none;" ><label style="background: #fafafa;
#       border: 1px solid #eee;  border-radius: 10px; padding: 10px;
#       font-size: 16px; cursor: pointer; text-align: center;"
#       onclick="checkbOIBZdCjvGiL()"
# ...
