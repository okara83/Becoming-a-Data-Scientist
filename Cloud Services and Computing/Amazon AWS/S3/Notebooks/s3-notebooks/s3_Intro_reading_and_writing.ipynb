# %%
import boto3
from smart_open import smart_open

# %% [markdown]
# # Listing Existing Buckets

# %%
s3 = boto3.client('s3')
response = s3.list_buckets() # Retrieve the list of existing buckets

# %%
for bucket in response['Buckets']:
    print(f'  {bucket["Name"]}') # Output the bucket names
# Out:
#   bmsorganic
#   copppp
#   isingmodeldata
#   onurkaraphys.com
#   organic-optical-recognition
#   orgo-repos-git
#   sommd-demo1.com
#   sommdwelcome.com
#   tbingol.com
#   tests3csv
#   theochem.com
#   www.onurkaraphys.com
#   www.sommd-demo1.com
#   www.sommdwelcome.com
#   www.tbingol.com
#   www.theochem.com

# %% [markdown]
# # Simplest Connection Option - To A Single Bucket and Item

# %%
s3 = boto3.resource('s3')
bucket = s3.Bucket('tests3csv')
print(bucket)
# Out:
# s3.Bucket(name='tests3csv')

# %%
obj = s3.Object('tests3csv', 'smoking.csv')
body = obj.get()['Body'].read()
print(body)
# Out:
# b'Id,Age,FEV,Height,Sex,Smoker\n301,9,1.708,57,Female,Non\n451,8,1.724,67.5,Female,Non\n501,7,1.72,54.5,Female,Non\n642,9,1.558,53,Male,Non\n901,9,1.895,57,Male,Non\n1701,8,2.336,61,Female,Non\n1752,6,1.919,58,Female,Non\n1753,6,1.415,56,Female,Non\n1901,8,1.987,58.5,Female,Non\n1951,9,1.942,60,Female,Non\n1952,6,1.602,53,Female,Non\n2001,8,1.735,54,Male,Non\n2101,8,2.193,58.5,Female,Non\n2401,8,2.118,60.5,Male,Non\n3102,8,2.258,58,Male,Non\n3142,7,1.932,53,Male,Non\n3541,5,1.472,50,Male,Non\n3551,6,1.878,53,Female,Non\n4201,9,2.352,59,Male,Non\n4301,9,2.604,61.5,Male,Non\n4351,5,1.4,49,Female,Non\n5151,5,1.256,52.5,Female,Non\n5152,4,0.839,48,Female,Non\n5201,7,2.578,62.5,Male,Non\n5601,9,2.988,65,Female,Non\n5642,3,1.404,51.5,Male,Non\n5702,9,2.348,60,Male,Non\n6042,5,1.755,52,Male,Non\n6101,8,2.98,60,Female,Non\n6801,9,2.1,60,Female,Non\n6851,5,1.282,49,Female,Non\n7201,9,3,65.5,Male,Non\n7251,8,2.673,60,Female,Non\n7252,7,2.093,57.5,Female,Non\n7253,5,1.612,52,Female,Non\n8501,8,2.175,59,Female,Non\n8801,9,2.725,59,Male,Non\n9101,8,2.071,55,Male,Non\n9201,8,1.547,57,Male,Non\n9301,8,2.004,57,Male,Non\n9501,9,3.135,60,Female,Non\n9801,8,2.42,59,Male,Non\n10041,5,1.776,51,Male,Non\n10401,8,1.931,57,Female,Non\n10451,5,1.343,50,Female,Non\n10601,9,2.076,57,Female,Non\n10701,7,1.624,54,Male,Non\n10751,8,1.344,52.5,Female,Non\n10841,6,1.65,55,Male,Non\n11201,8,2.732,60.5,Male,Non\n11241,5,2.017,54.5,Male,Non\n11501,9,2.797,61.5,Female,Non\n12001,9,3.556,62,Male,Non\n12201,8,1.703,54.5,Male,Non\n12241,6,1.634,54,Male,Non\n12402,9,2.57,57,Male,Non\n13351,9,3.016,62.5,Female,Non\n13701,7,2.419,60,Female,Non\n13751,4,1.569,50,Female,Non\n14051,8,1.698,57.5,Female,Non\n14101,8,2.123,60,Male,Non\n14201,8,2.481,60,Female,Non\n14251,6,1.481,51,Female,Non\n14252,4,1.577,49,Female,Non\n14501,8,1.94,59,Male,Non\n14541,6,1.747,57.5,Male,Non\n14601,9,2.069,58,Male,Non\n14651,7,1.631,55.5,Female,Non\n15153,5,1.536,52,Female,Non\n15201,9,2.56,60.5,Female,Non\n15241,8,1.962,57,Male,Non\n15301,8,2.531,58,Female,Non\n15401,9,2.715,60,Male,Non\n15443,9,2.457,59,Male,Non\n15601,9,2.09,59.5,Male,Non\n15701,7,1.789,56,Male,Non\n15741,5,1.858,53,Male,Non\n15842,5,1.452,51,Male,Non\n16101,9,3.842,69,Male,Non\n16151,6,1.719,53,Female,Non\n16251,7,2.111,57,Female,Non\n16252,6,1.695,53,Female,Non\n16501,8,2.211,63,Male,Non\n16601,8,1.794,54.5,Male,Non\n16651,7,1.917,58,Female,Non\n18101,8,2.144,63,Female,Non\n18501,7,1.253,52,Male,Non\n18843,9,2.659,61.5,Male,Non\n18844,5,1.58,52.5,Male,Non\n19401,9,2.126,62,Male,Non\n20152,9,3.029,61.5,Female,Non\n20801,9,2.964,64.5,Male,Non\n20841,7,1.611,57.5,Male,Non\n21552,8,2.215,60,Female,Non\n22201,8,2.388,60,Female,Non\n22901,9,2.196,61,Male,Non\n23101,9,1.751,58,Male,Non\n23441,9,2.165,61.5,Male,Non\n23442,7,1.682,55,Male,Non\n23641,8,1.523,55,Male,Non\n23653,8,1.292,52,Female,Non\n23801,7,1.649,54,Male,Non\n23802,9,2.588,63,Male,Non\n23841,4,0.796,47,Male,Non\n23902,9,2.574,60.5,Female,Non\n23941,6,1.979,56,Male,Non\n24401,8,2.354,58.5,Male,Non\n24843,6,1.718,55,Male,Non\n24851,7,1.742,58.5,Female,Non\n25001,7,1.603,51,Female,Non\n25052,8,2.639,59.5,Female,Non\n25201,7,1.829,54,Female,Non\n27001,7,2.084,58,Male,Non\n27401,7,2.22,58,Male,Non\n27952,7,1.473,52.5,Female,Non\n28452,8,2.341,60.5,Female,Non\n28501,7,1.698,54.5,Female,Non\n28551,5,1.196,46.5,Female,Non\n28801,8,1.872,56.5,Female,Non\n29001,7,2.219,55,Male,Non\n29101,9,2.42,57,Male,Non\n29151,7,1.827,54.5,Female,Non\n29401,7,1.461,54,Female,Non\n29443,6,1.338,53,Male,Non\n29601,8,2.09,57,Male,Non\n29701,8,1.697,59,Female,Non\n29741,8,1.562,55,Male,Non\n29901,9,2.04,55.5,Female,Non\n29954,7,1.609,51.5,Female,Non\n30001,8,2.458,61,Female,Non\n30043,9,2.65,63.5,Male,Non\n31001,8,1.429,57.5,Male,Non\n31501,8,1.675,53,Male,Non\n31551,9,1.947,56.5,Female,Non\n32501,8,2.069,54,Male,Non\n32542,6,1.572,52,Male,Non\n32742,6,1.348,53,Male,Non\n32751,8,2.288,61.5,Female,Non\n33301,9,1.773,58.5,Male,Non\n33351,5,0.791,52,Female,Non\n33501,7,1.905,58,Male,Non\n3360 ...

# %%
bucket.objects
# Out:
# s3.Bucket.objectsCollectionManager(s3.Bucket(name='tests3csv'), s3.ObjectSummary)

# %% [markdown]
# # Iterate through all the objects/items in a given Bucket
# doing the pagination for you. Each obj is an ObjectSummary, so it doesn't contain the body. You'll need to call get to get the whole body.

# %%
for obj in bucket.objects.all():
    key = obj.key
    body = obj.get()['Body'].read()
    print("key: ",key,"\nbody: ",body[:60])
# Out:
# key:  Stampede.csv
# body:  b'ID,DATE,TIME,TIME_OF_DAY,NETWORK,HEADLINE,SENTIMENT_LABEL,SE'
# key:  landing_page_class_exercise.csv
# body:  b'path,page_type\r\n/nieuws/2020/12/30/het-irrationele-wint-aan-'
# key:  skin_cancer.csv
# body:  b'keyword,count\n"1800 skin cancer research",376\n"2c 2c cancer '
# key:  sleeping-alone-data.csv
# body:  b'StartDate,EndDate,Which of the following best describes your'
# key:  smoking.csv
# body:  b'Id,Age,FEV,Height,Sex,Smoker\n301,9,1.708,57,Female,Non\n451,8'
# key:  some_binary_data.txt
# body:  b'Here we have some data'
# key:  stl_test_results.csv
# body:  b' scenario,idx,season,trend,rw\n baseline,           0 , -0.13'
# key:  tasks.csv
# body:  b'name,docs,cats,word,dpc1,dpc2,dpc3,dpc4,dpc5,dpc6,dpc7,dpc8,'
# key:  test.csv
# body:  b'__label__1\t"b""Dan Katzir has produced a wonderful film that'
# key:  test1.csv
# body:  b'"3","Fears for T N pension after talks","Unions representing'
# key:  test1.txt
# body:  b'Here we have some more data'

# %% [markdown]
# # Streaming Lines from an S3 object using <b>smart_open</b>

# %%
for line in smart_open('s3://tests3csv/smoking.csv', 'rb'):
    print(line.decode('utf8'))
# Out:
# Id,Age,FEV,Height,Sex,Smoker
#
# 301,9,1.708,57,Female,Non
#
# 451,8,1.724,67.5,Female,Non
#
# 501,7,1.72,54.5,Female,Non
#
# 642,9,1.558,53,Male,Non
#
# 901,9,1.895,57,Male,Non
#
# 1701,8,2.336,61,Female,Non
#
# 1752,6,1.919,58,Female,Non
#
# 1753,6,1.415,56,Female,Non
#
# 1901,8,1.987,58.5,Female,Non
#
# 1951,9,1.942,60,Female,Non
#
# 1952,6,1.602,53,Female,Non
#
# 2001,8,1.735,54,Male,Non
#
# 2101,8,2.193,58.5,Female,Non
#
# 2401,8,2.118,60.5,Male,Non
#
# 3102,8,2.258,58,Male,Non
#
# 3142,7,1.932,53,Male,Non
#
# 3541,5,1.472,50,Male,Non
#
# 3551,6,1.878,53,Female,Non
#
# 4201,9,2.352,59,Male,Non
#
# 4301,9,2.604,61.5,Male,Non
#
# 4351,5,1.4,49,Female,Non
#
# 5151,5,1.256,52.5,Female,Non
#
# 5152,4,0.839,48,Female,Non
#
# 5201,7,2.578,62.5,Male,Non
#
# 5601,9,2.988,65,Female,Non
#
# 5642,3,1.404,51.5,Male,Non
#
# 5702,9,2.348,60,Male,Non
#
# 6042,5,1.755,52,Male,Non
#
# 6101,8,2.98,60,Female,Non
#
# 6801,9,2.1,60,Female,Non
#
# 6851,5,1.282,49,Female,Non
#
# 7201,9,3,65.5,Male,Non
#
# 7251,8,2.673,60,Female,Non
#
# 7252,7,2.093,57.5,Female,Non
#
# 7253,5,1.612,52,Female,Non
#
# 8501,8,2.175,59,Female,Non
#
# 8801,9,2.725,59,Male,Non
#
# 9101,8,2.071,55,Male,Non
#
# 9201,8,1.547,57,Male,Non
#
# 9301,8,2.004,57,Male,Non
#
# 9501,9,3.135,60,Female,Non
#
# 9801,8,2.42,59,Male,Non
#
# 10041,5,1.776,51,Male,Non
#
# 10401,8,1.931,57,Female,Non
#
# 10451,5,1.343,50,Female,Non
#
# 10601,9,2.076,57,Female,Non
#
# 10701,7,1.624,54,Male,Non
#
# 10751,8,1.344,52.5,Female,Non
#
# 10841,6,1.65,55,Male,Non
#
# 11201,8,2.732,60.5,Male,Non
#
# 11241,5,2.017,54.5,Male,Non
#
# 11501,9,2.797,61.5,Female,Non
#
# 12001,9,3.556,62,Male,Non
#
# 12201,8,1.703,54.5,Male,Non
#
# 12241,6,1.634,54,Male,Non
#
# 12402,9,2.57,57,Male,Non
#
# 13351,9,3.016,62.5,Female,Non
#
# 13701,7,2.419,60,Female,Non
#
# 13751,4,1.569,50,Female,Non
#
# 14051,8,1.698,57.5,Female,Non
#
# 14101,8,2.123,60,Male,Non
#
# 14201,8,2.481,60,Female,Non
#
# 14251,6,1.481,51,Female,Non
#
# 14252,4,1.577,49,Female,Non
#
# 14501,8,1.94,59,Male,Non
#
# 14541,6,1.747,57.5,Male,Non
#
# 14601,9,2.069,58,Male,Non
#
# 14651,7,1.631,55.5,Female,Non
#
# 15153,5,1.536,52,Female,Non
#
# 15201,9,2.56,60.5,Female,Non
#
# 15241,8,1.962,57,Male,Non
#
# 15301,8,2.531,58,Female,Non
#
# 15401,9,2.715,60,Male,Non
#
# 15443,9,2.457,59,Male,Non
#
# 15601,9,2.09,59.5,Male,Non
#
# 15701,7,1.789,56,Male,Non
#
# 15741,5,1.858,53,Male,Non
#
# 15842,5,1.452,51,Male,Non
#
# 16101,9,3.842,69,Male,Non
#
# 16151,6,1.719,53,Female,Non
#
# 16251,7,2.111,57,Female,Non
#
# 16252,6,1.695,53,Female,Non
#
# 16501,8,2.211,63,Male,Non
#
# 16601,8,1.794,54.5,Male,Non
#
# 16651,7,1.917,58,Female,Non
#
# 18101,8,2.144,63,Female,Non
#
# 18501,7,1.253,52,Male,Non
#
# 18843,9,2.659,61.5,Male,Non
#
# 18844,5,1.58,52.5,Male,Non
#
# 19401,9,2.126,62,Male,Non
#
# 20152,9,3.029,61.5,Female,Non
#
# 20801,9,2.964,64.5,Male,Non
#
# 20841,7,1.611,57.5,Male,Non
#
# 21552,8,2.215,60,Female,Non
#
# 22201,8,2.388,60,Female,Non
#
# 22901,9,2.196,61,Male,Non
#
# 23101,9,1.751,58,Male,Non
#
# 23441,9,2.165,61.5,Male,Non
#
# 23442,7,1.682,55,Male,Non
#
# 23641,8,1.523,55,Male,Non
#
# 23653,8,1.292,52,Female,Non
#
# 23801,7,1.649,54,Male,Non
#
# 23802,9,2.588,63,Male,Non
#
# 23841,4,0.796,47,Male,Non
#
# 23902,9,2.574,60.5,Female,Non
#
# 23941,6,1.979,56,Male,Non
#
# 24401,8,2.354,58.5,Male,Non
#
# 24843,6,1.718,55,Male,Non
#
# 24851,7,1.742,58.5,Female,Non
#
# 25001,7,1.603,51,Female,Non
#
# 25052,8,2.639,59.5,Female,Non
#
# 25201,7,1.829,54,Female,Non
#
# 27001,7,2.084,58,Male,Non
#
# 27401,7,2.22,58,Male,Non
#
# 27952,7,1.473,52.5,Female,Non
#
# 28452,8,2.341,60.5,Female,Non
#
# 28501,7,1.698,54.5,Female,Non
#
# 28551,5,1.196,46.5,Female,Non
#
# 28801,8,1.872,56.5,Female,Non
#
# 29001,7,2.219,55,Male,Non
#
# 29101,9,2.42,57,Male,Non
#
# 29151,7,1.827,54.5,Female,Non
#
# 29401,7,1.461,54,Female,Non
#
# 29443,6,1.338,53,Male,Non
#
# 29601,8,2.09,57,Male,Non
#
# 29701,8,1.697,59,Female,Non
#
# 29741,8,1.562,55,Male,Non
#
# 29901,9,2.04,55.5,Female,Non
#
# 29954,7,1.609,51.5,Female,Non
#
# 30001,8,2.458,61,Female,Non
#
# 30043,9,2.65,63.5,Male,Non
#
# 31001,8,1.429,57.5,Male,Non
#
# 31501,8,1.675,53,Male,Non
#
# 31551,9,1.947,56.5,Female,Non
#
# 32501,8,2.069,54,Male,Non
#
# 32542,6,1.572,52,Male,Non
#
# 32742,6,1.348,53,Male,Non
#
# 32751,8,2.288,61.5,Female,Non
#
# 33301,9,1.773,58.5,Male,Non
#
# 33351,5,0.791,52,Female,Non
#
# 33501,7,1.905,58,Male,Non
#
# 33601,9,2.463,61,Female,Non
#
# 33641,6,1.431,51,Male,Non
#
# 33801,9,2.631,62,Female,Non
#
# 34101,9,3.114,64.5,Male,Non
#
# 34301,9,2.135,58.5,Male,Non
#
# 34341,6,1.527,52.5,Male,Non
#
# 35102,8,2.293,58,Female,Non
#
# 35103,9,3.042,66,Female,Non
#
# 35601,8,2.927,63.5,Male,Non
#
# 37201,8,2.665,64,Female,Non
#
# 37301,9,2.301,58.5,Male,Non
#
# 37901,9,2.46,64,Male,Non
#
# 38051,9,2.592,60.5,Female,Non
#
# 38152,7,1.75,55,Female,Non
#
# 38241,8,1.759,53,Male,Non
#
# 38242,6,1.536,48,Male,Non
#
# 38801,9,2.259,58.5,Female,Non
#
# 39001,9,2.048,64.5,Female,Non
#
# 39101,9,2.571,60.5,Male,Non
#
# 39141,7,2.046,56,Male,Non
#
# 39201,8,1.78,58.5,Female,Non
#
# 39251,5,1.552,54,Female,Non
#
# 39301,8,1.953,58,Female,Non
#
# 39401,9,2.893,64.5,Male,Non
#
# 39741,6,1.713,50.5,Male,Non
#
# 39801,9,2.851,60,Female,Non
#
# 39841,6,1.624,51.5,Male,Non
#
# 39901,8,2.631,59,Male,Non
#
# 39941,5,1.819,53,Male,Non
#
# 40001,7,1.658,53,Male,Non
#
# 40501,7,2.158,53.5,Male,Non
#
# 40541,4,1.789,52,Male,Non
#
# 42101,9,3.004,64,Female,Non
#
# 42201,8,2.503,63,Male,Non
#
# 42501,9,1.933,58,Female,Non
#
# 42552,9,2.091,58.5,Female,Non
#
# 42901,9,2.316,59.5,Female,Non
#
# 42941,5,1.704,51,Female,Non
#
# 43201,9,1.606,57.5,Female,Non
#
# 43242,7,1.165,47,Male,Non
#
# 43651,6,2.102,55.5,Female,Non
#
# 43901,9,2.32,57,Female,Non
#
# 44201,9,2.23,61,Male,Non
#
# 44301,9,1.716,55.5,Male,Non
#
# 44501,7,1.79,53.5,Male,Non
#
# 44551,5,1.146,50,Female,Non
#
# 44701,8,2.187,61.5,Female,Non
#
# 45001,9,2.717,61.5,Male,Non
#
# 45041,7,1.796,55,Male,Non
#
# 45241,9,1.953,58,Male,Current
#
# 45251,8,1.335,56.5,Female,Non
#
# 45301,9,2.119,57,Male,Non
#
# 45641,6,1.666,52,Male,Non
#
# 45642,6,1.826,52.5,Male,Non
#
# 45653,8,2.709,62.5,Female,Non
#
# 46101,9,2.871,65,Male,Non
#
# 46151,5,1.092,50,Female,Non
#
# 46641,6,2.262,57.5,Male,Non
#
# 46642,6,2.104,56.5,Male,Non
#
# 47001,9,2.166,57.5,Female,Non
#
# 47053,7,1.69,54,Female,Non
#
# 47242,9,2.973,59.5,Male,Non
#
# 47301,8,2.145,59.5,Female,Non
#
# 47341,5,1.971,58,Male,Non
#
# 47552,7,2.095,57,Female,Non
#
# 48052,6,1.697,55,Female,Non
#
# 48101,9,2.455,60,Female,Non
#
# 48401,7,1.92,56.5,Male,Non
#
# 48402,9,2.164,60,Male,Non
#
# 48901,9,2.13,59,Female,Non
#
# 49301,8,2.993,63,Female,Non
#
# 49401,9,2.529,59,Female,Non
#
# 49501,7,1.726,53,Female,Non
#
# 49542,9,2.442,61.5,Female,Non
#
# 49551,4,1.102,48,Female,Non
#
# 49701,9,2.056,63,Female,Non
#
# 49741,5,1.808,55.5,Male,Non
#
# 49751,8,2.305,64.5,Female,Non
#
# 50501,9,1.969,59,Female,Non
#
# 50701,8,1.556,58.5,Female,Non
#
# 50951,3,1.072,46,Female,Non
#
# 51241,9,2.042,62,Male,Non
#
# 51301,8,1.512,53,Female,Non
#
# 51341,6,1.423,49.5,Male,Non
#
# 51501,9,3.681,68,Male,Non
#
# 51542,8,1.991,59.5,Male,Non
#
# 52101,8,1.897,55.5,Male,Non
#
# 53601,7,1.37,55,Female,Non
#
# 53651,6,1.338,51.5,Female,Non
#
# 54201,8,2.016,56,Male,Non
#
# 54701,9,2.639,63,Female,Non
#
# 54751,4,1.389,48,Female,Non
#
# 54941,7,1.612,56.5,Male,Non
#
# 54952,8,2.135,59,Female,Non
#
# 55645,8,2.681,60.5,Male,Non
#
# 55652,9,3.223,65,Female,Non
#
# 57651,6,1.796,55,Female,Non
#
# 57901,8,2.01,55,Male,Non
#
# 58341,6,1.523,51,Female,Non
#
# 58601,8,1.744,52.5,Male,Non
#
# 58602,9,2.485,64,Female,Non
#
# 60051,8,2.335,59,Female,Non
#
# 60251,7,1.415,53.5,Female,Non
#
# 60801,9,2.076,60.5,Male,Non
#
# 61101,8,2.435,59.5,Male,Non
#
# 61601,7,1.728,56.5,Female,Non
#
# 61801,9,2.85,63,Female,Non
#
# 61901,8,1.844,56.5,Female,Non
#
# 62301,9,1.754,61.5,Female,Non
#
# 62351,6,1.343,52,Female,Non
#
# 62641,8,2.303,57,Male,Non
#
# 62702,9,2.246,63.5,Male,Non
#
# 63102,8,2.476,63,Female,Non
#
# 63201,9,3.239,65,Male,Non
#
# 63941,9,2.457,61.5,Male,Non
#
# 64101,8,2.382,62,Female,Non
#
# 64151,7,1.64,55,Female,Non
#
# 64152,5,1.589,51,Female,Non
#
# 64201,7,2.056,54,Male,Non
#
# 70001,8,2.226,57,Male,Non
#
# 70401,9,1.886,56,Female,Non
#
# 71101,9,2.833,61.5,Male,Non
#
# 71241,6,1.715,53,Male,Non
#
# 71401,8,2.631,59,Male,Non
#
# 71444,7,2.55,56,Male,Non
#
# 71851,9,1.912,59,Female,Non
#
# 72001,7,1.877,52.5,Female,Non
#
# 72051,7,1.935,52.5,Female,Non
#
# 72052,5,1.539,50,Female,Non
#
# 72501,9,2.803,59.5,Male,Non
#
# 73001,9,2.923,64,Male,Non
#
# 73151,8,2.358,61,Female,Non
#
# 73342,8,2.094,57.5,Male,Non
#
# 74201,9,1.855,60,Male,Non
#
# 74241,6,1.535,55,Female,Non
#
# 74401,7,2.135,56,Male,Non
#
# 74441,5,1.93,51,Male,Non
#
# 74601,9,2.182,59.5,Female,Non
#
# 74641,5,1.359,50.5,Male,Non
#
# 74652,7,2.002,57.5,Female,Non
#
# 74941,6,1.699,54,Male,Non
#
# 75701,8,2.5,57,Male,Non
#
# 75751,7,2.366,58,Female,Non
#
# 75901,8,2.069,60,Female,Non
#
# 75951,4,1.418,49,Female,Non
#
# 76501,8,2.333,57,Female,Non
#
# 76541,5,1.514,52,Male,Non
#
# 76751,8,1.758,52,Female,Non
#
# 77141,7,2.535,59.5,Male,Non
#
# 77901,7,2.564,58,Female,Non
#
# 78301,9,2.487,64,Female,Non
#
# 78352,9,1.591,57,Female,Non
#
# 80001,8,1.624,53,Male,Non
#
# 80301,9,2.798,62,Male,Non
#
# 80341,6,1.691,53,Male,Non
#
# 80601,8,1.999,56.5,Female,Non
#
# 80801,9,1.869,57,Male,Non
#
# 80841,4,1.004,48,Male,Non
#
# 81241,6,1.427,49.5,Male,Non
#
# 81401,7,1.826,51,Male,Non
#
# 81451,9,2.688,59.5,Female,Non
#
# 81501,8,1.657,56,Male,Non
#
# 81751,6,1.672,54,Female,Non
#
# 82701,8,2.015,57.5,Female,Non
#
# 83801,7,2.371,55.5,Female,Non
#
# 83841,5,2.115,50,Male,Non
#
# 83901,8,2.328,60,Female,Non
#
# 83952,7,1.495,57,Female,Non
#
# 201,11,2.884,69,Male,Non
#
# 202,10,2.328,64,Male,Non
#
# 341,14,3.381,63,Male,Non
#
# 351,11,2.17,58,Female,Non
#
# 401,11,3.47,66.5,Male,Non
#
# 551,12,3.058,60.5,Female,Non
#
# 601,10,1.811,57,Male,Non
#
# 641,11,2.524,64,Male,Non
#
# 1751,10,2.642,61,Female,Non
#
# 2041,14,3.741,68.5,Male,Non
#
# 2042,13,4.336,69.5,Male,Non
#
# 2142,14,4.842,72,Male,Non
#
# 2143,12,4.55,71,Male,Non
#
# 2451,12,2.841,63,Female,Non
#
# 2801,10,3.166,61.5,Female,Non
#
# 2851,13,3.816,63.5,Female,Non
#
# 3141,10,2.561,62,Male,Non
#
# 3501,11,3.654,65,Female,Non
#
# 3901,10,2.481,61,Male,Non
#
# 4001,11,2.665,63,Female,Non
#
# 4341,10,3.203,66,Male,Non
#
# 4901,13,3.549,68,Male,Non
#
# 4952,14,2.236,66,Female,Current
#
# 5001,11,3.222,72,Male,Non
#
# 5101,10,3.111,66,Male,Non
#
# 5251,11,3.49,67,Female,Non
#
# 5351,13,3.147,64,Female,Non
#
# 5352,10,2.52,60.5,Female,Non
#
# 5641,10,2.292,63,Male,Non
#
# 5701,12,2.889,64,Female,Non
#
# 6001,10,2.246,60.5,Male,Non
#
# 6041,10,1.937,62,Male,Non
#
# 6145,10,2.646,60,Male,Non
#
# 6201,11,2.957,64.5,Male,Non
#
# 6401,11,4.007,67,Male,Non
#
# 7101,11,2.386,61.5,Female,Non
#
# 7241,10,3.251,66,Male,Non
#
# 7901,11,2.762,60,Female,Non
#
# 8301,11,3.011,64,Female,Non
#
# 8541,13,4.305,68.5,Male,Non
#
# 8542,13,3.906,67,Male,Non
#
# 8842,11,3.583,67,Male,Non
#
# 8901,11,3.236,66,Female,Non
#
# 9141,14,3.436,62.5,Male,Non
#
# 9142,11,3.058,61,Male,Non
#
# 9502,10,3.007,62,Male,Non
#
# 9802,10,3.489,66.5,Male,Non
#
# 10001,10,2.864,60,Female,Non
#
# 10053,14,3.428,64,Female,Current
#
# 10054,13,2.819,62,Female,Non
#
# 10501,10,2.25,58,Female,Non
#
# 10642,14,4.683,68.5,Male,Non
#
# 10801,10,2.352,61.5,Male,Non
#
# 10901,11,3.108,64.5,Male,Non
#
# 10942,13,3.994,67,Male,Non
#
# 11101,12,4.393,68.5,Male,Non
#
# 11151,13,3.208,61,Female,Current
#
# 11301,10,2.592,65,Male,Non
#
# 11341,13,3.193,70,Male,Non
#
# 11601,11,1.694,60,Male,Current
#
# 11642,14,3.957,72,Male,Current
#
# 11901,11,2.346,59,Female,Non
#
# 11942,13,4.789,69,Male,Current
#
# 12501,11,3.515,67.5,Male,Non
#
# 13301,11,2.754,65.5,Female,Non
#
# 14001,10,2.72,65.5,Male,Non
#
# 14143,11,2.463,64.5,Male,Non
#
# 14401,11,2.633,62,Female,Non
#
# 15101,10,3.048,65.5,Female,Non
#
# 15141,11,3.111,67.5,Male,Non
#
# 15152,13,3.745,68,Female,Non
#
# 15302,12,2.384,63.5,Female,Current
#
# 15342,10,2.094,58.5,Male,Non
#
# 15451,10,3.183,65.5,Female,Non
#
# 15751,14,3.074,65,Female,Current
#
# 15801,11,3.977,70.5,Male,Non
#
# 15841,10,3.354,63,Male,Non
#
# 16201,11,3.411,63.5,Female,Non
#
# 16551,10,2.387,66,Female,Current
#
# 16901,11,3.171,63,Female,Non
#
# 16941,13,3.887,67.5,Male,Non
#
# 16951,13,2.646,61.5,Female,Non
#
# 16952,10,2.504,60,Female,Non
#
# 17301,11,3.587,64.5,Male,Non
#
# 17401,11,3.845,68.5,Male,Non
#
# 17801,12,2.971,64.5,Male,Non
#
# 17851,10,2.891,61,Female,Non
#
# 18502,10,1.823,57,Female,Non
#
# 18541,11,2.417,62.5,Male,Non
#
# 18551,10,2.175,58,Female,Non
#
# 18801,11,2.735,62.5,Female,Non
#
# 18841,14,4.273,72.5,Male,Non
#
# 18842,13,2.976,65.5,Male,Non
#
# 19601,12,3.835,69.5,Female,Current
#
# 19901,11,4.065,66.5,Male,Non
#
# 20101,11,2.318,59,Female,Non
#
# 21301,11,3.596,68,Male,Non
#
# 21352,14,3.395,67,Female,Non
#
# 21353,12,2.751,63,Female,Non
#
# 21501,10,2.673,64.5,Female,Non
#
# 22253,12,2.556,62,Female,Non
#
# 23151,11,2.542,62,Female,Non
#
# 23401,10,2.608,66,Male,Non
#
# 23601,11,2.354,62,Female,Non
#
# 23651,13,2.599,62.5,Female,Current
#
# 23652,10,1.458,57,Female,Non
#
# 23901,10,3.795,68.5,Male,Non
#
# 24201,11,2.491,59,Female,Non
#
# 24251,13,3.06,61.5,Female,Non
#
# 24501,10,2.545,65,Male,Non
#
# 24543,11,2.993,66.5,Male,Non
#
# 24601,10,3.305,65,Female,Non
#
# 24642,13,4.756,68,Male,Current
#
# 24701,11,3.774,67,Female,Non
#
# 24741,10,2.855,64.5,Male,Non
#
# 24801,11,2.988,70,Male,Non
#
# 25041,11,2.498,60,Male,Non
#
# 25051,14,3.169,64,Female,Non
#
# 25501,11,2.887,62.5,Male,Non
#
# 25551,13,2.704,61,Female,Non
#
# 25901,11,3.515,64,Female,Non
#
# 27441,11,3.425,65.5,Male,Non
#
# 27701,10,2.287,61,Female,Non
#
# 27751,13,2.434,65.4,Female,Non
#
# 27901,10,2.365,63.5,Female,Non
#
# 27951,13,3.086,67.5,Female,Current
#
# 28401,10,2.696,66,Male,Non
#
# 29952,12,2.868,62,Female,Non
#
# 29953,10,2.813,61.5,Female,Non
#
# 30042,14,4.309,69,Male,Current
#
# 30051,12,3.255,66,Female,Non
#
# 30052,10,3.413,66,Female,Current
#
# 30401,11,4.593,69,Male,Non
#
# 31042,14,4.111,71,Male,Non
#
# 31201,12,1.916,60.5,Male,Non
#
# 31242,10,1.858,58,Male,Non
#
# 31502,10,2.975,63,Female,Current
#
# 31901,10,3.35,69,Male,Non
#
# 32541,10,2.901,59.5,Male,Non
#
# 32701,12,2.241,64,Male,Non
#
# 32741,13,4.225,74,Male,Non
#
# 33001,11,3.223,64.5,Female,Non
#
# 33041,12,5.224,70,Male,Non
#
# 33502,11,4.073,67,Male,Non
#
# 33541,12,4.08,64.5,Male,Non
#
# 33701,11,2.606,65,Female,Non
#
# 34201,11,3.169,62.5,Female,Current
#
# 34243,12,4.411,68,Male,Non
#
# 35101,12,3.791,68.5,Male,Non
#
# 35901,13,3.089,67.5,Male,Non
#
# 35941,11,2.465,60,Male,Non
#
# 36001,12,3.343,68,Male,Current
#
# 36041,10,3.2,65,Male,Non
#
# 36101,12,2.913,64,Male,Non
#
# 37241,13,4.877,73,Male,Non
#
# 37351,10,2.358,59,Female,Non
#
# 37401,12,3.279,70.5,Male,Non
#
# 37701,10,2.581,66,Male,Non
#
# 37702,12,2.347,61.5,Female,Non
#
# 37951,10,2.691,67,Female,Non
#
# 38001,11,2.827,62.5,Female,Non
#
# 38201,10,1.873,52.5,Male,Non
#
# 39041,12,3.751,72,Male,Current
#
# 39052,14,2.538,71,Female,Non
#
# 39601,10,2.758,65.5,Male,Non
#
# 39701,10,3.05,60,Female,Non
#
# 40051,12,3.079,60,Female,Non
#
# 40301,10,2.201,60.5,Male,Non
#
# 41601,10,1.858,59,Male,Non
#
# 42151,13,2.216,68,Female,Current
#
# 42251,12,3.403,62,Female,Non
#
# 42301,12,3.501,64.5,Female,Non
#
# 42502,11,2.578,63,Female,Non
#
# 42551,13,3.078,66,Female,Current
#
# 43002,12,3.186,67,Female,Current
#
# 43241,10,1.665,57,Male,Non
#
# 43251,11,2.081,63,Female,Non
#
# 43301,11,2.974,62,Female,Non
#
# 43351,13,3.297,65,Female,Current
#
# 43601,12,4.073,68.5,Male,Non
#
# 43641,13,4.448,69,Male,Non
#
# 44242,13,3.984,71,Male,Non
#
# 44302,10,2.25,58,Female,Non
#
# 44351,12,2.752,63.5,Female,Non
#
# 44601,12,2.304,66.5,Male,Current
#
# 44742,14,3.68,67,Male,Non
#
# 45201,11,3.102,64,Female,Current
#
# 45601,10,2.862,61,Female,Non
#
# 45651,13,2.677,67,Female,Current
#
# 45652,11,3.023,67.5,Female,Non
#
# 46301,11,3.681,68,Female,Non
#
# 46353,13,3.255,66.5,Female,Non
#
# 46601,12,3.692,67,Male,Non
#
# 46651,10,2.356,60.5,Female,Non
#
# 46901,10,4.591,70,Male,Non
#
# 46951,12,3.082,63.5,Female,Non
#
# 47051,13,3.297,65,Female,Current
#
# 47052,11,3.258,63,Female,Non
#
# 47801,10,2.216,61,Male,Non
#
# 47841,11,3.247,65.5,Male,Non
#
# 48001,11,4.324,67.5,Male,Non
#
# 48142,11,2.362,61,Female,Non
#
# 48951,11,2.563,63,Female,Non
#
# 49201,11,3.206,63.5,Male,Non
#
# 49341,14,3.585,70,Male,Non
#
# 49342,12,4.72,71.5,Male,Non
#
# 49451,13,3.331,65.5,Female,Non
#
# 49541,13,5.083,74,Male,Non
#
# 50301,10,3.498,68,Male,Current
#
# 50551,12,2.417,61,Female,Non
#
# 50702,10,2.364,61,Male,Non
#
# 50901,10,2.341,61,Male,Non
#
# 51101,12,2.759,61.5,Female,Current
#
# 51201,11,2.953,67,Female,Current
#
# 51302,12,3.231,63,Male,Non
#
# 51541,11,3.078,67.5,Male,Non
#
# 51601,11,3.369,70.5,Male,Non
#
# 51641,12,3.529,70.5,Male,Non
#
# 52401,12,2.866,62,Female,Non
#
# 52452,14,2.891,62,Female,Non
#
# 52801,11,3.022,61.5,Female,Non
#
# 53101,10,3.127,62,Male,Non
#
# 53151,11,2.866,60.5,Female,Non
#
# 53301,12,2.605,62.5,Female,Non
#
# 54251,13,3.056,63,Female,Non
#
# 54901,12,2.569,63,Female,Non
#
# 54951,11,2.501,62,Female,Non
#
# 55601,11,3.32,65.5,Male,Non
#
# 55901,11,2.123,65,Male,Non
#
# 55941,14,3.78,70,Male,Non
#
# 56601,11,3.847,66,Male,Non
#
# 56651,13,3.785,63,Female,Current
#
# 56901,12,3.924,68,Male,Non
#
# 57001,10,2.132,59,Male,Non
#
# 57042,12,2.752,68.5,Male,Non
#
# 57053,13,2.449,63,Female,Non
#
# 57601,10,3.456,63,Male,Non
#
# 58301,10,3.073,66,Female,Non
#
# 58603,10,2.688,62,Female,Non
#
# 59901,10,3.329,68,Male,Non
#
# 59941,14,4.271,72.5,Male,Non
#
# 60001,12,3.53,64,Male,Non
#
# 60201,11,2.928,65.5,Male,Non
#
# 60851,11,2.689,61.5,Female,Non
#
# 61301,12,2.332,57,Male,Non
#
# 61351,14,2.934,64,Female,Non
#
# 61941,14,2.276,66,Male,Current
#
# 62601,10,3.11,64.5,Male,Non
#
# 62701,11,2.894,67,Male,Non
#
# 62801,11,4.637,72,Male,Current
#
# 62802,10,2.435,65,Female,Non
#
# 63101,10,2.838,63,Female,Non
#
# 63252,12,3.035,62,Female,Non
#
# 63901,12,4.831,71,Male,Non
#
# 64241,11,2.812,61,Male,Non
#
# 70051,12,2.714,65.5,Female,Non
#
# 70052,10,3.086,62,Female,Non
#
# 70201,12,3.519,65.5,Female,Non
#
# 70441,13,4.232,70.5,Male,Non
#
# 70442,10,2.77,62,Male,Non
#
# 71151,12,3.341,65.5,Female,Non
#
# 71201,10,3.09,65,Male,Non
#
# 71443,13,2.531,61,Male,Non
#
# 71801,12,2.822,69.5,Male,Non
#
# 72552,10,3.038,65,Female,Current
#
# 72901,12,2.935,65.5,Male,Non
#
# 73101,10,2.568,63.5,Female,Non
#
# 73301,11,2.387,60.5,Male,Non
#
# 73341,12,2.499,65,Male,Non
#
# 73701,11,4.13,67,Male,Non
#
# 74651,12,3.001,63.5,Female,Non
#
# 74701,10,3.132,59.5,Female,Non
#
# 74751,13,3.577,63.5,Female,Non
#
# 74752,12,3.222,61,Female,Non
#
# 74901,11,3.28,66,Male,Non
#
# 75801,11,2.659,64,Male,Non
#
# 76601,11,2.822,62,Female,Non
#
# 76701,11,2.14,60.5,Female,Non
#
# 77101,12,4.203,71,Male,Non
#
# 77152,14,2.997,64.5,Female,Non
#
# 77501,11,3.12,61,Female,Current
#
# 77601,11,2.562,62.5,Female,Non
#
# 80051,12,3.082,64.5,Female,Non
#
# 80641,14,3.806,68,Male,Non
#
# 80642,11,3.339,68.5,Male,Current
#
# 80651,13,3.152,62,Female,Current
#
# 81201,11,2.458,60,Female,Non
#
# 81541,10,2.391,59.5,Male,Non
#
# 81551,13,3.141,61,Female,Non
#
# 81552,12,2.579,63,Female,Non
#
# 81701,11,3.104,67.5,Female,Current
#
# 81741,13,4.045,69,Male,Current
#
# 82743,14,4.763,68,Male,Current
#
# 82744,10,2.1,58,Male,Non
#
# 83951,11,3.069,65,Female,Current
#
# 90001,11,2.785,69,Male,Non
#
# 441,15,4.284,70,Male,Non
#
# 4041,15,4.506,71,Male,Current
#
# 4051,18,2.906,66,Female,Non
#
# 6144,19,5.102,72,Male,Non
#
# 6252,19,3.519,66,Female,Current
#
# 6441,16,3.688,68,Male,Current
#
# 7142,17,4.429,70,Male,Non
#
# 8841,15,4.279,67.5,Male,Non
#
# 10941,15,4.5,70,Male,Non
#
# 15351,15,2.635,64,Female,Non
#
# 15752,15,2.679,66,Female,Current
#
# 20151,15,2.198,62,Female,Current
#
# 21351,19,3.345,65.5,Female,Current
#
# 22251,18,3.082,64.5,Female,Non
#
# 22252,16,3.387,66.5,Female,Non
#
# 24541,17,3.082,67,Male,Current
#
# 24552,16,2.903,63,Female,Current
#
# 24553,15,3.004,64,Female,Current
#
# 25941,15,5.793,69,Male,Non
#
# 30041,15,3.985,71,Male,Non
#
# 30441,18,4.22,68,Male,Non
#
# 30442,17,4.724,70.5,Male,Non
#
# 33741,15,3.731,67,Male,Non
#
# 34241,17,3.406,69,Male,Current
#
# 37251,17,3.5,62,Female,Non
#
# 37252,16,3.674,67.5,Female,Non
#
# 37441,17,5.633,73,Male,Non
#
# 37451,15,3.122,64,Female,Current
#
# 39051,15,3.33,68.5,Female,Current
#
# 40351,16,2.608,62,Female,Current
#
# 44241,16,3.645,73.5,Male,Non
#
# 47241,15,3.799,66.5,Male,Current
#
# 48141,18,4.086,67,Male,Current
#
# 48152,15,2.887,63,Female,Non
#
# 48441,16,4.07,69.5,Male,Current
#
# 52841,17,3.96,70,Male,Non
#
# 52842,16,4.299,66,Male,Non
#
# 55951,16,2.981,66,Female,Non
#
# 57052,15,2.264,63,Female,Current
#
# 59944,18,4.404,70.5,Male,Current
#
# 61951,15,2.278,60,Female,Current
#
# 63241,16,4.504,72,Male,Non
#
# 71141,17,5.638,70,Male,Non
#
# 71142,16,4.872,72,Male,Current
#
# 73041,16,4.27,67,Male,Current
#
# 73042,15,3.727,68,Male,Current
#
# 73751,18,2.853,60,Female,Non
#
# 75852,16,2.795,63,Female,Current
#
# 77151,15,3.211,66.5,Female,Non

# %% [markdown]
# # Opening with encodings

# %%
with smart_open('s3://tests3csv/smoking.csv', 'rb') as s3_source:
    for line in s3_source:
         print(line.decode('utf8'))
    s3_source.seek(0)  # seek to the beginning
    b1000 = s3_source.read(1000)  # read 1000 bytes
# Out:
# Id,Age,FEV,Height,Sex,Smoker
#
# 301,9,1.708,57,Female,Non
#
# 451,8,1.724,67.5,Female,Non
#
# 501,7,1.72,54.5,Female,Non
#
# 642,9,1.558,53,Male,Non
#
# 901,9,1.895,57,Male,Non
#
# 1701,8,2.336,61,Female,Non
#
# 1752,6,1.919,58,Female,Non
#
# 1753,6,1.415,56,Female,Non
#
# 1901,8,1.987,58.5,Female,Non
#
# 1951,9,1.942,60,Female,Non
#
# 1952,6,1.602,53,Female,Non
#
# 2001,8,1.735,54,Male,Non
#
# 2101,8,2.193,58.5,Female,Non
#
# 2401,8,2.118,60.5,Male,Non
#
# 3102,8,2.258,58,Male,Non
#
# 3142,7,1.932,53,Male,Non
#
# 3541,5,1.472,50,Male,Non
#
# 3551,6,1.878,53,Female,Non
#
# 4201,9,2.352,59,Male,Non
#
# 4301,9,2.604,61.5,Male,Non
#
# 4351,5,1.4,49,Female,Non
#
# 5151,5,1.256,52.5,Female,Non
#
# 5152,4,0.839,48,Female,Non
#
# 5201,7,2.578,62.5,Male,Non
#
# 5601,9,2.988,65,Female,Non
#
# 5642,3,1.404,51.5,Male,Non
#
# 5702,9,2.348,60,Male,Non
#
# 6042,5,1.755,52,Male,Non
#
# 6101,8,2.98,60,Female,Non
#
# 6801,9,2.1,60,Female,Non
#
# 6851,5,1.282,49,Female,Non
#
# 7201,9,3,65.5,Male,Non
#
# 7251,8,2.673,60,Female,Non
#
# 7252,7,2.093,57.5,Female,Non
#
# 7253,5,1.612,52,Female,Non
#
# 8501,8,2.175,59,Female,Non
#
# 8801,9,2.725,59,Male,Non
#
# 9101,8,2.071,55,Male,Non
#
# 9201,8,1.547,57,Male,Non
#
# 9301,8,2.004,57,Male,Non
#
# 9501,9,3.135,60,Female,Non
#
# 9801,8,2.42,59,Male,Non
#
# 10041,5,1.776,51,Male,Non
#
# 10401,8,1.931,57,Female,Non
#
# 10451,5,1.343,50,Female,Non
#
# 10601,9,2.076,57,Female,Non
#
# 10701,7,1.624,54,Male,Non
#
# 10751,8,1.344,52.5,Female,Non
#
# 10841,6,1.65,55,Male,Non
#
# 11201,8,2.732,60.5,Male,Non
#
# 11241,5,2.017,54.5,Male,Non
#
# 11501,9,2.797,61.5,Female,Non
#
# 12001,9,3.556,62,Male,Non
#
# 12201,8,1.703,54.5,Male,Non
#
# 12241,6,1.634,54,Male,Non
#
# 12402,9,2.57,57,Male,Non
#
# 13351,9,3.016,62.5,Female,Non
#
# 13701,7,2.419,60,Female,Non
#
# 13751,4,1.569,50,Female,Non
#
# 14051,8,1.698,57.5,Female,Non
#
# 14101,8,2.123,60,Male,Non
#
# 14201,8,2.481,60,Female,Non
#
# 14251,6,1.481,51,Female,Non
#
# 14252,4,1.577,49,Female,Non
#
# 14501,8,1.94,59,Male,Non
#
# 14541,6,1.747,57.5,Male,Non
#
# 14601,9,2.069,58,Male,Non
#
# 14651,7,1.631,55.5,Female,Non
#
# 15153,5,1.536,52,Female,Non
#
# 15201,9,2.56,60.5,Female,Non
#
# 15241,8,1.962,57,Male,Non
#
# 15301,8,2.531,58,Female,Non
#
# 15401,9,2.715,60,Male,Non
#
# 15443,9,2.457,59,Male,Non
#
# 15601,9,2.09,59.5,Male,Non
#
# 15701,7,1.789,56,Male,Non
#
# 15741,5,1.858,53,Male,Non
#
# 15842,5,1.452,51,Male,Non
#
# 16101,9,3.842,69,Male,Non
#
# 16151,6,1.719,53,Female,Non
#
# 16251,7,2.111,57,Female,Non
#
# 16252,6,1.695,53,Female,Non
#
# 16501,8,2.211,63,Male,Non
#
# 16601,8,1.794,54.5,Male,Non
#
# 16651,7,1.917,58,Female,Non
#
# 18101,8,2.144,63,Female,Non
#
# 18501,7,1.253,52,Male,Non
#
# 18843,9,2.659,61.5,Male,Non
#
# 18844,5,1.58,52.5,Male,Non
#
# 19401,9,2.126,62,Male,Non
#
# 20152,9,3.029,61.5,Female,Non
#
# 20801,9,2.964,64.5,Male,Non
#
# 20841,7,1.611,57.5,Male,Non
#
# 21552,8,2.215,60,Female,Non
#
# 22201,8,2.388,60,Female,Non
#
# 22901,9,2.196,61,Male,Non
#
# 23101,9,1.751,58,Male,Non
#
# 23441,9,2.165,61.5,Male,Non
#
# 23442,7,1.682,55,Male,Non
#
# 23641,8,1.523,55,Male,Non
#
# 23653,8,1.292,52,Female,Non
#
# 23801,7,1.649,54,Male,Non
#
# 23802,9,2.588,63,Male,Non
#
# 23841,4,0.796,47,Male,Non
#
# 23902,9,2.574,60.5,Female,Non
#
# 23941,6,1.979,56,Male,Non
#
# 24401,8,2.354,58.5,Male,Non
#
# 24843,6,1.718,55,Male,Non
#
# 24851,7,1.742,58.5,Female,Non
#
# 25001,7,1.603,51,Female,Non
#
# 25052,8,2.639,59.5,Female,Non
#
# 25201,7,1.829,54,Female,Non
#
# 27001,7,2.084,58,Male,Non
#
# 27401,7,2.22,58,Male,Non
#
# 27952,7,1.473,52.5,Female,Non
#
# 28452,8,2.341,60.5,Female,Non
#
# 28501,7,1.698,54.5,Female,Non
#
# 28551,5,1.196,46.5,Female,Non
#
# 28801,8,1.872,56.5,Female,Non
#
# 29001,7,2.219,55,Male,Non
#
# 29101,9,2.42,57,Male,Non
#
# 29151,7,1.827,54.5,Female,Non
#
# 29401,7,1.461,54,Female,Non
#
# 29443,6,1.338,53,Male,Non
#
# 29601,8,2.09,57,Male,Non
#
# 29701,8,1.697,59,Female,Non
#
# 29741,8,1.562,55,Male,Non
#
# 29901,9,2.04,55.5,Female,Non
#
# 29954,7,1.609,51.5,Female,Non
#
# 30001,8,2.458,61,Female,Non
#
# 30043,9,2.65,63.5,Male,Non
#
# 31001,8,1.429,57.5,Male,Non
#
# 31501,8,1.675,53,Male,Non
#
# 31551,9,1.947,56.5,Female,Non
#
# 32501,8,2.069,54,Male,Non
#
# 32542,6,1.572,52,Male,Non
#
# 32742,6,1.348,53,Male,Non
#
# 32751,8,2.288,61.5,Female,Non
#
# 33301,9,1.773,58.5,Male,Non
#
# 33351,5,0.791,52,Female,Non
#
# 33501,7,1.905,58,Male,Non
#
# 33601,9,2.463,61,Female,Non
#
# 33641,6,1.431,51,Male,Non
#
# 33801,9,2.631,62,Female,Non
#
# 34101,9,3.114,64.5,Male,Non
#
# 34301,9,2.135,58.5,Male,Non
#
# 34341,6,1.527,52.5,Male,Non
#
# 35102,8,2.293,58,Female,Non
#
# 35103,9,3.042,66,Female,Non
#
# 35601,8,2.927,63.5,Male,Non
#
# 37201,8,2.665,64,Female,Non
#
# 37301,9,2.301,58.5,Male,Non
#
# 37901,9,2.46,64,Male,Non
#
# 38051,9,2.592,60.5,Female,Non
#
# 38152,7,1.75,55,Female,Non
#
# 38241,8,1.759,53,Male,Non
#
# 38242,6,1.536,48,Male,Non
#
# 38801,9,2.259,58.5,Female,Non
#
# 39001,9,2.048,64.5,Female,Non
#
# 39101,9,2.571,60.5,Male,Non
#
# 39141,7,2.046,56,Male,Non
#
# 39201,8,1.78,58.5,Female,Non
#
# 39251,5,1.552,54,Female,Non
#
# 39301,8,1.953,58,Female,Non
#
# 39401,9,2.893,64.5,Male,Non
#
# 39741,6,1.713,50.5,Male,Non
#
# 39801,9,2.851,60,Female,Non
#
# 39841,6,1.624,51.5,Male,Non
#
# 39901,8,2.631,59,Male,Non
#
# 39941,5,1.819,53,Male,Non
#
# 40001,7,1.658,53,Male,Non
#
# 40501,7,2.158,53.5,Male,Non
#
# 40541,4,1.789,52,Male,Non
#
# 42101,9,3.004,64,Female,Non
#
# 42201,8,2.503,63,Male,Non
#
# 42501,9,1.933,58,Female,Non
#
# 42552,9,2.091,58.5,Female,Non
#
# 42901,9,2.316,59.5,Female,Non
#
# 42941,5,1.704,51,Female,Non
#
# 43201,9,1.606,57.5,Female,Non
#
# 43242,7,1.165,47,Male,Non
#
# 43651,6,2.102,55.5,Female,Non
#
# 43901,9,2.32,57,Female,Non
#
# 44201,9,2.23,61,Male,Non
#
# 44301,9,1.716,55.5,Male,Non
#
# 44501,7,1.79,53.5,Male,Non
#
# 44551,5,1.146,50,Female,Non
#
# 44701,8,2.187,61.5,Female,Non
#
# 45001,9,2.717,61.5,Male,Non
#
# 45041,7,1.796,55,Male,Non
#
# 45241,9,1.953,58,Male,Current
#
# 45251,8,1.335,56.5,Female,Non
#
# 45301,9,2.119,57,Male,Non
#
# 45641,6,1.666,52,Male,Non
#
# 45642,6,1.826,52.5,Male,Non
#
# 45653,8,2.709,62.5,Female,Non
#
# 46101,9,2.871,65,Male,Non
#
# 46151,5,1.092,50,Female,Non
#
# 46641,6,2.262,57.5,Male,Non
#
# 46642,6,2.104,56.5,Male,Non
#
# 47001,9,2.166,57.5,Female,Non
#
# 47053,7,1.69,54,Female,Non
#
# 47242,9,2.973,59.5,Male,Non
#
# 47301,8,2.145,59.5,Female,Non
#
# 47341,5,1.971,58,Male,Non
#
# 47552,7,2.095,57,Female,Non
#
# 48052,6,1.697,55,Female,Non
#
# 48101,9,2.455,60,Female,Non
#
# 48401,7,1.92,56.5,Male,Non
#
# 48402,9,2.164,60,Male,Non
#
# 48901,9,2.13,59,Female,Non
#
# 49301,8,2.993,63,Female,Non
#
# 49401,9,2.529,59,Female,Non
#
# 49501,7,1.726,53,Female,Non
#
# 49542,9,2.442,61.5,Female,Non
#
# 49551,4,1.102,48,Female,Non
#
# 49701,9,2.056,63,Female,Non
#
# 49741,5,1.808,55.5,Male,Non
#
# 49751,8,2.305,64.5,Female,Non
#
# 50501,9,1.969,59,Female,Non
#
# 50701,8,1.556,58.5,Female,Non
#
# 50951,3,1.072,46,Female,Non
#
# 51241,9,2.042,62,Male,Non
#
# 51301,8,1.512,53,Female,Non
#
# 51341,6,1.423,49.5,Male,Non
#
# 51501,9,3.681,68,Male,Non
#
# 51542,8,1.991,59.5,Male,Non
#
# 52101,8,1.897,55.5,Male,Non
#
# 53601,7,1.37,55,Female,Non
#
# 53651,6,1.338,51.5,Female,Non
#
# 54201,8,2.016,56,Male,Non
#
# 54701,9,2.639,63,Female,Non
#
# 54751,4,1.389,48,Female,Non
#
# 54941,7,1.612,56.5,Male,Non
#
# 54952,8,2.135,59,Female,Non
#
# 55645,8,2.681,60.5,Male,Non
#
# 55652,9,3.223,65,Female,Non
#
# 57651,6,1.796,55,Female,Non
#
# 57901,8,2.01,55,Male,Non
#
# 58341,6,1.523,51,Female,Non
#
# 58601,8,1.744,52.5,Male,Non
#
# 58602,9,2.485,64,Female,Non
#
# 60051,8,2.335,59,Female,Non
#
# 60251,7,1.415,53.5,Female,Non
#
# 60801,9,2.076,60.5,Male,Non
#
# 61101,8,2.435,59.5,Male,Non
#
# 61601,7,1.728,56.5,Female,Non
#
# 61801,9,2.85,63,Female,Non
#
# 61901,8,1.844,56.5,Female,Non
#
# 62301,9,1.754,61.5,Female,Non
#
# 62351,6,1.343,52,Female,Non
#
# 62641,8,2.303,57,Male,Non
#
# 62702,9,2.246,63.5,Male,Non
#
# 63102,8,2.476,63,Female,Non
#
# 63201,9,3.239,65,Male,Non
#
# 63941,9,2.457,61.5,Male,Non
#
# 64101,8,2.382,62,Female,Non
#
# 64151,7,1.64,55,Female,Non
#
# 64152,5,1.589,51,Female,Non
#
# 64201,7,2.056,54,Male,Non
#
# 70001,8,2.226,57,Male,Non
#
# 70401,9,1.886,56,Female,Non
#
# 71101,9,2.833,61.5,Male,Non
#
# 71241,6,1.715,53,Male,Non
#
# 71401,8,2.631,59,Male,Non
#
# 71444,7,2.55,56,Male,Non
#
# 71851,9,1.912,59,Female,Non
#
# 72001,7,1.877,52.5,Female,Non
#
# 72051,7,1.935,52.5,Female,Non
#
# 72052,5,1.539,50,Female,Non
#
# 72501,9,2.803,59.5,Male,Non
#
# 73001,9,2.923,64,Male,Non
#
# 73151,8,2.358,61,Female,Non
#
# 73342,8,2.094,57.5,Male,Non
#
# 74201,9,1.855,60,Male,Non
#
# 74241,6,1.535,55,Female,Non
#
# 74401,7,2.135,56,Male,Non
#
# 74441,5,1.93,51,Male,Non
#
# 74601,9,2.182,59.5,Female,Non
#
# 74641,5,1.359,50.5,Male,Non
#
# 74652,7,2.002,57.5,Female,Non
#
# 74941,6,1.699,54,Male,Non
#
# 75701,8,2.5,57,Male,Non
#
# 75751,7,2.366,58,Female,Non
#
# 75901,8,2.069,60,Female,Non
#
# 75951,4,1.418,49,Female,Non
#
# 76501,8,2.333,57,Female,Non
#
# 76541,5,1.514,52,Male,Non
#
# 76751,8,1.758,52,Female,Non
#
# 77141,7,2.535,59.5,Male,Non
#
# 77901,7,2.564,58,Female,Non
#
# 78301,9,2.487,64,Female,Non
#
# 78352,9,1.591,57,Female,Non
#
# 80001,8,1.624,53,Male,Non
#
# 80301,9,2.798,62,Male,Non
#
# 80341,6,1.691,53,Male,Non
#
# 80601,8,1.999,56.5,Female,Non
#
# 80801,9,1.869,57,Male,Non
#
# 80841,4,1.004,48,Male,Non
#
# 81241,6,1.427,49.5,Male,Non
#
# 81401,7,1.826,51,Male,Non
#
# 81451,9,2.688,59.5,Female,Non
#
# 81501,8,1.657,56,Male,Non
#
# 81751,6,1.672,54,Female,Non
#
# 82701,8,2.015,57.5,Female,Non
#
# 83801,7,2.371,55.5,Female,Non
#
# 83841,5,2.115,50,Male,Non
#
# 83901,8,2.328,60,Female,Non
#
# 83952,7,1.495,57,Female,Non
#
# 201,11,2.884,69,Male,Non
#
# 202,10,2.328,64,Male,Non
#
# 341,14,3.381,63,Male,Non
#
# 351,11,2.17,58,Female,Non
#
# 401,11,3.47,66.5,Male,Non
#
# 551,12,3.058,60.5,Female,Non
#
# 601,10,1.811,57,Male,Non
#
# 641,11,2.524,64,Male,Non
#
# 1751,10,2.642,61,Female,Non
#
# 2041,14,3.741,68.5,Male,Non
#
# 2042,13,4.336,69.5,Male,Non
#
# 2142,14,4.842,72,Male,Non
#
# 2143,12,4.55,71,Male,Non
#
# 2451,12,2.841,63,Female,Non
#
# 2801,10,3.166,61.5,Female,Non
#
# 2851,13,3.816,63.5,Female,Non
#
# 3141,10,2.561,62,Male,Non
#
# 3501,11,3.654,65,Female,Non
#
# 3901,10,2.481,61,Male,Non
#
# 4001,11,2.665,63,Female,Non
#
# 4341,10,3.203,66,Male,Non
#
# 4901,13,3.549,68,Male,Non
#
# 4952,14,2.236,66,Female,Current
#
# 5001,11,3.222,72,Male,Non
#
# 5101,10,3.111,66,Male,Non
#
# 5251,11,3.49,67,Female,Non
#
# 5351,13,3.147,64,Female,Non
#
# 5352,10,2.52,60.5,Female,Non
#
# 5641,10,2.292,63,Male,Non
#
# 5701,12,2.889,64,Female,Non
#
# 6001,10,2.246,60.5,Male,Non
#
# 6041,10,1.937,62,Male,Non
#
# 6145,10,2.646,60,Male,Non
#
# 6201,11,2.957,64.5,Male,Non
#
# 6401,11,4.007,67,Male,Non
#
# 7101,11,2.386,61.5,Female,Non
#
# 7241,10,3.251,66,Male,Non
#
# 7901,11,2.762,60,Female,Non
#
# 8301,11,3.011,64,Female,Non
#
# 8541,13,4.305,68.5,Male,Non
#
# 8542,13,3.906,67,Male,Non
#
# 8842,11,3.583,67,Male,Non
#
# 8901,11,3.236,66,Female,Non
#
# 9141,14,3.436,62.5,Male,Non
#
# 9142,11,3.058,61,Male,Non
#
# 9502,10,3.007,62,Male,Non
#
# 9802,10,3.489,66.5,Male,Non
#
# 10001,10,2.864,60,Female,Non
#
# 10053,14,3.428,64,Female,Current
#
# 10054,13,2.819,62,Female,Non
#
# 10501,10,2.25,58,Female,Non
#
# 10642,14,4.683,68.5,Male,Non
#
# 10801,10,2.352,61.5,Male,Non
#
# 10901,11,3.108,64.5,Male,Non
#
# 10942,13,3.994,67,Male,Non
#
# 11101,12,4.393,68.5,Male,Non
#
# 11151,13,3.208,61,Female,Current
#
# 11301,10,2.592,65,Male,Non
#
# 11341,13,3.193,70,Male,Non
#
# 11601,11,1.694,60,Male,Current
#
# 11642,14,3.957,72,Male,Current
#
# 11901,11,2.346,59,Female,Non
#
# 11942,13,4.789,69,Male,Current
#
# 12501,11,3.515,67.5,Male,Non
#
# 13301,11,2.754,65.5,Female,Non
#
# 14001,10,2.72,65.5,Male,Non
#
# 14143,11,2.463,64.5,Male,Non
#
# 14401,11,2.633,62,Female,Non
#
# 15101,10,3.048,65.5,Female,Non
#
# 15141,11,3.111,67.5,Male,Non
#
# 15152,13,3.745,68,Female,Non
#
# 15302,12,2.384,63.5,Female,Current
#
# 15342,10,2.094,58.5,Male,Non
#
# 15451,10,3.183,65.5,Female,Non
#
# 15751,14,3.074,65,Female,Current
#
# 15801,11,3.977,70.5,Male,Non
#
# 15841,10,3.354,63,Male,Non
#
# 16201,11,3.411,63.5,Female,Non
#
# 16551,10,2.387,66,Female,Current
#
# 16901,11,3.171,63,Female,Non
#
# 16941,13,3.887,67.5,Male,Non
#
# 16951,13,2.646,61.5,Female,Non
#
# 16952,10,2.504,60,Female,Non
#
# 17301,11,3.587,64.5,Male,Non
#
# 17401,11,3.845,68.5,Male,Non
#
# 17801,12,2.971,64.5,Male,Non
#
# 17851,10,2.891,61,Female,Non
#
# 18502,10,1.823,57,Female,Non
#
# 18541,11,2.417,62.5,Male,Non
#
# 18551,10,2.175,58,Female,Non
#
# 18801,11,2.735,62.5,Female,Non
#
# 18841,14,4.273,72.5,Male,Non
#
# 18842,13,2.976,65.5,Male,Non
#
# 19601,12,3.835,69.5,Female,Current
#
# 19901,11,4.065,66.5,Male,Non
#
# 20101,11,2.318,59,Female,Non
#
# 21301,11,3.596,68,Male,Non
#
# 21352,14,3.395,67,Female,Non
#
# 21353,12,2.751,63,Female,Non
#
# 21501,10,2.673,64.5,Female,Non
#
# 22253,12,2.556,62,Female,Non
#
# 23151,11,2.542,62,Female,Non
#
# 23401,10,2.608,66,Male,Non
#
# 23601,11,2.354,62,Female,Non
#
# 23651,13,2.599,62.5,Female,Current
#
# 23652,10,1.458,57,Female,Non
#
# 23901,10,3.795,68.5,Male,Non
#
# 24201,11,2.491,59,Female,Non
#
# 24251,13,3.06,61.5,Female,Non
#
# 24501,10,2.545,65,Male,Non
#
# 24543,11,2.993,66.5,Male,Non
#
# 24601,10,3.305,65,Female,Non
#
# 24642,13,4.756,68,Male,Current
#
# 24701,11,3.774,67,Female,Non
#
# 24741,10,2.855,64.5,Male,Non
#
# 24801,11,2.988,70,Male,Non
#
# 25041,11,2.498,60,Male,Non
#
# 25051,14,3.169,64,Female,Non
#
# 25501,11,2.887,62.5,Male,Non
#
# 25551,13,2.704,61,Female,Non
#
# 25901,11,3.515,64,Female,Non
#
# 27441,11,3.425,65.5,Male,Non
#
# 27701,10,2.287,61,Female,Non
#
# 27751,13,2.434,65.4,Female,Non
#
# 27901,10,2.365,63.5,Female,Non
#
# 27951,13,3.086,67.5,Female,Current
#
# 28401,10,2.696,66,Male,Non
#
# 29952,12,2.868,62,Female,Non
#
# 29953,10,2.813,61.5,Female,Non
#
# 30042,14,4.309,69,Male,Current
#
# 30051,12,3.255,66,Female,Non
#
# 30052,10,3.413,66,Female,Current
#
# 30401,11,4.593,69,Male,Non
#
# 31042,14,4.111,71,Male,Non
#
# 31201,12,1.916,60.5,Male,Non
#
# 31242,10,1.858,58,Male,Non
#
# 31502,10,2.975,63,Female,Current
#
# 31901,10,3.35,69,Male,Non
#
# 32541,10,2.901,59.5,Male,Non
#
# 32701,12,2.241,64,Male,Non
#
# 32741,13,4.225,74,Male,Non
#
# 33001,11,3.223,64.5,Female,Non
#
# 33041,12,5.224,70,Male,Non
#
# 33502,11,4.073,67,Male,Non
#
# 33541,12,4.08,64.5,Male,Non
#
# 33701,11,2.606,65,Female,Non
#
# 34201,11,3.169,62.5,Female,Current
#
# 34243,12,4.411,68,Male,Non
#
# 35101,12,3.791,68.5,Male,Non
#
# 35901,13,3.089,67.5,Male,Non
#
# 35941,11,2.465,60,Male,Non
#
# 36001,12,3.343,68,Male,Current
#
# 36041,10,3.2,65,Male,Non
#
# 36101,12,2.913,64,Male,Non
#
# 37241,13,4.877,73,Male,Non
#
# 37351,10,2.358,59,Female,Non
#
# 37401,12,3.279,70.5,Male,Non
#
# 37701,10,2.581,66,Male,Non
#
# 37702,12,2.347,61.5,Female,Non
#
# 37951,10,2.691,67,Female,Non
#
# 38001,11,2.827,62.5,Female,Non
#
# 38201,10,1.873,52.5,Male,Non
#
# 39041,12,3.751,72,Male,Current
#
# 39052,14,2.538,71,Female,Non
#
# 39601,10,2.758,65.5,Male,Non
#
# 39701,10,3.05,60,Female,Non
#
# 40051,12,3.079,60,Female,Non
#
# 40301,10,2.201,60.5,Male,Non
#
# 41601,10,1.858,59,Male,Non
#
# 42151,13,2.216,68,Female,Current
#
# 42251,12,3.403,62,Female,Non
#
# 42301,12,3.501,64.5,Female,Non
#
# 42502,11,2.578,63,Female,Non
#
# 42551,13,3.078,66,Female,Current
#
# 43002,12,3.186,67,Female,Current
#
# 43241,10,1.665,57,Male,Non
#
# 43251,11,2.081,63,Female,Non
#
# 43301,11,2.974,62,Female,Non
#
# 43351,13,3.297,65,Female,Current
#
# 43601,12,4.073,68.5,Male,Non
#
# 43641,13,4.448,69,Male,Non
#
# 44242,13,3.984,71,Male,Non
#
# 44302,10,2.25,58,Female,Non
#
# 44351,12,2.752,63.5,Female,Non
#
# 44601,12,2.304,66.5,Male,Current
#
# 44742,14,3.68,67,Male,Non
#
# 45201,11,3.102,64,Female,Current
#
# 45601,10,2.862,61,Female,Non
#
# 45651,13,2.677,67,Female,Current
#
# 45652,11,3.023,67.5,Female,Non
#
# 46301,11,3.681,68,Female,Non
#
# 46353,13,3.255,66.5,Female,Non
#
# 46601,12,3.692,67,Male,Non
#
# 46651,10,2.356,60.5,Female,Non
#
# 46901,10,4.591,70,Male,Non
#
# 46951,12,3.082,63.5,Female,Non
#
# 47051,13,3.297,65,Female,Current
#
# 47052,11,3.258,63,Female,Non
#
# 47801,10,2.216,61,Male,Non
#
# 47841,11,3.247,65.5,Male,Non
#
# 48001,11,4.324,67.5,Male,Non
#
# 48142,11,2.362,61,Female,Non
#
# 48951,11,2.563,63,Female,Non
#
# 49201,11,3.206,63.5,Male,Non
#
# 49341,14,3.585,70,Male,Non
#
# 49342,12,4.72,71.5,Male,Non
#
# 49451,13,3.331,65.5,Female,Non
#
# 49541,13,5.083,74,Male,Non
#
# 50301,10,3.498,68,Male,Current
#
# 50551,12,2.417,61,Female,Non
#
# 50702,10,2.364,61,Male,Non
#
# 50901,10,2.341,61,Male,Non
#
# 51101,12,2.759,61.5,Female,Current
#
# 51201,11,2.953,67,Female,Current
#
# 51302,12,3.231,63,Male,Non
#
# 51541,11,3.078,67.5,Male,Non
#
# 51601,11,3.369,70.5,Male,Non
#
# 51641,12,3.529,70.5,Male,Non
#
# 52401,12,2.866,62,Female,Non
#
# 52452,14,2.891,62,Female,Non
#
# 52801,11,3.022,61.5,Female,Non
#
# 53101,10,3.127,62,Male,Non
#
# 53151,11,2.866,60.5,Female,Non
#
# 53301,12,2.605,62.5,Female,Non
#
# 54251,13,3.056,63,Female,Non
#
# 54901,12,2.569,63,Female,Non
#
# 54951,11,2.501,62,Female,Non
#
# 55601,11,3.32,65.5,Male,Non
#
# 55901,11,2.123,65,Male,Non
#
# 55941,14,3.78,70,Male,Non
#
# 56601,11,3.847,66,Male,Non
#
# 56651,13,3.785,63,Female,Current
#
# 56901,12,3.924,68,Male,Non
#
# 57001,10,2.132,59,Male,Non
#
# 57042,12,2.752,68.5,Male,Non
#
# 57053,13,2.449,63,Female,Non
#
# 57601,10,3.456,63,Male,Non
#
# 58301,10,3.073,66,Female,Non
#
# 58603,10,2.688,62,Female,Non
#
# 59901,10,3.329,68,Male,Non
#
# 59941,14,4.271,72.5,Male,Non
#
# 60001,12,3.53,64,Male,Non
#
# 60201,11,2.928,65.5,Male,Non
#
# 60851,11,2.689,61.5,Female,Non
#
# 61301,12,2.332,57,Male,Non
#
# 61351,14,2.934,64,Female,Non
#
# 61941,14,2.276,66,Male,Current
#
# 62601,10,3.11,64.5,Male,Non
#
# 62701,11,2.894,67,Male,Non
#
# 62801,11,4.637,72,Male,Current
#
# 62802,10,2.435,65,Female,Non
#
# 63101,10,2.838,63,Female,Non
#
# 63252,12,3.035,62,Female,Non
#
# 63901,12,4.831,71,Male,Non
#
# 64241,11,2.812,61,Male,Non
#
# 70051,12,2.714,65.5,Female,Non
#
# 70052,10,3.086,62,Female,Non
#
# 70201,12,3.519,65.5,Female,Non
#
# 70441,13,4.232,70.5,Male,Non
#
# 70442,10,2.77,62,Male,Non
#
# 71151,12,3.341,65.5,Female,Non
#
# 71201,10,3.09,65,Male,Non
#
# 71443,13,2.531,61,Male,Non
#
# 71801,12,2.822,69.5,Male,Non
#
# 72552,10,3.038,65,Female,Current
#
# 72901,12,2.935,65.5,Male,Non
#
# 73101,10,2.568,63.5,Female,Non
#
# 73301,11,2.387,60.5,Male,Non
#
# 73341,12,2.499,65,Male,Non
#
# 73701,11,4.13,67,Male,Non
#
# 74651,12,3.001,63.5,Female,Non
#
# 74701,10,3.132,59.5,Female,Non
#
# 74751,13,3.577,63.5,Female,Non
#
# 74752,12,3.222,61,Female,Non
#
# 74901,11,3.28,66,Male,Non
#
# 75801,11,2.659,64,Male,Non
#
# 76601,11,2.822,62,Female,Non
#
# 76701,11,2.14,60.5,Female,Non
#
# 77101,12,4.203,71,Male,Non
#
# 77152,14,2.997,64.5,Female,Non
#
# 77501,11,3.12,61,Female,Current
#
# 77601,11,2.562,62.5,Female,Non
#
# 80051,12,3.082,64.5,Female,Non
#
# 80641,14,3.806,68,Male,Non
#
# 80642,11,3.339,68.5,Male,Current
#
# 80651,13,3.152,62,Female,Current
#
# 81201,11,2.458,60,Female,Non
#
# 81541,10,2.391,59.5,Male,Non
#
# 81551,13,3.141,61,Female,Non
#
# 81552,12,2.579,63,Female,Non
#
# 81701,11,3.104,67.5,Female,Current
#
# 81741,13,4.045,69,Male,Current
#
# 82743,14,4.763,68,Male,Current
#
# 82744,10,2.1,58,Male,Non
#
# 83951,11,3.069,65,Female,Current
#
# 90001,11,2.785,69,Male,Non
#
# 441,15,4.284,70,Male,Non
#
# 4041,15,4.506,71,Male,Current
#
# 4051,18,2.906,66,Female,Non
#
# 6144,19,5.102,72,Male,Non
#
# 6252,19,3.519,66,Female,Current
#
# 6441,16,3.688,68,Male,Current
#
# 7142,17,4.429,70,Male,Non
#
# 8841,15,4.279,67.5,Male,Non
#
# 10941,15,4.5,70,Male,Non
#
# 15351,15,2.635,64,Female,Non
#
# 15752,15,2.679,66,Female,Current
#
# 20151,15,2.198,62,Female,Current
#
# 21351,19,3.345,65.5,Female,Current
#
# 22251,18,3.082,64.5,Female,Non
#
# 22252,16,3.387,66.5,Female,Non
#
# 24541,17,3.082,67,Male,Current
#
# 24552,16,2.903,63,Female,Current
#
# 24553,15,3.004,64,Female,Current
#
# 25941,15,5.793,69,Male,Non
#
# 30041,15,3.985,71,Male,Non
#
# 30441,18,4.22,68,Male,Non
#
# 30442,17,4.724,70.5,Male,Non
#
# 33741,15,3.731,67,Male,Non
#
# 34241,17,3.406,69,Male,Current
#
# 37251,17,3.5,62,Female,Non
#
# 37252,16,3.674,67.5,Female,Non
#
# 37441,17,5.633,73,Male,Non
#
# 37451,15,3.122,64,Female,Current
#
# 39051,15,3.33,68.5,Female,Current
#
# 40351,16,2.608,62,Female,Current
#
# 44241,16,3.645,73.5,Male,Non
#
# 47241,15,3.799,66.5,Male,Current
#
# 48141,18,4.086,67,Male,Current
#
# 48152,15,2.887,63,Female,Non
#
# 48441,16,4.07,69.5,Male,Current
#
# 52841,17,3.96,70,Male,Non
#
# 52842,16,4.299,66,Male,Non
#
# 55951,16,2.981,66,Female,Non
#
# 57052,15,2.264,63,Female,Current
#
# 59944,18,4.404,70.5,Male,Current
#
# 61951,15,2.278,60,Female,Current
#
# 63241,16,4.504,72,Male,Non
#
# 71141,17,5.638,70,Male,Non
#
# 71142,16,4.872,72,Male,Current
#
# 73041,16,4.27,67,Male,Current
#
# 73042,15,3.727,68,Male,Current
#
# 73751,18,2.853,60,Female,Non
#
# 75852,16,2.795,63,Female,Current
#
# 77151,15,3.211,66.5,Female,Non

# %%
b1000
# Out:
# b'Id,Age,FEV,Height,Sex,Smoker\n301,9,1.708,57,Female,Non\n451,8,1.724,67.5,Female,Non\n501,7,1.72,54.5,Female,Non\n642,9,1.558,53,Male,Non\n901,9,1.895,57,Male,Non\n1701,8,2.336,61,Female,Non\n1752,6,1.919,58,Female,Non\n1753,6,1.415,56,Female,Non\n1901,8,1.987,58.5,Female,Non\n1951,9,1.942,60,Female,Non\n1952,6,1.602,53,Female,Non\n2001,8,1.735,54,Male,Non\n2101,8,2.193,58.5,Female,Non\n2401,8,2.118,60.5,Male,Non\n3102,8,2.258,58,Male,Non\n3142,7,1.932,53,Male,Non\n3541,5,1.472,50,Male,Non\n3551,6,1.878,53,Female,Non\n4201,9,2.352,59,Male,Non\n4301,9,2.604,61.5,Male,Non\n4351,5,1.4,49,Female,Non\n5151,5,1.256,52.5,Female,Non\n5152,4,0.839,48,Female,Non\n5201,7,2.578,62.5,Male,Non\n5601,9,2.988,65,Female,Non\n5642,3,1.404,51.5,Male,Non\n5702,9,2.348,60,Male,Non\n6042,5,1.755,52,Male,Non\n6101,8,2.98,60,Female,Non\n6801,9,2.1,60,Female,Non\n6851,5,1.282,49,Female,Non\n7201,9,3,65.5,Male,Non\n7251,8,2.673,60,Female,Non\n7252,7,2.093,57.5,Female,Non\n7253,5,1.612,52,Female,Non\n8501,8,2.175,59,Female,Non\n8801,9,2.725,59,Male'

# %% [markdown]
# # Downloading a File

# %%
s3 = boto3.resource('s3')
bucketname ='tests3csv'
s3.Bucket(bucketname).download_file('smoking.csv', 'smoking_new.csv')

# %% [markdown]
# # Writing Data To a Bucket

# %%
some_binary_data = b'Here we have some data'
more_binary_data = b'Here we have some more data'

# %% [markdown]
# # Method 1: Object.put() - some binary data in the interpreter or IDE

# %%
s3 = boto3.resource('s3')
object = s3.Object('tests3csv', 'some_binary_data.txt')
object.put(Body=some_binary_data)
# Out:
# {'ResponseMetadata': {'RequestId': 'TSDPK0Y2QN5NECDZ',
#   'HostId': '1GTTuhVsee+a0N2Yc5i2meKWSHbB+hd03Uj2G7RXKl5MQEvHlipWhbZltJL50a60DWchSv9UKrc=',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2': '1GTTuhVsee+a0N2Yc5i2meKWSHbB+hd03Uj2G7RXKl5MQEvHlipWhbZltJL50a60DWchSv9UKrc=',
#    'x-amz-request-id': 'TSDPK0Y2QN5NECDZ',
#    'date': 'Tue, 08 Jun 2021 06:54:16 GMT',
#    'etag': '"686fe502441525967f82cad39746b385"',
#    'content-length': '0',
#    'server': 'AmazonS3'},
#   'RetryAttempts': 0},
#  'ETag': '"686fe502441525967f82cad39746b385"'}

# %% [markdown]
# # Method 2: Client.put_object() -- Some existing file or object

# %%
client = boto3.client('s3')
client.put_object(Body=more_binary_data, Bucket='tests3csv', Key='test1.txt')
# Out:
# {'ResponseMetadata': {'RequestId': 'TSDY03333NQBKTEH',
#   'HostId': 'BClGNX+0+fMY8Vz0YHTF/8v//tw4MlBcyKTsiHLRg4Wq7xq5ORVVhnF9d/g9+Bz6GrJeUL1QzBA=',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2': 'BClGNX+0+fMY8Vz0YHTF/8v//tw4MlBcyKTsiHLRg4Wq7xq5ORVVhnF9d/g9+Bz6GrJeUL1QzBA=',
#    'x-amz-request-id': 'TSDY03333NQBKTEH',
#    'date': 'Tue, 08 Jun 2021 06:54:16 GMT',
#    'etag': '"7ee61533af4316840a03e5b59f4a5bea"',
#    'content-length': '0',
#    'server': 'AmazonS3'},
#   'RetryAttempts': 0},
#  'ETag': '"7ee61533af4316840a03e5b59f4a5bea"'}
