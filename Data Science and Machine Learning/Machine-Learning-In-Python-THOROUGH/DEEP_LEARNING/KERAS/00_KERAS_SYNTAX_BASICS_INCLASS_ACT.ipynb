# %% [markdown]
# # 00 KERAS SYNTAX BASICS INCLASS ACT

# %%
import pandas as pd

# %%
df=pd.read_csv("fake_reg.csv")

# %%
df.head()
# Out:
#         price     feature1     feature2
# 0  461.527929   999.787558   999.766096
# 1  548.130011   998.861615  1001.042403
# 2  410.297162  1000.070267   998.844015
# 3  540.382220   999.952251  1000.440940
# 4  546.024553  1000.446011  1000.338531

# %%
df.shape
# Out:
# (1000, 3)

# %%
df.isnull().sum().any()
# Out:
# False

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.pairplot(df)

# %%
df.corr()
# Out:
#              price  feature1  feature2
# price     1.000000  0.444190  0.907576
# feature1  0.444190  1.000000  0.030607
# feature2  0.907576  0.030607  1.000000

# %%
from sklearn.model_selection import train_test_split

# %%
X = df[["feature1", "feature2"]].values

# %%
y=df["price"].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=42)

# %%
X_train.shape
# Out:
# (700, 2)

# %%
X_train
# Out:
# array([[1001.63407565,  998.80950388],
#        [ 999.76150137,  998.41802414],
#        [ 998.2638401 , 1000.92030063],
#        ...,
#        [1000.47386523, 1001.44542815],
#        [ 998.8625673 ,  999.15662112],
#        [1000.55690247,  999.35441706]])

# %% [markdown]
# ## SCALING DATA

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler2 = MinMaxScaler()

# %%
scaler2.fit(X_train)
# Out:
# MinMaxScaler()

# %%
X_train = scaler2.transform(X_train)

# %%
X_test = scaler2.transform(X_test)

# %%
X_train.min()
# Out:
# 0.0

# %%
X_train.max()
# Out:
# 1.0

# %% [markdown]
# TensorFlow Syntax:
#
# (use %tensorflow_version 1.x to use old versions of tf)

# %%
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.4.0'

# %%
from tensorflow.keras.models import Sequential

# %%
from tensorflow.keras.layers import Dense, Activation

# %%
model6 = Sequential()
model6.add(Dense(4, input_dim=2, activation="relu"))           #input_dim = 2  or input_dim = X_train.shape[0]
model6.add(Dense(4, activation="relu"))
model6.add(Dense(2, activation="relu"))
model6.add(Dense(1))
model6.compile(optimizer="rmsprop", loss="mse")

# %%
model6.fit(X_train, y_train, batch_size = 16, epochs = 250)
# Out:
# Epoch 1/250
# 44/44 [==============================] - 3s 4ms/step - loss: 253204.6073
# Epoch 2/250
# 44/44 [==============================] - 0s 4ms/step - loss: 250053.3611
# Epoch 3/250
# 44/44 [==============================] - 0s 4ms/step - loss: 250125.6344
# Epoch 4/250
# 44/44 [==============================] - 0s 4ms/step - loss: 253022.1243
# Epoch 5/250
# 44/44 [==============================] - 0s 4ms/step - loss: 255729.0201
# Epoch 6/250
# 44/44 [==============================] - 0s 4ms/step - loss: 256092.5424
# Epoch 7/250
# 44/44 [==============================] - 0s 4ms/step - loss: 258163.9101
# Epoch 8/250
# 44/44 [==============================] - 0s 4ms/step - loss: 261422.6149
# Epoch 9/250
# 44/44 [==============================] - 0s 4ms/step - loss: 254437.9990
# Epoch 10/250
# 44/44 [==============================] - 0s 4ms/step - loss: 254975.4965: 0s - loss: 25486
# Epoch 11/250
# 44/44 [==============================] - 0s 4ms/step - loss: 250510.3347
# Epoch 12/250
# 44/44 [==============================] - 0s 4ms/step - loss: 249437.3788
# Epoch 13/250
# 44/44 [==============================] - 0s 4ms/step - loss: 247853.5924
# Epoch 14/250
# 44/44 [==============================] - 0s 4ms/step - loss: 255379.5931
# 44/44 [==============================] - 0s 6ms/step - loss: 24.8708
# Epoch 244/250
# 44/44 [==============================] - 0s 4ms/step - loss: 23.5455
# Epoch 245/250
# 44/44 [==============================] - 0s 5ms/step - loss: 23.5131
# Epoch 246/250
# 44/44 [==============================] - 0s 7ms/step - loss: 26.0268
# Epoch 247/250
# 44/44 [==============================] - 0s 5ms/step - loss: 26.8006
# Epoch 248/250
# 44/44 [==============================] - 0s 5ms/step - loss: 26.3125
# Epoch 249/250
# 44/44 [==============================] - 0s 6ms/step - loss: 24.3861
# Epoch 250/250
# 44/44 [==============================] - 0s 6ms/step - loss: 23.6183

# %%
model6.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 4)                 12
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 20
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 10
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 3
# =================================================================
# Total params: 45
# Trainable params: 45
# Non-trainable params: 0
# _________________________________________________________________

# %%
loss_df=pd.DataFrame(model6.history.history)

# %%
loss_df.plot()
# Out:
# <AxesSubplot:>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
loss = model6.history.history['loss']
sns.lineplot(x=range(len(loss)),y=loss)
plt.title("Training Loss per Epoch");

# %%
fig, ax= plt.subplots()
ax.plot(loss_df)
ax.set_xlabel("epoch")
ax.set_ylabel("loss")
ax.set_title("loss - epoch graph")
ax.set_xlim([0,250]) # focusing on the given x values
ax.set_ylim([0,50]) # focusing on the given y values
# Out:
# (0.0, 50.0)

# %%
loss_df.loss.idxmin()
# Out:
# 213

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import numpy as np

# %%
def eval_metrics(actual, pred):
    rmse = np.sqrt(mean_squared_error(actual, pred))
    mae = mean_absolute_error(actual, pred)
    mse = mean_squared_error(actual, pred)
    score = r2_score(actual, pred)
    return print("r2_score:", score, "\n","mae:", mae, "\n","mse:",mse, "\n","rmse:",rmse)

# %%
y_pred = model6.predict(X_test)

# %%
eval_metrics(y_test, y_pred)
# Out:
# r2_score: 0.9968071650619934
#  mae: 4.302461497556691
#  mse: 28.071505877390432
#  rmse: 5.298254984180209

# %%
y_test.shape
# Out:
# (300,)

# %%
y_pred.shape
# Out:
# (300, 1)

# %%
my_dict={"Actual":y_test, "Pred":y_pred.reshape(300,)}
compare=pd.DataFrame(my_dict)

# %%
compare.sample(5)
# Out:
#          Actual        Pred
# 245  515.778446  520.496643
# 202  524.967029  524.145935
# 67   531.482372  539.625488
# 230  325.794803  328.192810
# 15   429.214520  438.714172

# %% [markdown]
# ### SECTION 2

# %%
model6.evaluate(X_train, y_train, verbose=0)
# Out:
# 25.46002197265625

# %%
model6.evaluate(X_test, y_test, verbose=0)
# Out:
# 28.071500778198242

# %%
import seaborn as sns

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x="Actual", y="Pred", data=compare)
# Out:
# <AxesSubplot:xlabel='Actual', ylabel='Pred'>

# %% [markdown]
# ## MAKING PREDICTIONS WITH MODEL

# %%
df.head()
# Out:
#         price     feature1     feature2
# 0  461.527929   999.787558   999.766096
# 1  548.130011   998.861615  1001.042403
# 2  410.297162  1000.070267   998.844015
# 3  540.382220   999.952251  1000.440940
# 4  546.024553  1000.446011  1000.338531

# %%
new_data =[[999, 1001]]

# %%
new_data=scaler2.transform(new_data)

# %%
new_data
# Out:
# array([[0.30608328, 0.71932348]])

# %%
model6.predict(new_data)[0][0]
# Out:
# 549.99805

# %% [markdown]
# ## SAVING AND LOADING THE MODEL

# %%
from tensorflow.keras.models import load_model

# %%
model6.save("my_model.h5")

# %%
loaded_model=load_model("my_model.h5")

# %%
new_data
# Out:
# array([[0.30608328, 0.71932348]])

# %%
loaded_model.predict(new_data)
# Out:
# array([[549.99805]], dtype=float32)
