# %%
import sys, os
sys.path.insert(0, os.path.join(os.pardir, 'src'))
import sympy as sym
from approx1D import least_squares_orth, comparison_plot
import matplotlib.pyplot as plt
x = sym.Symbol('x')

def efficient(f, B, s, Omega, N=10, basis='a'):
    u = B
    for i in range(N+1):
        if basis == 'a':
            psi = [sym.sin((i+1)*x)]
        elif basis == 'b':
            psi = [sym.sin((2*i+1)*x)]
        elif basis == 'c':
            psi = [sym.sin(2*(i+1)*x)]
        next_term, c = least_squares_orth(f-B, psi, Omega, False)
        u = u + next_term
        # Make only plot for i even
        if i % 2 == 0:
            comparison_plot(f, u, Omega, 'tmp_sin%02dx' % i,
                            legend_loc='upper left', show=False,
                            plot_title='s=%g, i=%d' % (s, i))


if __name__ == '__main__':
    s = 20  # steepness
    f = sym.tanh(s*(x-sym.pi))
    from math import pi
    Omega = [0, 2*pi]  # sym.pi did not work here

    # sin((i+1)*x) basis
    xL = Omega[0]
    xR = Omega[1]
    B = ((xR-x)*f.subs(x, xL) + (x-xL)*f.subs(x, xR))/(xR-xL)
    for exercise in 'a', 'b', 'c':
        efficient(f, B, s, Omega, N=16, basis=exercise)
        # Make movie
        cmd = 'convert -delay 200 tmp_sin*.png '
        cmd += 'tanh_sines_boundary_term_%s.gif' % exercise
        os.system(cmd)
        # Make static plots, 3 figures on 2 lines
        for ext in 'pdf', 'png':
            cmd = 'doconce combine_images %s -3 ' % ext
            cmd += 'tmp_sin00x tmp_sin02x tmp_sin04x tmp_sin08x '
            cmd += 'tmp_sin12x tmp_sin16x '
            cmd += 'tanh_sines_boundary_term_%s' % exercise
            os.system(cmd)
# Out:
# ...evaluating matrix... (0,0)
# numerical integration of (-0.159154943091895*x*tanh(125.663706143592 - 20*pi) + 0.159154943091895*(6.28318530717959 - x)*tanh(20*pi) + tanh(20*x - 20*pi))*sin(x)
# A:
#  [3.14159265358979]
# b:
#  [mpf('-1.9978630074249364')]
# coeff: [mpf('-0.63593954650423723')]
# approximation: -0.635939546504237*sin(x)
# f: tanh(20*x - 20*pi)
# u: 0.159154943091895*x*tanh(125.663706143592 - 20*pi) - 0.159154943091895*(6.28318530717959 - x)*tanh(20*pi) - 0.635939546504237*sin(x)
# ...evaluating matrix... (0,0)
# numerical integration of (-0.159154943091895*x*tanh(125.663706143592 - 20*pi) + 0.159154943091895*(6.28318530717959 - x)*tanh(20*pi) + tanh(20*x - 20*pi))*sin(2*x)
# A:
#  [3.14159265358979]
# b:
#  [mpf('0.99573435649846787')]
# coeff: [mpf('0.31695208968631738')]
# approximation: 0.316952089686317*sin(2*x)
# ...evaluating matrix... (0,0)
# numerical integration of (-0.159154943091895*x*tanh(125.663706143592 - 20*pi) + 0.159154943091895*(6.28318530717959 - x)*tanh(20*pi) + tanh(20*x - 20*pi))*sin(3*x)
# A:
#  [3.14159265358979]
# b:
#  [mpf('-0.66028893791935028')]
# coeff: [mpf('-0.21017649667752442')]
# approximation: -0.210176496677524*sin(3*x)
# f: tanh(20*x - 20*pi)
# u: 0.159154943091895*x*tanh(125.663706143592 - 20*pi) - 0.159154943091895*(6.28318530717959 - x)*tanh(20*pi) - 0.635939546504237*sin(x) + 0.316952089686317*sin(2*x) - 0.210176496677524*sin(3*x)
# ...evaluating matrix... (0,0)
# numerical integration of (-0.159154943091895*x*tanh(125.663706143592 - 20*pi) + 0.159154943091895*(6.28318530717959 - x)*tanh(20*pi) + tanh(20*x - 20*pi))*sin(4*x)
# A:
#  [3.14159265358979]
# b:
#  [mpf('0.49153474347489984')]
# coeff: [mpf('0.15646036825087412')]
# approximation: 0.156460368250874*sin(4*x)
# ...evaluating matrix... (0,0)
# numerical integration of (-0.159154943091895*x*tanh(125.663706143592 - 20*pi) + 0.159154943091895*(6.28318530717959 - x)*tanh(20*pi) + tanh(20*x - 20*pi))*sin(5*x)
# A:
#  [3.14159265358979]
# b:
#  [mpf('-0.38947942392209106')]
# coeff: [mpf('-0.12397515109956916')]
# approximation: -0.123975151099569*sin(5*x)
# f: tanh(20*x - 20*pi)
# u: 0.159154943091895*x*tanh(125.663706143592 - 20*pi) - 0.159154943091895*(6.28318530717959 - x)*tanh(20*pi) - 0.635939546504237*sin(x) + 0.316952089686317*sin(2*x) - 0.210176496677524*sin(3*x) + 0.156460368250874*sin(4*x) - 0.123975151099569*sin(5*x)
# ...evaluating matrix... (0,0)
# numerical integration of (-0.159154943091895*x*tanh(125.663706143592 - 20*pi) + 0.159154943091895*(6.28318530717959 - x)*tanh(20*pi) + tanh(20*x - 20*pi))*sin(6*x)
# A:
#  [3.14159265358979]
# b:
#  [mpf('0.3207968553072772')]
# coeff: [mpf('0.10211281050097737')]
# approximation: 0.102112810500977*sin(6*x)
# ...evaluating matrix... (0,0)
# numerical integration of (-0.159154943091895*x*tanh(125.663706143592 - 20*pi) + 0.159154943091895*(6.28318530717959 - x)*tanh(20*pi) + tanh(20*x - 20*pi))*sin(7*x)
# A:
#  [3.14159265358979]
# b:
#  [mpf('-0.27120800166853598')]
# coeff: [mpf('-0.086328188143244999')]
# approximation: -0.086328188143245*sin(7*x)
# f: tanh(20*x - 20*pi)
# u: 0.159154943091895*x*tanh(125.663706143592 - 20*pi) - 0.159154943091895*(6.28318530717959 - x)*tanh(20*pi) - 0.635939546504237*sin(x) + 0.316952089686317*sin(2*x) - 0.210176496677524*sin(3*x) + 0.156460368250874*sin(4*x) - 0.123975151099569*sin(5*x) + 0.102112810500977*sin(6*x) - 0.086328188143245*sin(7*x)
# ...evaluating matrix... (0,0)
# numerical integration of (-0.159154943091895*x*tanh(125.663706143592 - 20*pi) + 0.159154943091895*(6.28318530717959 - x)*tanh(20*pi) + tanh(20*x - 20*pi))*sin(8*x)
# A:
#  [3.14159265358979]
# b:
#  [mpf('0.23357607590020127')]
# coeff: [mpf('0.074349574135049515')]
# approximation: 0.0743495741350495*sin(8*x)
# ...evaluating matrix... (0,0)
# numerical integration of (-0.159154943091895*x*tanh(125.663706143592 - 20*pi) + 0.159154943091895*(6.28318530717959 - x)*tanh(20*pi) + tanh(20*x - 20*pi))*sin(9*x)
# A:
#  [3.14159265358979]
# b:
#  [mpf('-0.20393822227530742')]
# coeff: [mpf('-0.064915552320977704')]
# approximation: -0.0649155523209777*sin(9*x)
# f: tanh(20*x - 20*pi)
# u: 0.159154943091895*x*tanh(125.663706143592 - 20*pi) - 0.159154943091895*(6.28318530717959 - x)*tanh(20*pi) - 0.635939546504237*sin(x) + 0.316952089686317*sin(2*x) - 0.210176496677524*sin(3*x) + 0.156460368250874*sin(4*x) - 0.123975151099569*sin(5*x) + 0.102112810500977*sin(6*x) - 0.086328188143245*sin(7*x) + 0.0743495741350495*sin(8*x) - 0.0649155523209777*sin(9*x)
# ...evaluating matrix... (0,0)
# numerical integration of (-0.159154943091895*x*tanh(125.663706143592 - 20*pi) + 0.159154943091895*(6.28318530717959 - x)*tanh(20*pi) + tanh(20*x - 20*pi))*sin(10*x)
# A:
#  [3.14159265358979]
# b:
#  [mpf('0.17991816581202025')]
# coeff: [mpf('0.057269730882020545')]
# approximation: 0.0572697308820205*sin(10*x)
# ...evaluating matrix... (0,0)
# numerical integration of (-0.159154943091895*x*tanh(125.663706143592 - 20*pi) + 0.159154943091895*(6.28318530717959 - x)*tanh(20*pi) + tanh(20*x - 20*pi))*sin(11*x)
# A:
#  [3.14159265358979]
# b:
#  [mpf('-0.16000467718241157')]
# coeff: [mpf('-0.050931070582807589')]
# approximation: -0.0509310705828076*sin(11*x)
# f: tanh(20*x - 20*pi)
# u: 0.159154943091895*x*tanh(125.663706143592 - 20*pi) - 0.159154943091895*(6.28318530717959 - x)*tanh(20*pi) - 0.635939546504237*sin(x) + 0.316952089686317*sin(2*x) - 0.210176496677524*sin(3*x) + 0.156460368250874*sin(4*x) - 0.123975151099569*sin(5*x) + 0.102112810500977*sin(6*x) - 0.086328188143245*sin(7*x) + 0.0743495741350495*sin(8*x) - 0.0649155523209777*sin(9*x) + 0.0572697308820205*sin(10*x) - 0.0509310705828076*sin(11*x)
# ...evaluating matrix... (0,0)
# numerical integration of (-0.159154943091895*x*tanh(125.663706143592 - 20*pi) + 0.159154943091895*(6.28318530717959 - x)*tanh(20*pi) + tanh(20*x - 20*pi))*sin(12*x)
# A:
#  [3.14159265358979]
# b:
#  [mpf('0.14319080237459844')]
# coeff: [mpf('0.045579048006424094')]
# approximation: 0.0455790480064241*sin(12*x)
# ...evaluating matrix... (0,0)
# numerical integration of (-0.159154943091895*x*tanh(125.663706143592 - 20*pi) + 0.159154943091895*(6.28318530717959 - x)*tanh(20*pi) + tanh(20*x - 20*pi))*sin(13*x)
# A:
#  [3.14159265358979]
# b:
#  [mpf('-0.12877960618578957')]
# coeff: [mpf('-0.040991821787792065')]
# approximation: -0.0409918217877921*sin(13*x)
# f: tanh(20*x - 20*pi)
# u: 0.159154943091895*x*tanh(125.663706143592 - 20*pi) - 0.159154943091895*(6.28318530717959 - x)*tanh(20*pi) - 0.635939546504237*sin(x) + 0.316952089686317*sin(2*x) - 0.210176496677524*sin(3*x) + 0.156460368250874*sin(4*x) - 0.123975151099569*sin(5*x) + 0.102112810500977*sin(6*x) - 0.086328188143245*sin(7*x) + 0.0743495741350495*sin(8*x) - 0.0649155523209777*sin(9*x) + 0.0572697308820205*sin(10*x) - 0.0509310705828076*sin(11*x) + 0.0455790480064241*sin(12*x) - 0.0409918217877921*sin(13*x)
# ...evaluating matrix... (0,0)
# numerical integration of (-0.159154943091895*x*tanh(125.663706143592 - 20*pi) + 0.159154943091895*(6.28318530717959 - x)*tanh(20*pi) + tanh(20*x - 20*pi))*sin(14*x)
# A:
#  [3.14159265358979]
# b:
#  [mpf('0.11627317836055381')]
# coeff: [mpf('0.037010902170175476')]
# approximation: 0.0370109021701755*sin(14*x)
# ...evaluating matrix... (0,0)
# numerical integration of (-0.159154943091895*x*tanh(125.663706143592 - 20*pi) + 0.159154943091895*(6.28318530717959 - x)*tanh(20*pi) + tanh(20*x - 20*pi))*sin(15*x)
# A:
#  [3.14159265358979]
# b:
#  [mpf('-0.10530605093954316')]
# coeff: [mpf('-0.033519957089030446')]
# approximation: -0.0335199570890304*sin(15*x)
# f: tanh(20*x - 20*pi)
# u: 0.159154943091895*x*tanh(125.663706143592 - 20*pi) - 0.159154943091895*(6.28318530717959 - x)*tanh(20*pi) - 0.635939546504237*sin(x) + 0.316952089686317*sin(2*x) - 0.210176496677524*sin(3*x) + 0.156460368250874*sin(4*x) - 0.123975151099569*sin(5*x) + 0.102112810500977*sin(6*x) - 0.086328188143245*sin(7*x) + 0.0743495741350495*sin(8*x) - 0.0649155523209777*sin(9*x) + 0.0572697308820205*sin(10*x) - 0.0509310705828076*sin(11*x) + 0.0455790480064241*sin(12*x) - 0.0409918217877921*sin(13*x) + 0.0370109021701755*sin(14*x) - 0.0335199570890304*sin(15*x)
# ...evaluating matrix... (0,0)
# numerical integration of (-0.159154943091895*x*tanh(125.663706143592 - 20*pi) + 0.159154943091895*(6.28318530717959 - x)*tanh(20*pi) + tanh(20*x - 20*pi))*sin(16*x)
# A:
#  [3.14159265358979]
# b:
#  [mpf('0.095603600195174651')]
# coeff: [mpf('0.030431571096886673')]
# approximation: 0.0304315710968867*sin(16*x)
# ...evaluating matrix... (0,0)
# numerical integration of (-0.159154943091895*x*tanh(125.663706143592 - 20*pi) + 0.159154943091895*(6.28318530717959 - x)*tanh(20*pi) + tanh(20*x - 20*pi))*sin(17*x)
# A:
#  [3.14159265358979]
# b:
#  [mpf('-0.086955147592525817')]
# coeff: [mpf('-0.027678683133271612')]
# approximation: -0.0276786831332716*sin(17*x)
# f: tanh(20*x - 20*pi)
# u: 0.159154943091895*x*tanh(125.663706143592 - 20*pi) - 0.159154943091895*(6.28318530717959 - x)*tanh(20*pi) - 0.635939546504237*sin(x) + 0.316952089686317*sin(2*x) - 0.210176496677524*sin(3*x) + 0.156460368250874*sin(4*x) - 0.123975151099569*sin(5*x) + 0.102112810500977*sin(6*x) - 0.086328188143245*sin(7*x) + 0.0743495741350495*sin(8*x) - 0.0649155523209777*sin(9*x) + 0.0572697308820205*sin(10*x) - 0.0509310705828076*sin(11*x) + 0.0455790480064241*sin(12*x) - 0.0409918217877921*sin(13*x) + 0.0370109021701755*sin(14*x) - 0.0335199570890304*sin(15*x) + 0.0304315710968867*sin(16*x) - 0.0276786831332716*sin(17*x)
# ...evaluating matrix... (0,0)
# numerical integration of (-0.159154943091895*x*tanh(125.663706143592 - 20*pi) + 0.159154943091895*(6.28318530717959 - x)*tanh(20*pi) + tanh(20*x - 20*pi))*sin(x)
# A:
#  [3.14159265358979]
# b:
#  [mpf('-1.9978630074249364')]
# coeff: [mpf('-0.63593954650423723')]
# approximation: -0.635939546504237*sin(x)
# f: tanh(20*x - 20*pi)
# u: 0.159154943091895*x*tanh(125.663706143592 - 20*pi) - 0.159154943091895*(6.28318530717959 - x)*tanh(20*pi) - 0.635939546504237*sin(x)
# ...evaluating matrix... (0,0)
# numerical integration of (-0.159154943091895*x*tanh(125.663706143592 - 20*pi) + 0.159154943091895*(6.28318530717959 - x)*tanh(20*pi) + tanh(20*x - 20*pi))*sin(3*x)
# A:
#  [3.14159265358979]
# b:
#  [mpf('-0.66028893791935028')]
# coeff: [mpf('-0.21017649667752442')]
# approximation: -0.210176496677524*sin(3*x)
# ...evaluating matrix... (0,0)
# numerical integration of (-0.159154943091895*x*tanh(125.663706143592 - 20*pi) + 0.159154943091895*(6.28318530717959 - x)*tanh(20*pi) + tanh(20*x - 20*pi))*sin(5*x)
# A:
#  [3.14159265358979]
# b:
#  [mpf('-0.38947942392209106')]
# coeff: [mpf('-0.12397515109956916')]
# approximation: -0.123975151099569*sin(5*x)
# f: tanh(20*x - 20*pi)
# u: 0.159154943091895*x*tanh(125.663706143592 - 20*pi) - 0.159154943091895*(6.28318530717959 - x)*tanh(20*pi) - 0.635939546504237*sin(x) - 0.210176496677524*sin(3*x) - 0.123975151099569*sin(5*x)
# ...evaluating matrix... (0,0)
# numerical integration of (-0.159154943091895*x*tanh(125.663706143592 - 20*pi) + 0.159154943091895*(6.28318530717959 - x)*tanh(20*pi) + tanh(20*x - 20*pi))*sin(7*x)
# A:
#  [3.14159265358979]
# b:
#  [mpf('-0.27120800166853598')]
# coeff: [mpf('-0.086328188143244999')]
# approximation: -0.086328188143245*sin(7*x)
# ...evaluating matrix... (0,0)
# numerical integration of (-0.159154943091895*x*tanh(125.663706143592 - 20*pi) + 0.159154943091895*(6.28318530717959 - x)*tanh(20*pi) + tanh(20*x - 20*pi))*sin(9*x)
# A:
#  [3.14159265358979]
# b:
#  [mpf('-0.20393822227530742')]
# coeff: [mpf('-0.064915552320977704')]
# approximation: -0.0649155523209777*sin(9*x)
# f: tanh(20*x - 20*pi)
# u: 0.159154943091895*x*tanh(125.663706143592 - 20*pi) - 0.159154943091895*(6.28318530717959 - x)*tanh(20*pi) - 0.635939546504237*sin(x) - 0.210176496677524*sin(3*x) - 0.123975151099569*sin(5*x) - 0.086328188143245*sin(7*x) - 0.0649155523209777*sin(9*x)
# ...evaluating matrix... (0,0)
# numerical integration of (-0.159154943091895*x*tanh(125.663706143592 - 20*pi) + 0.159154943091895*(6.28318530717959 - x)*tanh(20*pi) + tanh(20*x - 20*pi))*sin(11*x)
# A:
#  [3.14159265358979]
# b:
#  [mpf('-0.16000467718241157')]
# coeff: [mpf('-0.050931070582807589')]
# approximation: -0.0509310705828076*sin(11*x)
# ...evaluating matrix... (0,0)
# numerical integration of (-0.159154943091895*x*tanh(125.663706143592 - 20*pi) + 0.159154943091895*(6.28318530717959 - x)*tanh(20*pi) + tanh(20*x - 20*pi))*sin(13*x)
# A:
#  [3.14159265358979]
# b:
#  [mpf('-0.12877960618578957')]
# coeff: [mpf('-0.040991821787792065')]
# approximation: -0.0409918217877921*sin(13*x)
# f: tanh(20*x - 20*pi)
# u: 0.159154943091895*x*tanh(125.663706143592 - 20*pi) - 0.159154943091895*(6.28318530717959 - x)*tanh(20*pi) - 0.635939546504237*sin(x) - 0.210176496677524*sin(3*x) - 0.123975151099569*sin(5*x) - 0.086328188143245*sin(7*x) - 0.0649155523209777*sin(9*x) - 0.0509310705828076*sin(11*x) - 0.0409918217877921*sin(13*x)
# ...evaluating matrix... (0,0)
# numerical integration of (-0.159154943091895*x*tanh(125.663706143592 - 20*pi) + 0.159154943091895*(6.28318530717959 - x)*tanh(20*pi) + tanh(20*x - 20*pi))*sin(15*x)
# A:
#  [3.14159265358979]
# b:
#  [mpf('-0.10530605093954316')]
# coeff: [mpf('-0.033519957089030446')]
# approximation: -0.0335199570890304*sin(15*x)
# ...evaluating matrix... (0,0)
# numerical integration of (-0.159154943091895*x*tanh(125.663706143592 - 20*pi) + 0.159154943091895*(6.28318530717959 - x)*tanh(20*pi) + tanh(20*x - 20*pi))*sin(17*x)
# A:
#  [3.14159265358979]
# b:
#  [mpf('-0.086955147592525817')]
# coeff: [mpf('-0.027678683133271612')]
# approximation: -0.0276786831332716*sin(17*x)
# f: tanh(20*x - 20*pi)
# u: 0.159154943091895*x*tanh(125.663706143592 - 20*pi) - 0.159154943091895*(6.28318530717959 - x)*tanh(20*pi) - 0.635939546504237*sin(x) - 0.210176496677524*sin(3*x) - 0.123975151099569*sin(5*x) - 0.086328188143245*sin(7*x) - 0.0649155523209777*sin(9*x) - 0.0509310705828076*sin(11*x) - 0.0409918217877921*sin(13*x) - 0.0335199570890304*sin(15*x) - 0.0276786831332716*sin(17*x)
# ...evaluating matrix... (0,0)
# numerical integration of (-0.159154943091895*x*tanh(125.663706143592 - 20*pi) + 0.159154943091895*(6.28318530717959 - x)*tanh(20*pi) + tanh(20*x - 20*pi))*sin(19*x)
# A:
#  [3.14159265358979]
# b:
#  [mpf('-0.072195433063199935')]
# coeff: [mpf('-0.022980520081336647')]
# approximation: -0.0229805200813366*sin(19*x)
# ...evaluating matrix... (0,0)
# numerical integration of (-0.159154943091895*x*tanh(125.663706143592 - 20*pi) + 0.159154943091895*(6.28318530717959 - x)*tanh(20*pi) + tanh(20*x - 20*pi))*sin(21*x)
# A:
#  [3.14159265358979]
# b:
#  [mpf('-0.060066342781897791')]
# coeff: [mpf('-0.019119710734382442')]
# approximation: -0.0191197107343824*sin(21*x)
# f: tanh(20*x - 20*pi)
# u: 0.159154943091895*x*tanh(125.663706143592 - 20*pi) - 0.159154943091895*(6.28318530717959 - x)*tanh(20*pi) - 0.635939546504237*sin(x) - 0.210176496677524*sin(3*x) - 0.123975151099569*sin(5*x) - 0.086328188143245*sin(7*x) - 0.0649155523209777*sin(9*x) - 0.0509310705828076*sin(11*x) - 0.0409918217877921*sin(13*x) - 0.0335199570890304*sin(15*x) - 0.0276786831332716*sin(17*x) - 0.0229805200813366*sin(19*x) - 0.0191197107343824*sin(21*x)
# ...evaluating matrix... (0,0)
# numerical integration of (-0.159154943091895*x*tanh(125.663706143592 - 20*pi) + 0.159154943091895*(6.28318530717959 - x)*tanh(20*pi) + tanh(20*x - 20*pi))*sin(23*x)
# A:
#  [3.14159265358979]
# b:
#  [mpf('-0.049927284561523975')]
# coeff: [mpf('-0.015892348266244423')]
# approximation: -0.0158923482662444*sin(23*x)
# ...evaluating matrix... (0,0)
# numerical integration of (-0.159154943091895*x*tanh(125.663706143592 - 20*pi) + 0.159154943091895*(6.28318530717959 - x)*tanh(20*pi) + tanh(20*x - 20*pi))*sin(25*x)
# A:
#  [3.14159265358979]
# b:
#  [mpf('-0.041327879358044294')]
# coeff: [mpf('-0.013155072574676512')]
# approximation: -0.0131550725746765*sin(25*x)
# f: tanh(20*x - 20*pi)
# u: 0.159154943091895*x*tanh(125.663706143592 - 20*pi) - 0.159154943091895*(6.28318530717959 - x)*tanh(20*pi) - 0.635939546504237*sin(x) - 0.210176496677524*sin(3*x) - 0.123975151099569*sin(5*x) - 0.086328188143245*sin(7*x) - 0.0649155523209777*sin(9*x) - 0.0509310705828076*sin(11*x) - 0.0409918217877921*sin(13*x) - 0.0335199570890304*sin(15*x) - 0.0276786831332716*sin(17*x) - 0.0229805200813366*sin(19*x) - 0.0191197107343824*sin(21*x) - 0.0158923482662444*sin(23*x) - 0.0131550725746765*sin(25*x)
# ...evaluating matrix... (0,0)
# numerical integration of (-0.159154943091895*x*tanh(125.663706143592 - 20*pi) + 0.159154943091895*(6.28318530717959 - x)*tanh(20*pi) + tanh(20*x - 20*pi))*sin(27*x)
# A:
#  [3.14159265358979]
# b:
#  [mpf('-0.033936394666330846')]
# coeff: [mpf('-0.010802289923727972')]
# approximation: -0.010802289923728*sin(27*x)
# ...evaluating matrix... (0,0)
# numerical integration of (-0.159154943091895*x*tanh(125.663706143592 - 20*pi) + 0.159154943091895*(6.28318530717959 - x)*tanh(20*pi) + tanh(20*x - 20*pi))*sin(29*x)
# A:
#  [3.14159265358979]
# b:
#  [mpf('-0.02749810770606315')]
# coeff: [mpf('-0.0087529195341865783')]
# approximation: -0.00875291953418658*sin(29*x)
# f: tanh(20*x - 20*pi)
# u: 0.159154943091895*x*tanh(125.663706143592 - 20*pi) - 0.159154943091895*(6.28318530717959 - x)*tanh(20*pi) - 0.635939546504237*sin(x) - 0.210176496677524*sin(3*x) - 0.123975151099569*sin(5*x) - 0.086328188143245*sin(7*x) - 0.0649155523209777*sin(9*x) - 0.0509310705828076*sin(11*x) - 0.0409918217877921*sin(13*x) - 0.0335199570890304*sin(15*x) - 0.0276786831332716*sin(17*x) - 0.0229805200813366*sin(19*x) - 0.0191197107343824*sin(21*x) - 0.0158923482662444*sin(23*x) - 0.0131550725746765*sin(25*x) - 0.010802289923728*sin(27*x) - 0.00875291953418658*sin(29*x)
# ...evaluating matrix... (0,0)
# numerical integration of (-0.159154943091895*x*tanh(125.663706143592 - 20*pi) + 0.159154943091895*(6.28318530717959 - x)*tanh(20*pi) + tanh(20*x - 20*pi))*sin(31*x)
# A:
#  [3.14159265358979]
# b:
#  [mpf('-0.02180991324535576')]
# coeff: [mpf('-0.0069423110028075403')]
# approximation: -0.00694231100280754*sin(31*x)
# ...evaluating matrix... (0,0)
# numerical integration of (-0.159154943091895*x*tanh(125.663706143592 - 20*pi) + 0.159154943091895*(6.28318530717959 - x)*tanh(20*pi) + tanh(20*x - 20*pi))*sin(33*x)
# A:
#  [3.14159265358979]
# b:
#  [mpf('-0.016704129733217891')]
# coeff: [mpf('-0.0053170896341798611')]
# approximation: -0.00531708963417986*sin(33*x)
# f: tanh(20*x - 20*pi)
# u: 0.159154943091895*x*tanh(125.663706143592 - 20*pi) - 0.159154943091895*(6.28318530717959 - x)*tanh(20*pi) - 0.635939546504237*sin(x) - 0.210176496677524*sin(3*x) - 0.123975151099569*sin(5*x) - 0.086328188143245*sin(7*x) - 0.0649155523209777*sin(9*x) - 0.0509310705828076*sin(11*x) - 0.0409918217877921*sin(13*x) - 0.0335199570890304*sin(15*x) - 0.0276786831332716*sin(17*x) - 0.0229805200813366*sin(19*x) - 0.0191197107343824*sin(21*x) - 0.0158923482662444*sin(23*x) - 0.0131550725746765*sin(25*x) - 0.010802289923728*sin(27*x) - 0.00875291953418658*sin(29*x) - 0.00694231100280754*sin(31*x) - 0.00531708963417986*sin(33*x)
# ...evaluating matrix... (0,0)
# numerical integration of (-0.159154943091895*x*tanh(125.663706143592 - 20*pi) + 0.159154943091895*(6.28318530717959 - x)*tanh(20*pi) + tanh(20*x - 20*pi))*sin(2*x)
# A:
#  [3.14159265358979]
# b:
#  [mpf('0.99573435649846787')]
# coeff: [mpf('0.31695208968631738')]
# approximation: 0.316952089686317*sin(2*x)
# f: tanh(20*x - 20*pi)
# u: 0.159154943091895*x*tanh(125.663706143592 - 20*pi) - 0.159154943091895*(6.28318530717959 - x)*tanh(20*pi) + 0.316952089686317*sin(2*x)
# ...evaluating matrix... (0,0)
# numerical integration of (-0.159154943091895*x*tanh(125.663706143592 - 20*pi) + 0.159154943091895*(6.28318530717959 - x)*tanh(20*pi) + tanh(20*x - 20*pi))*sin(4*x)
# A:
#  [3.14159265358979]
# b:
#  [mpf('0.49153474347489984')]
# coeff: [mpf('0.15646036825087412')]
# approximation: 0.156460368250874*sin(4*x)
# ...evaluating matrix... (0,0)
# numerical integration of (-0.159154943091895*x*tanh(125.663706143592 - 20*pi) + 0.159154943091895*(6.28318530717959 - x)*tanh(20*pi) + tanh(20*x - 20*pi))*sin(6*x)
# A:
#  [3.14159265358979]
# b:
#  [mpf('0.3207968553072772')]
# coeff: [mpf('0.10211281050097737')]
# approximation: 0.102112810500977*sin(6*x)
# f: tanh(20*x - 20*pi)
# u: 0.159154943091895*x*tanh(125.663706143592 - 20*pi) - 0.159154943091895*(6.28318530717959 - x)*tanh(20*pi) + 0.316952089686317*sin(2*x) + 0.156460368250874*sin(4*x) + 0.102112810500977*sin(6*x)
# ...evaluating matrix... (0,0)
# numerical integration of (-0.159154943091895*x*tanh(125.663706143592 - 20*pi) + 0.159154943091895*(6.28318530717959 - x)*tanh(20*pi) + tanh(20*x - 20*pi))*sin(8*x)
# A:
#  [3.14159265358979]
# b:
#  [mpf('0.23357607590020127')]
# coeff: [mpf('0.074349574135049515')]
# approximation: 0.0743495741350495*sin(8*x)
# ...evaluating matrix... (0,0)
# numerical integration of (-0.159154943091895*x*tanh(125.663706143592 - 20*pi) + 0.159154943091895*(6.28318530717959 - x)*tanh(20*pi) + tanh(20*x - 20*pi))*sin(10*x)
# A:
#  [3.14159265358979]
# b:
#  [mpf('0.17991816581202025')]
# coeff: [mpf('0.057269730882020545')]
# approximation: 0.0572697308820205*sin(10*x)
# f: tanh(20*x - 20*pi)
# u: 0.159154943091895*x*tanh(125.663706143592 - 20*pi) - 0.159154943091895*(6.28318530717959 - x)*tanh(20*pi) + 0.316952089686317*sin(2*x) + 0.156460368250874*sin(4*x) + 0.102112810500977*sin(6*x) + 0.0743495741350495*sin(8*x) + 0.0572697308820205*sin(10*x)
# ..\src\approx1D.py:356: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# ...evaluating matrix... (0,0)
# numerical integration of (-0.159154943091895*x*tanh(125.663706143592 - 20*pi) + 0.159154943091895*(6.28318530717959 - x)*tanh(20*pi) + tanh(20*x - 20*pi))*sin(12*x)
# A:
#  [3.14159265358979]
# b:
#  [mpf('0.14319080237459844')]
# coeff: [mpf('0.045579048006424094')]
# approximation: 0.0455790480064241*sin(12*x)
# ...evaluating matrix... (0,0)
# numerical integration of (-0.159154943091895*x*tanh(125.663706143592 - 20*pi) + 0.159154943091895*(6.28318530717959 - x)*tanh(20*pi) + tanh(20*x - 20*pi))*sin(14*x)
# A:
#  [3.14159265358979]
# b:
#  [mpf('0.11627317836055381')]
# coeff: [mpf('0.037010902170175476')]
# approximation: 0.0370109021701755*sin(14*x)
# f: tanh(20*x - 20*pi)
# u: 0.159154943091895*x*tanh(125.663706143592 - 20*pi) - 0.159154943091895*(6.28318530717959 - x)*tanh(20*pi) + 0.316952089686317*sin(2*x) + 0.156460368250874*sin(4*x) + 0.102112810500977*sin(6*x) + 0.0743495741350495*sin(8*x) + 0.0572697308820205*sin(10*x) + 0.0455790480064241*sin(12*x) + 0.0370109021701755*sin(14*x)
# ...evaluating matrix... (0,0)
# numerical integration of (-0.159154943091895*x*tanh(125.663706143592 - 20*pi) + 0.159154943091895*(6.28318530717959 - x)*tanh(20*pi) + tanh(20*x - 20*pi))*sin(16*x)
# A:
#  [3.14159265358979]
# b:
#  [mpf('0.095603600195174651')]
# coeff: [mpf('0.030431571096886673')]
# approximation: 0.0304315710968867*sin(16*x)
# ...evaluating matrix... (0,0)
# numerical integration of (-0.159154943091895*x*tanh(125.663706143592 - 20*pi) + 0.159154943091895*(6.28318530717959 - x)*tanh(20*pi) + tanh(20*x - 20*pi))*sin(18*x)
# A:
#  [3.14159265358979]
# b:
#  [mpf('0.079196044761216819')]
# coeff: [mpf('0.02520888399414932')]
# approximation: 0.0252088839941493*sin(18*x)
# f: tanh(20*x - 20*pi)
# u: 0.159154943091895*x*tanh(125.663706143592 - 20*pi) - 0.159154943091895*(6.28318530717959 - x)*tanh(20*pi) + 0.316952089686317*sin(2*x) + 0.156460368250874*sin(4*x) + 0.102112810500977*sin(6*x) + 0.0743495741350495*sin(8*x) + 0.0572697308820205*sin(10*x) + 0.0455790480064241*sin(12*x) + 0.0370109021701755*sin(14*x) + 0.0304315710968867*sin(16*x) + 0.0252088839941493*sin(18*x)
# ...evaluating matrix... (0,0)
# numerical integration of (-0.159154943091895*x*tanh(125.663706143592 - 20*pi) + 0.159154943091895*(6.28318530717959 - x)*tanh(20*pi) + tanh(20*x - 20*pi))*sin(20*x)
# A:
#  [3.14159265358979]
# b:
#  [mpf('0.065847691489331617')]
# coeff: [mpf('0.020959971183434508')]
# approximation: 0.0209599711834345*sin(20*x)
# ...evaluating matrix... (0,0)
# numerical integration of (-0.159154943091895*x*tanh(125.663706143592 - 20*pi) + 0.159154943091895*(6.28318530717959 - x)*tanh(20*pi) + tanh(20*x - 20*pi))*sin(22*x)
# A:
#  [3.14159265358979]
# b:
#  [mpf('0.054779634588085338')]
# coeff: [mpf('0.017436899250923087')]
# approximation: 0.0174368992509231*sin(22*x)
# f: tanh(20*x - 20*pi)
# u: 0.159154943091895*x*tanh(125.663706143592 - 20*pi) - 0.159154943091895*(6.28318530717959 - x)*tanh(20*pi) + 0.316952089686317*sin(2*x) + 0.156460368250874*sin(4*x) + 0.102112810500977*sin(6*x) + 0.0743495741350495*sin(8*x) + 0.0572697308820205*sin(10*x) + 0.0455790480064241*sin(12*x) + 0.0370109021701755*sin(14*x) + 0.0304315710968867*sin(16*x) + 0.0252088839941493*sin(18*x) + 0.0209599711834345*sin(20*x) + 0.0174368992509231*sin(22*x)
# ...evaluating matrix... (0,0)
# numerical integration of (-0.159154943091895*x*tanh(125.663706143592 - 20*pi) + 0.159154943091895*(6.28318530717959 - x)*tanh(20*pi) + tanh(20*x - 20*pi))*sin(24*x)
# A:
#  [3.14159265358979]
# b:
#  [mpf('0.045458048474002956')]
# coeff: [mpf('0.01446974623589712')]
# approximation: 0.0144697462358971*sin(24*x)
# ...evaluating matrix... (0,0)
# numerical integration of (-0.159154943091895*x*tanh(125.663706143592 - 20*pi) + 0.159154943091895*(6.28318530717959 - x)*tanh(20*pi) + tanh(20*x - 20*pi))*sin(26*x)
# A:
#  [3.14159265358979]
# b:
#  [mpf('0.037498516998398686')]
# coeff: [mpf('0.011936148677821225')]
# approximation: 0.0119361486778212*sin(26*x)
# f: tanh(20*x - 20*pi)
# u: 0.159154943091895*x*tanh(125.663706143592 - 20*pi) - 0.159154943091895*(6.28318530717959 - x)*tanh(20*pi) + 0.316952089686317*sin(2*x) + 0.156460368250874*sin(4*x) + 0.102112810500977*sin(6*x) + 0.0743495741350495*sin(8*x) + 0.0572697308820205*sin(10*x) + 0.0455790480064241*sin(12*x) + 0.0370109021701755*sin(14*x) + 0.0304315710968867*sin(16*x) + 0.0252088839941493*sin(18*x) + 0.0209599711834345*sin(20*x) + 0.0174368992509231*sin(22*x) + 0.0144697462358971*sin(24*x) + 0.0119361486778212*sin(26*x)
# ...evaluating matrix... (0,0)
# numerical integration of (-0.159154943091895*x*tanh(125.663706143592 - 20*pi) + 0.159154943091895*(6.28318530717959 - x)*tanh(20*pi) + tanh(20*x - 20*pi))*sin(28*x)
# A:
#  [3.14159265358979]
# b:
#  [mpf('0.030611782307596518')]
# coeff: [mpf('0.0097440329422140252')]
# approximation: 0.00974403294221403*sin(28*x)
# ...evaluating matrix... (0,0)
# numerical integration of (-0.159154943091895*x*tanh(125.663706143592 - 20*pi) + 0.159154943091895*(6.28318530717959 - x)*tanh(20*pi) + tanh(20*x - 20*pi))*sin(30*x)
# A:
#  [3.14159265358979]
# b:
#  [mpf('0.024571412777112032')]
# coeff: [mpf('0.00782132360445747')]
# approximation: 0.00782132360445747*sin(30*x)
# f: tanh(20*x - 20*pi)
# u: 0.159154943091895*x*tanh(125.663706143592 - 20*pi) - 0.159154943091895*(6.28318530717959 - x)*tanh(20*pi) + 0.316952089686317*sin(2*x) + 0.156460368250874*sin(4*x) + 0.102112810500977*sin(6*x) + 0.0743495741350495*sin(8*x) + 0.0572697308820205*sin(10*x) + 0.0455790480064241*sin(12*x) + 0.0370109021701755*sin(14*x) + 0.0304315710968867*sin(16*x) + 0.0252088839941493*sin(18*x) + 0.0209599711834345*sin(20*x) + 0.0174368992509231*sin(22*x) + 0.0144697462358971*sin(24*x) + 0.0119361486778212*sin(26*x) + 0.00974403294221403*sin(28*x) + 0.00782132360445747*sin(30*x)
# ...evaluating matrix... (0,0)
# numerical integration of (-0.159154943091895*x*tanh(125.663706143592 - 20*pi) + 0.159154943091895*(6.28318530717959 - x)*tanh(20*pi) + tanh(20*x - 20*pi))*sin(32*x)
# A:
#  [3.14159265358979]
# b:
#  [mpf('0.019193637939450968')]
# coeff: [mpf('0.0061095247079595242')]
# approximation: 0.00610952470795952*sin(32*x)
# ...evaluating matrix... (0,0)
# numerical integration of (-0.159154943091895*x*tanh(125.663706143592 - 20*pi) + 0.159154943091895*(6.28318530717959 - x)*tanh(20*pi) + tanh(20*x - 20*pi))*sin(34*x)
# A:
#  [3.14159265358979]
# b:
#  [mpf('0.014324194413479279')]
# coeff: [mpf('0.0045595326934290796')]
# approximation: 0.00455953269342908*sin(34*x)
# f: tanh(20*x - 20*pi)
# u: 0.159154943091895*x*tanh(125.663706143592 - 20*pi) - 0.159154943091895*(6.28318530717959 - x)*tanh(20*pi) + 0.316952089686317*sin(2*x) + 0.156460368250874*sin(4*x) + 0.102112810500977*sin(6*x) + 0.0743495741350495*sin(8*x) + 0.0572697308820205*sin(10*x) + 0.0455790480064241*sin(12*x) + 0.0370109021701755*sin(14*x) + 0.0304315710968867*sin(16*x) + 0.0252088839941493*sin(18*x) + 0.0209599711834345*sin(20*x) + 0.0174368992509231*sin(22*x) + 0.0144697462358971*sin(24*x) + 0.0119361486778212*sin(26*x) + 0.00974403294221403*sin(28*x) + 0.00782132360445747*sin(30*x) + 0.00610952470795952*sin(32*x) + 0.00455953269342908*sin(34*x)
