# %%
import sys, os
sys.path.insert(0, os.path.join(os.pardir, 'src'))
import sympy as sym
from approx1D import least_squares, comparison_plot
from math import pi
import matplotlib.pyplot as plt

x = sym.Symbol('x')
f = sym.sin(x)
N = 7
psi_bases = [[x**i for i in range(1, N+1, 2)],  # V_1
             [x**i for i in range(0, N+1)]]     # V_2
symbolic = False

for V, psi in enumerate(psi_bases):
    for domain_no in range(1, 3):
        for k in range(2, 6):
            if symbolic:
                Omega = [0, k*sym.pi] if domain_no == 1 else \
                        [-k*sym.pi/2, k*sym.pi/2]
            else:
                # cannot use sym.pi with numerical sympy computing
                Omega = [0, k*pi] if domain_no == 1 else \
                        [-k*pi/2, k*pi/2]

            u, c = least_squares(f, psi, Omega, symbolic=symbolic)

            comparison_plot(
                f, u, Omega,
                ymin=-2, ymax=2,
                filename='tmp_N%d_V%dOmega%dk%d' %
                (N, V, k, domain_no),
                plot_title='sin(x) on [0,%d*pi/2] by %s' %
                (k, ','.join([str(p) for p in psi])))
            # Need to kill the plot to proceed!
        for ext in 'png', 'pdf':
            cmd = 'doconce combine_images -2 ' + \
                  ' '.join(['tmp_N%d_V%dOmega%dk%d.' %
                            (N, V, k, domain_no) + ext
                            for k in range(2, 6)]) + \
                  ' sin_powers_N%d_V%d_Omega%d.' % (N, V, domain_no) + ext
            print(cmd)
            os.system(cmd)

# Show the standard Taylor series approximation
from math import factorial, pi
import time
Omega = [0, 12*pi/2.]
u = 0
for k in range(0,N+1):
    u = u + ((-1)**k*x**(1+2*k))/float(factorial(1+2*k))
# Shorter: u = sum(((-1)**k*x**(1+2*k))/float(factorial(1+2*k))
# for k in range(0,10))
comparison_plot(f, u, Omega, 'sin_taylor%d' % k,
                ymin=-1.5, ymax=1.5)
# Out:
# ...evaluating matrix... (0,0)
# numerical integration of x**2
# (0,1)
# numerical integration of x**4
# (0,2)
# numerical integration of x**6
# (0,3)
# numerical integration of x**8
# numerical integration of x*sin(x)
# (1,1)
# numerical integration of x**6
# (1,2)
# numerical integration of x**8
# (1,3)
# numerical integration of x**10
# numerical integration of x**3*sin(x)
# (2,2)
# numerical integration of x**10
# (2,3)
# numerical integration of x**12
# numerical integration of x**5*sin(x)
# (3,3)
# numerical integration of x**14
# numerical integration of x**7*sin(x)
#
# A:
#  Matrix([[82.6834044807995, 1958.52598262580, 55228.2190222042, 1695806.53985827], [1958.52598262580, 55228.2190222042, 1695806.53985827, 54775438.9827752], [55228.2190222042, 1695806.53985827, 54775438.9827752, 1829763400.06646], [1695806.53985827, 54775438.9827752, 1829763400.06646, 62604675141.6604]])
# b:
#  Matrix([[-6.28318530717959], [-210.351101599321], [-5585.60788114259], [-152002.002147441]])
# coeff: [mpf('0.92597367983195629'), mpf('-0.13738285823568559'), mpf('0.0051258281521011748'), mpf('-5.7122261160658068e-5')]
# approximation: -5.71222611606581e-5*x**7 + 0.00512582815210118*x**5 - 0.137382858235686*x**3 + 0.925973679831956*x
# f: sin(x)
# u: -5.71222611606581e-5*x**7 + 0.00512582815210118*x**5 - 0.137382858235686*x**3 + 0.925973679831956*x
# ...evaluating matrix... (0,0)
# numerical integration of x**2
# (0,1)
# numerical integration of x**4
# (0,2)
# numerical integration of x**6
# (0,3)
# numerical integration of x**8
# numerical integration of x*sin(x)
# (1,1)
# numerical integration of x**6
# (1,2)
# numerical integration of x**8
# (1,3)
# numerical integration of x**10
# numerical integration of x**3*sin(x)
# (2,2)
# numerical integration of x**10
# (2,3)
# numerical integration of x**12
# numerical integration of x**5*sin(x)
# (3,3)
# numerical integration of x**14
# numerical integration of x**7*sin(x)
#
# A:
#  Matrix([[279.056490122698, 14872.5566805647, 943625.898449692, 65192500.2422468], [14872.5566805647, 943625.898449692, 65192500.2422468, 4737941742.91098], [943625.898449692, 65192500.2422468, 4737941742.91098, 356107650547.383], [65192500.2422468, 4737941742.91098, 356107650547.383, 27414204753811.5]])
# b:
#  Matrix([[9.42477796076938], [780.620802603479], [58750.3673507538], [4137865.86041618]])
# coeff: [mpf('0.38374215151462713'), mpf('-0.044276062785613973'), mpf('0.0011533840672992573'), mpf('-8.0918170247245526e-6')]
# approximation: -8.09181702472455e-6*x**7 + 0.00115338406729926*x**5 - 0.044276062785614*x**3 + 0.383742151514627*x
# f: sin(x)
# u: -8.09181702472455e-6*x**7 + 0.00115338406729926*x**5 - 0.044276062785614*x**3 + 0.383742151514627*x
# ...evaluating matrix... (0,0)
# numerical integration of x**2
# (0,1)
# numerical integration of x**4
# (0,2)
# numerical integration of x**6
# (0,3)
# numerical integration of x**8
# numerical integration of x*sin(x)
# (1,1)
# numerical integration of x**6
# (1,2)
# numerical integration of x**8
# (1,3)
# numerical integration of x**10
# numerical integration of x**3*sin(x)
# (2,2)
# numerical integration of x**10
# (2,3)
# numerical integration of x**12
# numerical integration of x**5*sin(x)
# (3,3)
# numerical integration of x**14
# numerical integration of x**7*sin(x)
#
# A:
#  Matrix([[661.467235846396, 62672.8314440256, 7069212.03484214, 868252948.407436], [62672.8314440256, 7069212.03484214, 868252948.407436, 112180099036.724], [7069212.03484214, 868252948.407436, 112180099036.724, 14989421773344.5], [868252948.407436, 112180099036.724, 14989421773344.5, 2.05142999504193e+15]])
# b:
#  Matrix([[-12.5663706143592], [-1909.00348385303], [-275184.087543068], [-37926752.5670861]])
# coeff: [mpf('-0.15990050431212154'), mpf('0.0094882321915445385'), mpf('-0.00012918378118644784'), mpf('4.7425780536180386e-7')]
# approximation: 4.74257805361804e-7*x**7 - 0.000129183781186448*x**5 + 0.00948823219154454*x**3 - 0.159900504312122*x
# f: sin(x)
# u: 4.74257805361804e-7*x**7 - 0.000129183781186448*x**5 + 0.00948823219154454*x**3 - 0.159900504312122*x
# ...evaluating matrix... (0,0)
# numerical integration of x**2
# (0,1)
# numerical integration of x**4
# (0,2)
# numerical integration of x**6
# (0,3)
# numerical integration of x**8
# numerical integration of x*sin(x)
# (1,1)
# numerical integration of x**6
# (1,2)
# numerical integration of x**8
# (1,3)
# numerical integration of x**10
# numerical integration of x**3*sin(x)
# (2,2)
# numerical integration of x**10
# (2,3)
# numerical integration of x**12
# numerical integration of x**5*sin(x)
# (3,3)
# numerical integration of x**14
# numerical integration of x**7*sin(x)
#
# A:
#  Matrix([[1291.92819501249, 191262.302990801, 33708629.7742945, 6468988570.62635], [191262.302990801, 33708629.7742945, 6468988570.62635, 1305948233193.76], [33708629.7742945, 6468988570.62635, 1305948233193.76, 272655993709931.], [6468988570.62635, 1305948233193.76, 272655993709931., 5.83051472358968e+16]])
# b:
#  Matrix([[15.7079632679490], [3781.53680542978], [880680.778845409], [198971815.708555]])
# coeff: [mpf('0.055603529529546464'), mpf('-0.0019064618273737619'), mpf('1.449141754857386e-5'), mpf('-2.7821869167113193e-8')]
# approximation: -2.78218691671132e-8*x**7 + 1.44914175485739e-5*x**5 - 0.00190646182737376*x**3 + 0.0556035295295465*x
# f: sin(x)
# u: -2.78218691671132e-8*x**7 + 1.44914175485739e-5*x**5 - 0.00190646182737376*x**3 + 0.0556035295295465*x
# doconce combine_images -2 tmp_N7_V0Omega2k1.png tmp_N7_V0Omega3k1.png tmp_N7_V0Omega4k1.png tmp_N7_V0Omega5k1.png sin_powers_N7_V0_Omega1.png
# doconce combine_images -2 tmp_N7_V0Omega2k1.pdf tmp_N7_V0Omega3k1.pdf tmp_N7_V0Omega4k1.pdf tmp_N7_V0Omega5k1.pdf sin_powers_N7_V0_Omega1.pdf
# ...evaluating matrix... (0,0)
# numerical integration of x**2
# (0,1)
# numerical integration of x**4
# (0,2)
# numerical integration of x**6
# (0,3)
# numerical integration of x**8
# numerical integration of x*sin(x)
# (1,1)
# numerical integration of x**6
# (1,2)
# numerical integration of x**8
# (1,3)
# numerical integration of x**10
# numerical integration of x**3*sin(x)
# (2,2)
# numerical integration of x**10
# (2,3)
# numerical integration of x**12
# numerical integration of x**5*sin(x)
# (3,3)
# numerical integration of x**14
# numerical integration of x**7*sin(x)
#
# A:
#  Matrix([[20.6708511201999, 122.407873914113, 862.940922221940, 6624.24429632138], [122.407873914113, 862.940922221940, 6624.24429632138, 53491.6396316164], [862.940922221940, 6624.24429632138, 53491.6396316164, 446719.580094351], [6624.24429632138, 53491.6396316164, 446719.580094351, 3821086.12925173]])
# b:
#  Matrix([[6.28318530717959], [24.3134415175221], [125.770539220120], [758.223808308524]])
# coeff: [mpf('0.99945019389327376'), mpf('-0.16583845269804153'), mpf('0.0079985814374336975'), mpf('-0.00014774088079746696')]
# approximation: -0.000147740880797467*x**7 + 0.0079985814374337*x**5 - 0.165838452698042*x**3 + 0.999450193893274*x
# f: sin(x)
# u: -0.000147740880797467*x**7 + 0.0079985814374337*x**5 - 0.165838452698042*x**3 + 0.999450193893274*x
# ...evaluating matrix... (0,0)
# numerical integration of x**2
# (0,1)
# numerical integration of x**4
# (0,2)
# numerical integration of x**6
# (0,3)
# numerical integration of x**8
# numerical integration of x*sin(x)
# (1,1)
# numerical integration of x**6
# (1,2)
# numerical integration of x**8
# (1,3)
# numerical integration of x**10
# numerical integration of x**3*sin(x)
# (2,2)
# numerical integration of x**10
# (2,3)
# numerical integration of x**12
# numerical integration of x**5*sin(x)
# (3,3)
# numerical integration of x**14
# numerical integration of x**7*sin(x)
#
# A:
#  Matrix([[69.7641225306746, 929.534792535292, 14744.1546632764, 254658.204071277], [929.534792535292, 14744.1546632764, 254658.204071277, 4626896.23331150], [14744.1546632764, 254658.204071277, 4626896.23331150, 86940344.3719197], [254658.204071277, 4626896.23331150, 86940344.3719197, 1673230270.61838]])
# b:
#  Matrix([[-2.00000000000000], [-121.239659414706], [-2506.54204530225], [-48036.7670602675]])
# coeff: [mpf('0.98918799295036915'), mpf('-0.15929043392322859'), mpf('0.0069663982405030813'), mpf('-0.00010075263466929024')]
# approximation: -0.00010075263466929*x**7 + 0.00696639824050308*x**5 - 0.159290433923229*x**3 + 0.989187992950369*x
# f: sin(x)
# u: -0.00010075263466929*x**7 + 0.00696639824050308*x**5 - 0.159290433923229*x**3 + 0.989187992950369*x
# ...evaluating matrix... (0,0)
# numerical integration of x**2
# (0,1)
# numerical integration of x**4
# (0,2)
# numerical integration of x**6
# (0,3)
# numerical integration of x**8
# numerical integration of x*sin(x)
# (1,1)
# numerical integration of x**6
# (1,2)
# numerical integration of x**8
# (1,3)
# numerical integration of x**10
# numerical integration of x**3*sin(x)
# (2,2)
# numerical integration of x**10
# (2,3)
# numerical integration of x**12
# numerical integration of x**5*sin(x)
# (3,3)
# numerical integration of x**14
# numerical integration of x**7*sin(x)
#
# A:
#  Matrix([[165.366808961599, 3917.05196525160, 110456.438044408, 3391613.07971655], [3917.05196525160, 110456.438044408, 3391613.07971655, 109550877.965550], [110456.438044408, 3391613.07971655, 109550877.965550, 3659526800.13292], [3391613.07971655, 109550877.965550, 3659526800.13292, 125209350283.321]])
# b:
#  Matrix([[-12.5663706143592], [-420.702203198642], [-11171.2157622852], [-304004.004294882]])
# coeff: [mpf('0.92597367983195629'), mpf('-0.13738285823568559'), mpf('0.0051258281521011748'), mpf('-5.7122261160658068e-5')]
# approximation: -5.71222611606581e-5*x**7 + 0.00512582815210118*x**5 - 0.137382858235686*x**3 + 0.925973679831956*x
# f: sin(x)
# u: -5.71222611606581e-5*x**7 + 0.00512582815210118*x**5 - 0.137382858235686*x**3 + 0.925973679831956*x
# ...evaluating matrix... (0,0)
# numerical integration of x**2
# (0,1)
# numerical integration of x**4
# (0,2)
# numerical integration of x**6
# (0,3)
# numerical integration of x**8
# numerical integration of x*sin(x)
# (1,1)
# numerical integration of x**6
# (1,2)
# numerical integration of x**8
# (1,3)
# numerical integration of x**10
# numerical integration of x**3*sin(x)
# (2,2)
# numerical integration of x**10
# (2,3)
# numerical integration of x**12
# numerical integration of x**5*sin(x)
# (3,3)
# numerical integration of x**14
# numerical integration of x**7*sin(x)
#
# A:
#  Matrix([[322.982048753123, 11953.8939369251, 526697.340223352, 25269486.6040092], [11953.8939369251, 526697.340223352, 25269486.6040092, 1275340071.47828], [526697.340223352, 25269486.6040092, 1275340071.47828, 66566404714.3386], [25269486.6040092, 1275340071.47828, 66566404714.3386, 3558663771722.22]])
# b:
#  Matrix([[2.00000000000000], [358.110165040851], [30888.2228843402], [1988692.85908580]])
# coeff: [mpf('0.7317580301268817'), mpf('-0.095454845019209241'), mpf('0.0029517904361667358'), mpf('-2.564309265229097e-5')]
# approximation: -2.5643092652291e-5*x**7 + 0.00295179043616674*x**5 - 0.0954548450192092*x**3 + 0.731758030126882*x
# f: sin(x)
# u: -2.5643092652291e-5*x**7 + 0.00295179043616674*x**5 - 0.0954548450192092*x**3 + 0.731758030126882*x
# doconce combine_images -2 tmp_N7_V0Omega2k2.png tmp_N7_V0Omega3k2.png tmp_N7_V0Omega4k2.png tmp_N7_V0Omega5k2.png sin_powers_N7_V0_Omega2.png
# doconce combine_images -2 tmp_N7_V0Omega2k2.pdf tmp_N7_V0Omega3k2.pdf tmp_N7_V0Omega4k2.pdf tmp_N7_V0Omega5k2.pdf sin_powers_N7_V0_Omega2.pdf
# ...evaluating matrix... (0,0)
# numerical integration of 1
# (0,1)
# numerical integration of x
# (0,2)
# numerical integration of x**2
# (0,3)
# numerical integration of x**3
# (0,4)
# numerical integration of x**4
# (0,5)
# numerical integration of x**5
# (0,6)
# numerical integration of x**6
# (0,7)
# numerical integration of x**7
# numerical integration of sin(x)
# (1,1)
# numerical integration of x**2
# (1,2)
# numerical integration of x**3
# (1,3)
# numerical integration of x**4
# (1,4)
# numerical integration of x**5
# (1,5)
# numerical integration of x**6
# (1,6)
# numerical integration of x**7
# (1,7)
# numerical integration of x**8
# numerical integration of x*sin(x)
# (2,2)
# numerical integration of x**4
# (2,3)
# numerical integration of x**5
# (2,4)
# numerical integration of x**6
# (2,5)
# numerical integration of x**7
# (2,6)
# numerical integration of x**8
# (2,7)
# numerical integration of x**9
# numerical integration of x**2*sin(x)
# (3,3)
# numerical integration of x**6
# (3,4)
# numerical integration of x**7
# (3,5)
# numerical integration of x**8
# (3,6)
# numerical integration of x**9
# (3,7)
# numerical integration of x**10
# numerical integration of x**3*sin(x)
# (4,4)
# numerical integration of x**8
# (4,5)
# numerical integration of x**9
# (4,6)
# numerical integration of x**10
# (4,7)
# numerical integration of x**11
# numerical integration of x**4*sin(x)
# (5,5)
# numerical integration of x**10
# (5,6)
# numerical integration of x**11
# (5,7)
# numerical integration of x**12
# numerical integration of x**5*sin(x)
# (6,6)
# numerical integration of x**12
# (6,7)
# numerical integration of x**13
# numerical integration of x**6*sin(x)
# (7,7)
# numerical integration of x**14
# numerical integration of x**7*sin(x)
#
# A:
#  Matrix([[6.28318530717959, 19.7392088021787, 82.6834044807995, 389.636364136010, 1958.52598262580, 10254.8180648032, 55228.2190222042, 303632.992514258], [19.7392088021787, 82.6834044807995, 389.636364136010, 1958.52598262580, 10254.8180648032, 55228.2190222042, 303632.992514258, 1695806.53985827], [82.6834044807995, 389.636364136010, 1958.52598262580, 10254.8180648032, 55228.2190222042, 303632.992514258, 1695806.53985827, 9589560.06155090], [389.636364136010, 1958.52598262580, 10254.8180648032, 55228.2190222042, 303632.992514258, 1695806.53985827, 9589560.06155090, 54775438.9827752], [1958.52598262580, 10254.8180648032, 55228.2190222042, 303632.992514258, 1695806.53985827, 9589560.06155090, 54775438.9827752, 315483880.626645], [10254.8180648032, 55228.2190222042, 303632.992514258, 1695806.53985827, 9589560.06155090, 54775438.9827752, 315483880.626645, 1829763400.06646], [55228.2190222042, 303632.992514258, 1695806.53985827, 9589560.06155090, 54775438.9827752, 315483880.626645, 1829763400.06646, 10675546617.2759], [303632.992514258, 1695806.53985827, 9589560.06155090, 54775438.9827752, 315483880.626645, 1829763400.06646, 10675546617.2759, 62604675141.6604]])
# b:
#  Matrix([[7.85129078919495e-22], [-6.28318530717959], [-39.4784176043574], [-210.351101599321], [-1084.80444529175], [-5585.60788114259], [-28984.7750300670], [-152002.002147441]])
# coeff: [mpf('-0.00066497444876099993'), mpf('1.0094122499627164'), mpf('-0.032372295001356919'), mpf('-0.11989420518695864'), mpf('-0.034689895289614284'), mpf('0.022622445065864'), mpf('-0.0032489918299399362'), mpf('0.00014774088837131979')]
# approximation: 0.00014774088837132*x**7 - 0.00324899182993994*x**6 + 0.022622445065864*x**5 - 0.0346898952896143*x**4 - 0.119894205186959*x**3 - 0.0323722950013569*x**2 + 1.00941224996272*x - 0.000664974448761
# f: sin(x)
# u: 0.00014774088837132*x**7 - 0.00324899182993994*x**6 + 0.022622445065864*x**5 - 0.0346898952896143*x**4 - 0.119894205186959*x**3 - 0.0323722950013569*x**2 + 1.00941224996272*x - 0.000664974448761
# ...evaluating matrix... (0,0)
# numerical integration of 1
# (0,1)
# numerical integration of x
# (0,2)
# numerical integration of x**2
# (0,3)
# numerical integration of x**3
# (0,4)
# numerical integration of x**4
# (0,5)
# numerical integration of x**5
# (0,6)
# numerical integration of x**6
# (0,7)
# numerical integration of x**7
# numerical integration of sin(x)
# (1,1)
# numerical integration of x**2
# (1,2)
# numerical integration of x**3
# (1,3)
# numerical integration of x**4
# (1,4)
# numerical integration of x**5
# (1,5)
# numerical integration of x**6
# (1,6)
# numerical integration of x**7
# (1,7)
# numerical integration of x**8
# numerical integration of x*sin(x)
# (2,2)
# numerical integration of x**4
# (2,3)
# numerical integration of x**5
# (2,4)
# numerical integration of x**6
# (2,5)
# numerical integration of x**7
# (2,6)
# numerical integration of x**8
# (2,7)
# numerical integration of x**9
# numerical integration of x**2*sin(x)
# (3,3)
# numerical integration of x**6
# (3,4)
# numerical integration of x**7
# (3,5)
# numerical integration of x**8
# (3,6)
# numerical integration of x**9
# (3,7)
# numerical integration of x**10
# numerical integration of x**3*sin(x)
# (4,4)
# numerical integration of x**8
# (4,5)
# numerical integration of x**9
# (4,6)
# numerical integration of x**10
# (4,7)
# numerical integration of x**11
# numerical integration of x**4*sin(x)
# (5,5)
# numerical integration of x**10
# (5,6)
# numerical integration of x**11
# (5,7)
# numerical integration of x**12
# numerical integration of x**5*sin(x)
# (6,6)
# numerical integration of x**12
# (6,7)
# numerical integration of x**13
# numerical integration of x**6*sin(x)
# (7,7)
# numerical integration of x**14
# numerical integration of x**7*sin(x)
#
# A:
#  Matrix([[9.42477796076938, 44.4132198049021, 279.056490122698, 1972.53409343855, 14872.5566805647, 116808.787019399, 943625.898449692, 7781781.49955488], [44.4132198049021, 279.056490122698, 1972.53409343855, 14872.5566805647, 116808.787019399, 943625.898449692, 7781781.49955488, 65192500.2422468], [279.056490122698, 1972.53409343855, 14872.5566805647, 116808.787019399, 943625.898449692, 7781781.49955488, 65192500.2422468, 552982355.541522], [1972.53409343855, 14872.5566805647, 116808.787019399, 943625.898449692, 7781781.49955488, 65192500.2422468, 552982355.541522, 4737941742.91098], [14872.5566805647, 116808.787019399, 943625.898449692, 7781781.49955488, 65192500.2422468, 552982355.541522, 4737941742.91098, 40932878174.8303], [116808.787019399, 943625.898449692, 7781781.49955488, 65192500.2422468, 552982355.541522, 4737941742.91098, 40932878174.8303, 356107650547.383], [943625.898449692, 7781781.49955488, 65192500.2422468, 552982355.541522, 4737941742.91098, 40932878174.8303, 356107650547.383, 3116504426787.46], [7781781.49955488, 65192500.2422468, 552982355.541522, 4737941742.91098, 40932878174.8303, 356107650547.383, 3116504426787.46, 27414204753811.5]])
# b:
#  Matrix([[2.00000000000000], [9.42477796076938], [84.8264396098042], [780.620802603479], [6872.21909843655], [58750.3673507538], [494686.149163301], [4137865.86041618]])
# coeff: [mpf('0.060919572646239706'), mpf('0.5528258014836336'), mpf('0.77956135425362652'), mpf('-0.71283697966141258'), mpf('0.17972014538335632'), mpf('-0.018067646765376301'), mpf('0.0006390122342736913'), mpf('2.9852094973705441e-12')]
# approximation: 2.98520949737054e-12*x**7 + 0.000639012234273691*x**6 - 0.0180676467653763*x**5 + 0.179720145383356*x**4 - 0.712836979661413*x**3 + 0.779561354253626*x**2 + 0.552825801483634*x + 0.0609195726462397
# f: sin(x)
# u: 2.98520949737054e-12*x**7 + 0.000639012234273691*x**6 - 0.0180676467653763*x**5 + 0.179720145383356*x**4 - 0.712836979661413*x**3 + 0.779561354253626*x**2 + 0.552825801483634*x + 0.0609195726462397
# ...evaluating matrix... (0,0)
# numerical integration of 1
# (0,1)
# numerical integration of x
# (0,2)
# numerical integration of x**2
# (0,3)
# numerical integration of x**3
# (0,4)
# numerical integration of x**4
# (0,5)
# numerical integration of x**5
# (0,6)
# numerical integration of x**6
# (0,7)
# numerical integration of x**7
# numerical integration of sin(x)
# (1,1)
# numerical integration of x**2
# (1,2)
# numerical integration of x**3
# (1,3)
# numerical integration of x**4
# (1,4)
# numerical integration of x**5
# (1,5)
# numerical integration of x**6
# (1,6)
# numerical integration of x**7
# (1,7)
# numerical integration of x**8
# numerical integration of x*sin(x)
# (2,2)
# numerical integration of x**4
# (2,3)
# numerical integration of x**5
# (2,4)
# numerical integration of x**6
# (2,5)
# numerical integration of x**7
# (2,6)
# numerical integration of x**8
# (2,7)
# numerical integration of x**9
# numerical integration of x**2*sin(x)
# (3,3)
# numerical integration of x**6
# (3,4)
# numerical integration of x**7
# (3,5)
# numerical integration of x**8
# (3,6)
# numerical integration of x**9
# (3,7)
# numerical integration of x**10
# numerical integration of x**3*sin(x)
# (4,4)
# numerical integration of x**8
# (4,5)
# numerical integration of x**9
# (4,6)
# numerical integration of x**10
# (4,7)
# numerical integration of x**11
# numerical integration of x**4*sin(x)
# (5,5)
# numerical integration of x**10
# (5,6)
# numerical integration of x**11
# (5,7)
# numerical integration of x**12
# numerical integration of x**5*sin(x)
# (6,6)
# numerical integration of x**12
# (6,7)
# numerical integration of x**13
# numerical integration of x**6*sin(x)
# (7,7)
# numerical integration of x**14
# numerical integration of x**7*sin(x)
#
# A:
#  Matrix([[12.5663706143592, 78.9568352087149, 661.467235846396, 6234.18182617615, 62672.8314440256, 656308.356147408, 7069212.03484214, 77730046.0836501], [78.9568352087149, 661.467235846396, 6234.18182617615, 62672.8314440256, 656308.356147408, 7069212.03484214, 77730046.0836501, 868252948.407436], [661.467235846396, 6234.18182617615, 62672.8314440256, 656308.356147408, 7069212.03484214, 77730046.0836501, 868252948.407436, 9819709503.02812], [6234.18182617615, 62672.8314440256, 656308.356147408, 7069212.03484214, 77730046.0836501, 868252948.407436, 9819709503.02812, 112180099036.724], [62672.8314440256, 656308.356147408, 7069212.03484214, 77730046.0836501, 868252948.407436, 9819709503.02812, 112180099036.724, 1292221975046.74], [656308.356147408, 7069212.03484214, 77730046.0836501, 868252948.407436, 9819709503.02812, 112180099036.724, 1292221975046.74, 14989421773344.5], [7069212.03484214, 77730046.0836501, 868252948.407436, 9819709503.02812, 112180099036.724, 1292221975046.74, 14989421773344.5, 174908155777449.], [77730046.0836501, 868252948.407436, 9819709503.02812, 112180099036.724, 1292221975046.74, 14989421773344.5, 174908155777449., 2.05142999504193e+15]])
# b:
#  Matrix([[-1.08870284745390e-21], [-12.5663706143592], [-157.913670417430], [-1909.00348385303], [-23041.7632596955], [-275184.087543068], [-3246597.23909358], [-37926752.5670861]])
# coeff: [mpf('0.14777032914664548'), mpf('-0.0035119345579701233'), mpf('1.6218989765785857'), mpf('-1.2297545857243444'), mpf('0.33488900899183839'), mpf('-0.042231201548345568'), mpf('0.002512368468299607'), mpf('-5.7122265736529726e-5')]
# approximation: -5.71222657365297e-5*x**7 + 0.00251236846829961*x**6 - 0.0422312015483456*x**5 + 0.334889008991838*x**4 - 1.22975458572434*x**3 + 1.62189897657859*x**2 - 0.00351193455797012*x + 0.147770329146645
# f: sin(x)
# u: -5.71222657365297e-5*x**7 + 0.00251236846829961*x**6 - 0.0422312015483456*x**5 + 0.334889008991838*x**4 - 1.22975458572434*x**3 + 1.62189897657859*x**2 - 0.00351193455797012*x + 0.147770329146645
# ...evaluating matrix... (0,0)
# numerical integration of 1
# (0,1)
# numerical integration of x
# (0,2)
# numerical integration of x**2
# (0,3)
# numerical integration of x**3
# (0,4)
# numerical integration of x**4
# (0,5)
# numerical integration of x**5
# (0,6)
# numerical integration of x**6
# (0,7)
# numerical integration of x**7
# numerical integration of sin(x)
# (1,1)
# numerical integration of x**2
# (1,2)
# numerical integration of x**3
# (1,3)
# numerical integration of x**4
# (1,4)
# numerical integration of x**5
# (1,5)
# numerical integration of x**6
# (1,6)
# numerical integration of x**7
# (1,7)
# numerical integration of x**8
# numerical integration of x*sin(x)
# (2,2)
# numerical integration of x**4
# (2,3)
# numerical integration of x**5
# (2,4)
# numerical integration of x**6
# (2,5)
# numerical integration of x**7
# (2,6)
# numerical integration of x**8
# (2,7)
# numerical integration of x**9
# numerical integration of x**2*sin(x)
# (3,3)
# numerical integration of x**6
# (3,4)
# numerical integration of x**7
# (3,5)
# numerical integration of x**8
# (3,6)
# numerical integration of x**9
# (3,7)
# numerical integration of x**10
# numerical integration of x**3*sin(x)
# (4,4)
# numerical integration of x**8
# (4,5)
# numerical integration of x**9
# (4,6)
# numerical integration of x**10
# (4,7)
# numerical integration of x**11
# numerical integration of x**4*sin(x)
# (5,5)
# numerical integration of x**10
# (5,6)
# numerical integration of x**11
# (5,7)
# numerical integration of x**12
# numerical integration of x**5*sin(x)
# (6,6)
# numerical integration of x**12
# (6,7)
# numerical integration of x**13
# numerical integration of x**6*sin(x)
# (7,7)
# numerical integration of x**14
# numerical integration of x**7*sin(x)
#
# A:
#  Matrix([[15.7079632679490, 123.370055013617, 1291.92819501249, 15220.1704740629, 191262.302990801, 2503617.69160235, 33708629.7742945, 463307178.519071], [123.370055013617, 1291.92819501249, 15220.1704740629, 191262.302990801, 2503617.69160235, 33708629.7742945, 463307178.519071, 6468988570.62635], [1291.92819501249, 15220.1704740629, 191262.302990801, 2503617.69160235, 33708629.7742945, 463307178.519071, 6468988570.62635, 91453171363.3623], [15220.1704740629, 191262.302990801, 2503617.69160235, 33708629.7742945, 463307178.519071, 6468988570.62635, 91453171363.3623, 1305948233193.76], [191262.302990801, 2503617.69160235, 33708629.7742945, 463307178.519071, 6468988570.62635, 91453171363.3623, 1305948233193.76, 18804304637112.9], [2503617.69160235, 33708629.7742945, 463307178.519071, 6468988570.62635, 91453171363.3623, 1305948233193.76, 18804304637112.9, 272655993709931.], [33708629.7742945, 463307178.519071, 6468988570.62635, 91453171363.3623, 1305948233193.76, 18804304637112.9, 272655993709931., 3.97695102441160e+15], [463307178.519071, 6468988570.62635, 91453171363.3623, 1305948233193.76, 18804304637112.9, 272655993709931., 3.97695102441160e+15, 5.83051472358968e+16]])
# b:
#  Matrix([[2.00000000000000], [15.7079632679490], [242.740110027234], [3781.53680542978], [57967.8005759247], [880680.778845409], [13282672.1323364], [198971815.708555]])
# coeff: [mpf('-0.92312579281272834'), mpf('4.6751630264446369'), mpf('-3.2611314959529759'), mpf('0.85357958258673978'), mpf('-0.10296859861454632'), mpf('0.0057905648676761534'), mpf('-0.0001228796043114023'), mpf('4.6629361347685444e-14')]
# approximation: 4.66293613476854e-14*x**7 - 0.000122879604311402*x**6 + 0.00579056486767615*x**5 - 0.102968598614546*x**4 + 0.85357958258674*x**3 - 3.26113149595298*x**2 + 4.67516302644464*x - 0.923125792812728
# f: sin(x)
# u: 4.66293613476854e-14*x**7 - 0.000122879604311402*x**6 + 0.00579056486767615*x**5 - 0.102968598614546*x**4 + 0.85357958258674*x**3 - 3.26113149595298*x**2 + 4.67516302644464*x - 0.923125792812728
# doconce combine_images -2 tmp_N7_V1Omega2k1.png tmp_N7_V1Omega3k1.png tmp_N7_V1Omega4k1.png tmp_N7_V1Omega5k1.png sin_powers_N7_V1_Omega1.png
# doconce combine_images -2 tmp_N7_V1Omega2k1.pdf tmp_N7_V1Omega3k1.pdf tmp_N7_V1Omega4k1.pdf tmp_N7_V1Omega5k1.pdf sin_powers_N7_V1_Omega1.pdf
# ...evaluating matrix... (0,0)
# numerical integration of 1
# (0,1)
# numerical integration of x
# (0,2)
# numerical integration of x**2
# (0,3)
# numerical integration of x**3
# (0,4)
# numerical integration of x**4
# (0,5)
# numerical integration of x**5
# (0,6)
# numerical integration of x**6
# (0,7)
# numerical integration of x**7
# numerical integration of sin(x)
# (1,1)
# numerical integration of x**2
# (1,2)
# numerical integration of x**3
# (1,3)
# numerical integration of x**4
# (1,4)
# numerical integration of x**5
# (1,5)
# numerical integration of x**6
# (1,6)
# numerical integration of x**7
# (1,7)
# numerical integration of x**8
# numerical integration of x*sin(x)
# (2,2)
# numerical integration of x**4
# (2,3)
# numerical integration of x**5
# (2,4)
# numerical integration of x**6
# (2,5)
# numerical integration of x**7
# (2,6)
# numerical integration of x**8
# (2,7)
# numerical integration of x**9
# numerical integration of x**2*sin(x)
# (3,3)
# numerical integration of x**6
# (3,4)
# numerical integration of x**7
# (3,5)
# numerical integration of x**8
# (3,6)
# numerical integration of x**9
# (3,7)
# numerical integration of x**10
# numerical integration of x**3*sin(x)
# (4,4)
# numerical integration of x**8
# (4,5)
# numerical integration of x**9
# (4,6)
# numerical integration of x**10
# (4,7)
# numerical integration of x**11
# numerical integration of x**4*sin(x)
# (5,5)
# numerical integration of x**10
# (5,6)
# numerical integration of x**11
# (5,7)
# numerical integration of x**12
# numerical integration of x**5*sin(x)
# (6,6)
# numerical integration of x**12
# (6,7)
# numerical integration of x**13
# numerical integration of x**6*sin(x)
# (7,7)
# numerical integration of x**14
# numerical integration of x**7*sin(x)
#
# A:
#  Matrix([[6.28318530717959, 0, 20.6708511201999, 0, 122.407873914113, 0, 862.940922221940, 0], [0, 20.6708511201999, 0, 122.407873914113, 0, 862.940922221940, 0, 6624.24429632138], [20.6708511201999, 0, 122.407873914113, 0, 862.940922221940, 0, 6624.24429632138, 0], [0, 122.407873914113, 0, 862.940922221940, 0, 6624.24429632138, 0, 53491.6396316164], [122.407873914113, 0, 862.940922221940, 0, 6624.24429632138, 0, 53491.6396316164, 0], [0, 862.940922221940, 0, 6624.24429632138, 0, 53491.6396316164, 0, 446719.580094351], [862.940922221940, 0, 6624.24429632138, 0, 53491.6396316164, 0, 446719.580094351, 0], [0, 6624.24429632138, 0, 53491.6396316164, 0, 446719.580094351, 0, 3821086.12925173]])
# b:
#  Matrix([[0], [6.28318530717959], [0], [24.3134415175221], [0], [125.770539220120], [0], [758.223808308524]])
# coeff: [mpf('0.0'), mpf('0.99945019389327376'), mpf('0.0'), mpf('-0.16583845269804153'), mpf('0.0'), mpf('0.0079985814374336975'), mpf('0.0'), mpf('-0.00014774088079746696')]
# approximation: -0.000147740880797467*x**7 + 0.0079985814374337*x**5 - 0.165838452698042*x**3 + 0.999450193893274*x
# f: sin(x)
# u: -0.000147740880797467*x**7 + 0.0079985814374337*x**5 - 0.165838452698042*x**3 + 0.999450193893274*x
# ...evaluating matrix... (0,0)
# numerical integration of 1
# (0,1)
# numerical integration of x
# (0,2)
# numerical integration of x**2
# (0,3)
# numerical integration of x**3
# (0,4)
# numerical integration of x**4
# (0,5)
# numerical integration of x**5
# (0,6)
# numerical integration of x**6
# (0,7)
# numerical integration of x**7
# numerical integration of sin(x)
# (1,1)
# numerical integration of x**2
# (1,2)
# numerical integration of x**3
# (1,3)
# numerical integration of x**4
# (1,4)
# numerical integration of x**5
# (1,5)
# numerical integration of x**6
# (1,6)
# numerical integration of x**7
# (1,7)
# numerical integration of x**8
# numerical integration of x*sin(x)
# (2,2)
# numerical integration of x**4
# (2,3)
# numerical integration of x**5
# (2,4)
# numerical integration of x**6
# (2,5)
# numerical integration of x**7
# (2,6)
# numerical integration of x**8
# (2,7)
# numerical integration of x**9
# numerical integration of x**2*sin(x)
# (3,3)
# numerical integration of x**6
# (3,4)
# numerical integration of x**7
# (3,5)
# numerical integration of x**8
# (3,6)
# numerical integration of x**9
# (3,7)
# numerical integration of x**10
# numerical integration of x**3*sin(x)
# (4,4)
# numerical integration of x**8
# (4,5)
# numerical integration of x**9
# (4,6)
# numerical integration of x**10
# (4,7)
# numerical integration of x**11
# numerical integration of x**4*sin(x)
# (5,5)
# numerical integration of x**10
# (5,6)
# numerical integration of x**11
# (5,7)
# numerical integration of x**12
# numerical integration of x**5*sin(x)
# (6,6)
# numerical integration of x**12
# (6,7)
# numerical integration of x**13
# numerical integration of x**6*sin(x)
# (7,7)
# numerical integration of x**14
# numerical integration of x**7*sin(x)
#
# A:
#  Matrix([[9.42477796076938, 0, 69.7641225306746, 0, 929.534792535292, 0, 14744.1546632764, 0], [0, 69.7641225306746, 0, 929.534792535292, 0, 14744.1546632764, 0, 254658.204071277], [69.7641225306746, 0, 929.534792535292, 0, 14744.1546632764, 0, 254658.204071277, 0], [0, 929.534792535292, 0, 14744.1546632764, 0, 254658.204071277, 0, 4626896.23331150], [929.534792535292, 0, 14744.1546632764, 0, 254658.204071277, 0, 4626896.23331150, 0], [0, 14744.1546632764, 0, 254658.204071277, 0, 4626896.23331150, 0, 86940344.3719197], [14744.1546632764, 0, 254658.204071277, 0, 4626896.23331150, 0, 86940344.3719197, 0], [0, 254658.204071277, 0, 4626896.23331150, 0, 86940344.3719197, 0, 1673230270.61838]])
# b:
#  Matrix([[0], [-2.00000000000000], [0], [-121.239659414706], [0], [-2506.54204530225], [0], [-48036.7670602675]])
# coeff: [mpf('0.0'), mpf('0.98918799295036915'), mpf('0.0'), mpf('-0.15929043392322859'), mpf('0.0'), mpf('0.0069663982405030813'), mpf('0.0'), mpf('-0.00010075263466929024')]
# approximation: -0.00010075263466929*x**7 + 0.00696639824050308*x**5 - 0.159290433923229*x**3 + 0.989187992950369*x
# f: sin(x)
# u: -0.00010075263466929*x**7 + 0.00696639824050308*x**5 - 0.159290433923229*x**3 + 0.989187992950369*x
# ...evaluating matrix... (0,0)
# numerical integration of 1
# (0,1)
# numerical integration of x
# (0,2)
# numerical integration of x**2
# (0,3)
# numerical integration of x**3
# (0,4)
# numerical integration of x**4
# (0,5)
# numerical integration of x**5
# (0,6)
# numerical integration of x**6
# (0,7)
# numerical integration of x**7
# numerical integration of sin(x)
# (1,1)
# numerical integration of x**2
# (1,2)
# numerical integration of x**3
# (1,3)
# numerical integration of x**4
# (1,4)
# numerical integration of x**5
# (1,5)
# numerical integration of x**6
# (1,6)
# numerical integration of x**7
# (1,7)
# numerical integration of x**8
# numerical integration of x*sin(x)
# (2,2)
# numerical integration of x**4
# (2,3)
# numerical integration of x**5
# (2,4)
# numerical integration of x**6
# (2,5)
# numerical integration of x**7
# (2,6)
# numerical integration of x**8
# (2,7)
# numerical integration of x**9
# numerical integration of x**2*sin(x)
# (3,3)
# numerical integration of x**6
# (3,4)
# numerical integration of x**7
# (3,5)
# numerical integration of x**8
# (3,6)
# numerical integration of x**9
# (3,7)
# numerical integration of x**10
# numerical integration of x**3*sin(x)
# (4,4)
# numerical integration of x**8
# (4,5)
# numerical integration of x**9
# (4,6)
# numerical integration of x**10
# (4,7)
# numerical integration of x**11
# numerical integration of x**4*sin(x)
# (5,5)
# numerical integration of x**10
# (5,6)
# numerical integration of x**11
# (5,7)
# numerical integration of x**12
# numerical integration of x**5*sin(x)
# (6,6)
# numerical integration of x**12
# (6,7)
# numerical integration of x**13
# numerical integration of x**6*sin(x)
# (7,7)
# numerical integration of x**14
# numerical integration of x**7*sin(x)
#
# A:
#  Matrix([[12.5663706143592, 0, 165.366808961599, 0, 3917.05196525160, 0, 110456.438044408, 0], [0, 165.366808961599, 0, 3917.05196525160, 0, 110456.438044408, 0, 3391613.07971655], [165.366808961599, 0, 3917.05196525160, 0, 110456.438044408, 0, 3391613.07971655, 0], [0, 3917.05196525160, 0, 110456.438044408, 0, 3391613.07971655, 0, 109550877.965550], [3917.05196525160, 0, 110456.438044408, 0, 3391613.07971655, 0, 109550877.965550, 0], [0, 110456.438044408, 0, 3391613.07971655, 0, 109550877.965550, 0, 3659526800.13292], [110456.438044408, 0, 3391613.07971655, 0, 109550877.965550, 0, 3659526800.13292, 0], [0, 3391613.07971655, 0, 109550877.965550, 0, 3659526800.13292, 0, 125209350283.321]])
# b:
#  Matrix([[0], [-12.5663706143592], [0], [-420.702203198642], [0], [-11171.2157622852], [0], [-304004.004294882]])
# coeff: [mpf('0.0'), mpf('0.92597367983195629'), mpf('0.0'), mpf('-0.13738285823568559'), mpf('0.0'), mpf('0.0051258281521011748'), mpf('0.0'), mpf('-5.7122261160658068e-5')]
# approximation: -5.71222611606581e-5*x**7 + 0.00512582815210118*x**5 - 0.137382858235686*x**3 + 0.925973679831956*x
# f: sin(x)
# u: -5.71222611606581e-5*x**7 + 0.00512582815210118*x**5 - 0.137382858235686*x**3 + 0.925973679831956*x
# ...evaluating matrix... (0,0)
# numerical integration of 1
# (0,1)
# numerical integration of x
# (0,2)
# numerical integration of x**2
# (0,3)
# numerical integration of x**3
# (0,4)
# numerical integration of x**4
# (0,5)
# numerical integration of x**5
# (0,6)
# numerical integration of x**6
# (0,7)
# numerical integration of x**7
# numerical integration of sin(x)
# (1,1)
# numerical integration of x**2
# (1,2)
# numerical integration of x**3
# (1,3)
# numerical integration of x**4
# (1,4)
# numerical integration of x**5
# (1,5)
# numerical integration of x**6
# (1,6)
# numerical integration of x**7
# (1,7)
# numerical integration of x**8
# numerical integration of x*sin(x)
# (2,2)
# numerical integration of x**4
# (2,3)
# numerical integration of x**5
# (2,4)
# numerical integration of x**6
# (2,5)
# numerical integration of x**7
# (2,6)
# numerical integration of x**8
# (2,7)
# numerical integration of x**9
# numerical integration of x**2*sin(x)
# (3,3)
# numerical integration of x**6
# (3,4)
# numerical integration of x**7
# (3,5)
# numerical integration of x**8
# (3,6)
# numerical integration of x**9
# (3,7)
# numerical integration of x**10
# numerical integration of x**3*sin(x)
# (4,4)
# numerical integration of x**8
# (4,5)
# numerical integration of x**9
# (4,6)
# numerical integration of x**10
# (4,7)
# numerical integration of x**11
# numerical integration of x**4*sin(x)
# (5,5)
# numerical integration of x**10
# (5,6)
# numerical integration of x**11
# (5,7)
# numerical integration of x**12
# numerical integration of x**5*sin(x)
# (6,6)
# numerical integration of x**12
# (6,7)
# numerical integration of x**13
# numerical integration of x**6*sin(x)
# (7,7)
# numerical integration of x**14
# numerical integration of x**7*sin(x)
#
# A:
#  Matrix([[15.7079632679490, 0, 322.982048753123, 0, 11953.8939369251, 0, 526697.340223352, 0], [0, 322.982048753123, 0, 11953.8939369251, 0, 526697.340223352, 0, 25269486.6040092], [322.982048753123, 0, 11953.8939369251, 0, 526697.340223352, 0, 25269486.6040092, 0], [0, 11953.8939369251, 0, 526697.340223352, 0, 25269486.6040092, 0, 1275340071.47828], [11953.8939369251, 0, 526697.340223352, 0, 25269486.6040092, 0, 1275340071.47828, 0], [0, 526697.340223352, 0, 25269486.6040092, 0, 1275340071.47828, 0, 66566404714.3386], [526697.340223352, 0, 25269486.6040092, 0, 1275340071.47828, 0, 66566404714.3386, 0], [0, 25269486.6040092, 0, 1275340071.47828, 0, 66566404714.3386, 0, 3558663771722.22]])
# b:
#  Matrix([[0], [2.00000000000000], [0], [358.110165040851], [0], [30888.2228843402], [0], [1988692.85908580]])
# coeff: [mpf('0.0'), mpf('0.7317580301268817'), mpf('0.0'), mpf('-0.095454845019209241'), mpf('0.0'), mpf('0.0029517904361667358'), mpf('0.0'), mpf('-2.564309265229097e-5')]
# approximation: -2.5643092652291e-5*x**7 + 0.00295179043616674*x**5 - 0.0954548450192092*x**3 + 0.731758030126882*x
# f: sin(x)
# u: -2.5643092652291e-5*x**7 + 0.00295179043616674*x**5 - 0.0954548450192092*x**3 + 0.731758030126882*x
# doconce combine_images -2 tmp_N7_V1Omega2k2.png tmp_N7_V1Omega3k2.png tmp_N7_V1Omega4k2.png tmp_N7_V1Omega5k2.png sin_powers_N7_V1_Omega2.png
# doconce combine_images -2 tmp_N7_V1Omega2k2.pdf tmp_N7_V1Omega3k2.pdf tmp_N7_V1Omega4k2.pdf tmp_N7_V1Omega5k2.pdf sin_powers_N7_V1_Omega2.pdf
# f: sin(x)
# u: -7.64716373181982e-13*x**15 + 1.60590438368216e-10*x**13 - 2.50521083854417e-8*x**11 + 2.75573192239859e-6*x**9 - 0.000198412698412698*x**7 + 0.00833333333333333*x**5 - 0.166666666666667*x**3 + 1.0*x
