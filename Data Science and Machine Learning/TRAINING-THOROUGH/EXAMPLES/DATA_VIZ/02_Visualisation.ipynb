# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0,2,10)
y = x**2
print(x)
# Out:
# [0.         0.22222222 0.44444444 0.66666667 0.88888889 1.11111111
#  1.33333333 1.55555556 1.77777778 2.        ]

# %% [markdown]
# ### Pyplot

# %%
#attention toujours avoir les mêmes dimensions
plt.plot(x,y)
plt.show()

# %%
plt.scatter(x,y)
plt.show()

# %%
#ajouts de paramètres:c : couleurs, lw = épaisseur, ls = style
plt.plot(x,y, c= 'red',lw=4, ls='--')
plt.show()

# %% [markdown]
# ### cycle de vie d'une figure

# %%
#début de la figure
plt.figure()
#contenu de la figure
plt.plot(x,y, label= 'quadratique')
plt.plot(x,x**3, label ='cubique')
##on peut ajouter un titre
plt.title('figure1')
plt.xlabel('axe x')
plt.ylabel('axe y')
plt.legend()
#affiche la figure
plt.show()
#enregistrer notre figure
plt.savefig('figure.png') 

#faire une autre figure
plt.figure()
plt.plot(x,y)

# %%
## subplot grille de graphiques plt.subplot(lignes, colonnes, poisition)
plt.subplot(2,1,1)
plt.plot(x,y,c='red')
plt.subplot(2,1,2)
plt.plot(x,y,c='blue')

# %%
plt.figure()
plt.subplot(2,2,1)
plt.plot(x,y)
plt.title('graphique 1')
plt.subplot(2,2,2)
plt.plot(x,np.sin(x),label='sinus')
plt.plot(x,np.cos(x),label='cosinus')
plt.title('graphique 2')
plt.legend()
plt.show()

# %% [markdown]
# ## façon orientée objet

# %%
#permet de creer des figures qui partagent la même absisse
#fig est un objet et ax est un tableau ndarray qui contient des objets
fig, ax = plt.subplots(2,1,sharex=True)
ax[0].plot(x,y)
ax[1].plot(x,np.sin(x))
plt.show()

# %% [markdown]
# ### Experience

# %%
dataset = {f"experience {i}": np.random.randn(100)for i in range(4)}
dataset
# Out:
# {'experience 0': array([ 0.10077716,  0.59567817, -0.05820978, -0.93049884, -1.47035134,
#         -0.21511711, -0.22591213,  0.80406405, -1.14679528, -0.93461121,
#         -0.77132601,  0.3643144 ,  0.16277542,  0.31560321,  1.59371285,
#          0.15700389, -0.31106346,  0.75480917,  0.66656748, -0.21059507,
#          0.47910621, -0.5754001 ,  1.41468641,  2.13001573,  0.03933099,
#          0.25195396, -0.76566848, -0.05370892,  1.12927486, -0.41629361,
#         -0.17872241, -1.17094429,  0.46202024,  0.88433872, -2.16895262,
#          0.66559648,  0.63952287,  1.73265758, -1.14818097, -0.30238457,
#          1.58594453, -1.07211894,  1.32557564, -1.65468642,  0.13414487,
#          1.27845398,  0.83594662,  0.39695863,  0.65188401,  0.8728651 ,
#         -0.72187047,  0.55533844,  1.53709556,  0.94088673,  0.97402286,
#          1.96721042, -0.24224351, -0.88395623,  1.05077889, -0.53941673,
#          0.16419393,  0.30388052,  0.27140535, -0.08222382, -1.28650035,
# ...

# %% [raw]
# for k, v in dataset.items():
#     print(k)

# %%
n = len(dataset)
plt.figure(figsize = (12,8))
for k,i in zip(dataset.keys(),range(1,n+1)):
    plt.subplot(n,1,i)
    plt.plot(dataset[k])
    plt.title(k)
plt.show()

# %%
def graphique(data):
    #le nombre d'experiences que l'on veut
    n = len(data)
    plt.figuresize(12,8)
    for k , i in zip(data.keys(), range(1,n+1)):
        plt.subplot(n,1,i)
        plt.plot(data[k])
        plt.title(k)
        
    plt.show()
